# %% [markdown]
# `python3.11 -m pip install jupyterlab PyEnchant scipy numpy spotipy scikit-learn --user`

# %% [markdown]
# # Init & Login

# %%
import time, pickle, os
from math import ceil
from random import randrange, choice, random
from time import sleep
from pprint import pprint
from uuid import uuid4

import enchant
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from scipy.spatial import cKDTree

from ShuffleSoGood import ( SpotifyClient, update_music_database, load_music_database, 
                            save_music_database, genre_vector_ops, now )

sc = SpotifyClient()
# Out:
# TOKEN OBTAINED

# %%
sc.check_API_token()
# Out:
# TOKEN STILL VALID, AGE: 0.03 MINUTES

# %% [markdown]
# ## Playlists

# %%
playlist = {
    'study01' : "0a2qoe6S7lYeZ6nlhZdA0v",
    'study02' : "6gbtR2cBq5PvkghidCvvGk",
    'study03' : "3o3lN2qntdEV7UKTuuC77K",
    'study04' : "41sFSisljvBDMBXtpp5NIw",
    'study05' : "02iS5AFGp8YVuUUqcQf8ys",
    'study06' : "6KI7A4MWrSM7EyKRUjxIi1",
    'study07' : "3V055Md2JdrUT8tX0af7di",
    'study08' : "0tspdJlwSgiyf2O9PO6QaP",
    'study09' : "5mHRBFoQtYy2izeZ66pG95",
    'study10' : "3832xeKGEOAXFJqE4K8kIq",
    'study11' : "65MXR4dubPL9t0P4dgTWvn",
    'study12' : "0ecSAfnD4CulIVnLt26ukI",
    'study13' : "7K9ucByFRgDuZk8KMHeJkL",
    'study14' : "0v26bHydUxcGC5EbMlkjzG",
    'study15' : "6SqlfurCBP7eeMOojaDNtS",
}

review = {
    'zf_Over' : "5TtKaKCouyJp7Hhtu4YlYm",
    'zg_Over' : "5qX1Tq3IQ74iSgrlMfRhty",
    'zh_Over' : "1bwXMYoRgEFWebWZ9ZPBqs",
}

# %% [markdown]
# ## Session Database

# %% [markdown]
# * FILTER TYPES: {'album', 'artist', 'track', 'year', 'upc', 'tag:hipster', 'tag:new', 'isrc', 'genre',}
# * SEARCH TYPES: {"album", "artist", "playlist", "track", "show", "episode", "audiobook",}

# %%
##### Session Database Params #####
_MOD_T_DAY_S  = 60.0 * 60 * 24
_STALE_TIME_S = _MOD_T_DAY_S * 31
_NULL_GENRE   = "Music"
_DATA_DIR     = "data/"
_DATA_PREFIX  = "Study-Music-Data_"

# %%
from ShuffleSoGood import init_session_database
data, timestamp, outFilNam, outPath = init_session_database( _DATA_PREFIX )

# %% [markdown]
# ## Settings

# %%
## General Params ##
_N_BACKFILL  = 400
_N_GN_CHUNK  = 100 # 50 # 200
_N_RM_CHUNK  = 125 #500
_NAME_PT_LIM =   6

## Search 01 Params ##
_N_MAX_SEARCH = 50
_N_DEF_SEARCH = 10
_YEAR_PADDING =  5

## DBSCAN Params ##
_DBS_EPSILON  =  0.7500 # 0.200 # 0.300 # 0.400 # 0.500 # 0.750
_DBS_MIN_MMBR =  3

## Mini-Genre Params ##
_MRG_D_FACTOR =  1.25 # 1.0 # 1.5 # 2.0 #3.0
_MIN_GNR_MMBR =  7
_ONE_BILLION  = 1e9

## Query History Keys ##
_NU_REL_Q_KEY = "NewReleases:Albums" # Query Key for New Releases
_FEAT_PL_Q_KY = "Featured:Playlists" # Query Key for Featured Playlists
_ART_Q_PREFIX = "ArtistTopTracks:" # - Query Key Prefix for Artist Top Tracks

# %% [markdown]
# # Function Selection

# %%
_LOAD_DB_PKL = False
_REGEN_DBASE = False
_SEARCH_BKFL = False
_FILL_PL_ID  = review['zh_Over']
_TEST_ADV    = True

# %% [markdown]
# # Query Functions

# %%
def get_playlist_length( playlist_ID ):
    """ Get the number of total tracks in the playlist """
    response = sc.spot.user_playlist_tracks(
        sc.CLIENT_ID, 
        playlist_ID, 
        fields = 'items,uri,name,id,total', 
        limit  = sc._RESPONSE_LIMIT
    )
    return response['total']

# %% [markdown]
# # Search Version 01, Query by Existing Artist and Year

# %%
def search_artist_within_era( artistName, releaseDate, 
                              N = _N_MAX_SEARCH, yearPadding = _YEAR_PADDING, pause_s = 0.5 ):
    """ Return `N` tracks within `yearPadding` of `trackDict` and by the same artist """
    global data
    rtnLs = list()
    query = "artist%3A" + str( artistName ).replace( " ", "%20")
    try:
        rYear = int( str( releaseDate )[:4] )
    except Exception:
        rYear = 2024
    bYear   = rYear - yearPadding
    eYear   = rYear + yearPadding
    years   = list( range( bYear, eYear+1 ) )
    miniLim = max( int(N/(eYear - bYear)), 1 )
    Nloop   = int(N / miniLim * 2)
    for i in range( Nloop ):
        iYear = choice( years )
        qry_i = query + "%20year%3A" + str( iYear )
        print( f"Search: {qry_i}" )

        if (data is not None):
            if (qry_i in data['queries']):
                ofst = data['queries'][ qry_i ]
                data['queries'][ qry_i ] += miniLim
            else:
                ofst = 0
                data['queries'][ qry_i ] = miniLim
        else:
            ofst = 0
        
        res = sc.spot.search( qry_i, 
                           limit  = miniLim, 
                           offset = min( ofst, _MAX_OFFSET ), 
                           type   = 'track' )
        sleep( pause_s )
        
        # tracks_i = [item['id'] for item in res['tracks']['items']]
        tracks_i = res['tracks']['items']
        
        if (data is not None):
            tracks_ii = list()
            for trk_j in tracks_i:
                if trk_j['id'] not in data['collectID']:
                    tracks_ii.append( trk_j )
            tracks_i = tracks_ii[:]

        rem = N - len( rtnLs )
        if len( tracks_i ) > rem:
            rtnLs.extend( tracks_i[:rem] )
            return rtnLs
        else:
            rtnLs.extend( tracks_i )
            # sleep( pause_s )
    return rtnLs


def choose_N_artist_year_pairs_from_db( N ):
    """ Fetch `N` random (<Artist>, <Date>) pairs from the `data` for searching """
    global data
    rtnPairs = list()
    artList  = list( data['artists'].keys() )
    print( f"How Many Artists?: {len(artList)}" )
    for i in range(N):
        artKey_i = choice( artList )
        artist_i = data['artists'][ artKey_i ]['name']
        rlYear_i = choice( data['artists'][ artKey_i ]['releases'] ) if len( data['artists'][ artKey_i ]['releases'] ) else '2024'
        rtnPairs.append( (artist_i, rlYear_i,) )
    return rtnPairs


def basic_new_music_search_01( Ntot, Mper = 5, pause_s = 0.125 ):
    """ Choose random `data` entries as search queries, Return a list of `Ntot` tracks consisting of `Mper` entries for each artist """  
    global data
    rtnLst   = list()
    searches = choose_N_artist_year_pairs_from_db( int( ceil( Ntot/Mper ) )*2 )
    addSet   = set([])
    for (art_i, rel_i) in searches:
        print( f"\tSearch, Artist: {art_i}, Around Year: {rel_i}" )
        rem    = Ntot - len( rtnLst )
        Mper   = min( Mper, rem )
        trks   = search_artist_within_era( art_i, rel_i, N = Mper, yearPadding = 3, pause_s = 0.5 )
        trks_i = list()
        for trk in trks:
            if trk['id'] not in addSet:
                trks_i.append( trk )
                addSet.add( trk['id'] )
        rem = Ntot - len( rtnLst )
        if rem > len( trks_i ):
            rtnLst.extend( trks_i )
        else:
            rtnLst.extend( trks_i[ :rem ] )
            break
        sleep( pause_s )
        sc.check_API_token()
    return rtnLst

# %% [markdown]
# # Helper Functions

# %%
########## CONTAINER FUNCTIONS #####################################################################

def sort_keys_by_value( dct, reverse = True ):
    """ Return a list of keys sorted by their (numeric) values """
    srtLst = list()
    for k, v in dct.items():
        srtLst.append( [v,k,] )
    srtLst.sort( key = lambda x: x[0], reverse = reverse )
    return [pair[1] for pair in srtLst] 



########## STRING ANALYSIS #########################################################################
from collections import deque

def levenshtein_dist( s1, s2 ):
    """ Get the edit distance between two strings """
    # Author: Salvador Dali, https://stackoverflow.com/a/32558749
    if len(s1) > len(s2):
        s1, s2 = s2, s1
    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = deque()
        distances_.append( i2+1 )
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        # distances = distances_
    # return distances[-1]
    return distances_.pop()


########## STATS & SAMPLING ########################################################################


def total_pop( odds ):
    """ Sum over all categories in the prior odds """
    total = 0
    for k in odds:
        total += odds[k]
    return total


def normalize_dist( odds_ ):
    """ Normalize the distribution so that the sum equals 1.0 """
    total  = total_pop( odds_ )
    rtnDst = dict()
    for k in odds_:
        rtnDst[k] = odds_[k] / total
    return rtnDst


def roll_outcome( odds ):
    """ Get a random outcome from the distribution """
    oddsNorm = normalize_dist( odds )
    distrib  = []
    outcome  = []
    total    = 0.0
    for o, p in oddsNorm.items():
        total += p
        distrib.append( total )
        outcome.append( o )
    roll = random()
    for i, p in enumerate( distrib ):
        if roll <= p:
            return outcome[i]
    return None

# %% [markdown]
# # Search Version 03, More Dimensions from Audio Analysis

# %%
from collections import defaultdict
from ShuffleSoGood import get_tracks_as_vectors, _V_NUM_FEATURES


def zip_dict_sorted_by_decreasing_value( dct ):
    """ Return a list of (k,v) tuples sorted by decreasing value """
    keys = list()
    vals = list()
    for k, v in dct.items():
        keys.append(k)
        vals.append(v)
    return sorted( zip( keys, vals ), key=lambda x: x[1], reverse=1)


"""
'segments': [{'confidence': 0.0,
               'duration': 0.20726,
               'loudness_end': 0.0,
               'loudness_max': -18.031,
               'loudness_max_time': 0.02426,
               'loudness_start': -24.279,
               'pitches': [0.004,
                           0.005,
                           0.01,
                           0.15,
                           1.0,
                           0.131,
                           0.009,
                           0.003,
                           0.008,
                           0.002,
                           0.002,
                           0.015],
               'start': 0.0,
               'timbre': [39.821,
                          28.025,
                          -99.44,
                          -42.135,
                          58.998,
                          -47.306,
                          7.856,
                          12.332,
                          -19.522,
                          13.344,
                          -3.278,
                          10.72]},
"""
    
    
def audio_analysis_summary( trkAudioDct ):
    """ Provide a summary of the audio analysis in order to provide extra sound dimensions """
    # FIXME: USE TIMBRE INFORMATION!

    def give_0():
        return 0
    
    ## Get Key Spread && Section Length ##
    sections = trkAudioDct['sections']
    trkKeys  = defaultdict( give_0 )
    sctDurs = list()
    for sctn in sections:
        sctDurs.append( sctn['duration'] )
        mode    = -0.5 if ((sctn['mode'] == 1) and (sctn['mode_confidence'] > 0.5)) else 0.0
        wght_i  = sctn['confidence'] * sctn['key_confidence']
        trkKeys[ sctn['key']+mode ] += wght_i
    SECT_DUR   = sum( sctDurs ) / len( sctDurs ) # Scalar for how often the song "shifts"
    keyRank    = zip_dict_sorted_by_decreasing_value( trkKeys )
    # Scalar for how much keys "move"
    if len( keyRank ) >= 3:
        KEY_SPREAD = abs( keyRank[0][0] - keyRank[1][0] ) + abs( keyRank[1][0] - keyRank[2][0] ) 
    elif len( keyRank ) == 2:
        KEY_SPREAD = abs( keyRank[0][0] - keyRank[1][0] )
    else:
        KEY_SPREAD = 0.0
    
    ## Get Bar Duration ##
    # Possibly analogous to tempo
    barDurs = list()
    for bar in trkAudioDct['bars']:
        barDurs.append( bar['duration'] )
    BAR_DUR = sum( barDurs ) / len( barDurs )

    ## Get Beat Strength ##
    # Use confidence in beats as an overall measure of how "sharp" the beats are
    beatCs = list()
    for beat in trkAudioDct['beats']:
        beatCs.append( beat['confidence'] )
    BEAT_STRENGTH = sum( beatCs ) / len( beatCs )

    return {
        "SECT_DUR"      : SECT_DUR,
        "BAR_DUR"       : BAR_DUR,
        "KEY_SPREAD"    : KEY_SPREAD,
        "BEAT_STRENGTH" : BEAT_STRENGTH,
    }
    

def fetch_entire_playlist_with_audio_features( playlist_ID, pause_s = 0.05 ):
    """ Get maximum infodump on all playlist tracks """
    # 2024-11-03: Summarized the audio analysis

    plTracks = []
    Ntracks  = get_playlist_length( playlist_ID )
    trCount  = 0
    trOffst  = 0

    resTracks = list()
    
    while trCount < Ntracks:

        lim = min( sc._RESPONSE_LIMIT, Ntracks-trCount )

        response = sc.spot.user_playlist_tracks(
            sc.CLIENT_ID, 
            playlist_ID, 
            fields = 'items,uri,name,id,total', 
            limit  = lim,
            offset = trCount
        )
        
        sleep( pause_s )

        if len( response['items'] ):
            trCount  += len( response['items'] )
            resTracks += response['items']

        print('>',end=' ',flush=True)

    print( f"\tObtained basic track info for {len(resTracks)} tracks!" )

            
    resIDs    = [item['track']['id'] for item in resTracks]
    resFeatrs = list()
    trCount   = 0
    bgn       = 0
    end       = 0

    while trCount < Ntracks:

        lim      = min( sc._RESPONSE_LIMIT, Ntracks-trCount )
        end      = bgn + lim
        response = sc.spot.audio_features( resIDs[ bgn:end ] )
        sleep( pause_s )
        
        if len( response ):
            trCount   += len( response )
            resFeatrs += response
            bgn        = end

        print('>',end=' ',flush=True)

    print( f"\tObtained detailed track info for {len(resFeatrs)} tracks!" )


    for i, track_i in enumerate( resTracks ):
        track_i.update( resFeatrs[i] )
        details   = sc.spot.audio_analysis( track_i['id'] )
        sleep( pause_s/10.0 )
        audioSmry = audio_analysis_summary( details )
        track_i['sectionDur']  = audioSmry["SECT_DUR"]
        track_i['barDuration'] = audioSmry["BAR_DUR"]
        track_i['keySpread']   = audioSmry["KEY_SPREAD"]
        track_i['beatSharp']   = audioSmry["BEAT_STRENGTH"]
        if( (i+1)%sc._RESPONSE_LIMIT == 0 ):
            print('>',end=' ',flush=True)

    print( f"\tObtained detailed audio info for {len(resFeatrs)} tracks!" )
            

    return resTracks


def assign_vectors_to_tracks( tracks ):
    """ Store vector info in each track dictionary """
    matxTrks = get_tracks_as_vectors( tracks )
    for i, vec_i in enumerate( matxTrks ):
        trk_i = tracks[i]
        trk_i['vector'] = vec_i
    print( f"Stored vectors for {len(tracks)} tracks!" )


def fetch_collection_with_audio_features( plDct, rvDct = None, pause_s = 3.0, renewSets = True ):
    """ Get maximum infodump on all playlists """
    global data

    if renewSets:
        data['collectID'] = set([])
    
    print( "##### Get Collection Data #####" )
    for plName_i, plID_i in plDct.items():
        print( plName_i, '-', plID_i, '...' )
        tracks_i = fetch_entire_playlist_with_audio_features( plID_i )
        assign_vectors_to_tracks( tracks_i )
        data['playlists'][ plName_i ] = {
            'ID'    : plID_i,
            'tracks': tracks_i,
            'len'   : len( tracks_i ),
        }
        data['collectID'] = data['collectID'].union( set([trk['track']['id'] for trk in tracks_i]) )

        # Catalog artists from collection tracks (Req'd for (Sub-)Search 01)
        for track_j in tracks_i:
            for artist_k in track_j['track']['artists']:
                artistID_j = artist_k['id']
                if artistID_j not in data['artists']:
                    data['artists'][ artistID_j ] = { 
                        'name'    : track_j['track']['artists'][0]['name'], 
                        'count'   : 1, 
                        'releases': [track_j['track']['album']['release_date'],], 
                    }
                else:
                    data['artists'][ artistID_j ]['count'   ] += 1
                    data['artists'][ artistID_j ]['releases'].append( track_j['track']['album']['release_date'] )
        
        sleep( pause_s )

    if rvDct is not None:
        print( "\n##### Get Review Data #####" )
        for plName_i, plID_i in rvDct.items():
            print( plName_i, '-', plID_i, '...' )
            tracks_i = fetch_entire_playlist_with_audio_features( plID_i )
            assign_vectors_to_tracks( tracks_i )
            data['review'][ plName_i ] = {
                'ID'    : plID_i,
                'tracks': tracks_i,
                'len'   : len( tracks_i ),
            }
            data['reviewID'] = data['reviewID'].union( set([trk['track']['id'] for trk in tracks_i]) )
            sleep( pause_s )

    print( "\n##### Complete #####" )


def analyze_db_vector_spread( ):
    """ Gather info for feature scaling and print it for manual scaling update """
    global data
    rtnMatx = np.ones( (2, _V_NUM_FEATURES,) )
    rtnMatx[0,:] *=  1e6
    rtnMatx[1,:] *= -1e6
    totlDct = dict()
    totlDct.update( data['playlists'] )
    totlDct.update( data['review'   ] )
    for plName_i, playls_i in totlDct.items():
        if len( playls_i['tracks'] ):
            matx_i = get_tracks_as_vectors( playls_i['tracks'] )
            mMin_i = np.min( matx_i, axis = 0 )
            mMax_i = np.max( matx_i, axis = 0 )
            for j in range( _V_NUM_FEATURES ):
                if mMin_i[j] < rtnMatx[0,j]:
                    rtnMatx[0,j] = mMin_i[j]
                if mMax_i[j] > rtnMatx[1,j]:
                    rtnMatx[1,j] = mMax_i[j]
    for j in range( _V_NUM_FEATURES ):
        print( f"Feature {j+1}, Span: {rtnMatx[1,j] - rtnMatx[0,j]}, Min: {rtnMatx[0,j]}" )
    return rtnMatx

# %%
if _LOAD_DB_PKL:
    data = load_music_database( data, _DATA_DIR, _DATA_PREFIX, forceLoad = 1 );

# %%
if _REGEN_DBASE:
    fetch_collection_with_audio_features( playlist, review, pause_s = 3.0 )

# %%
if _REGEN_DBASE:
    analyze_db_vector_spread(  );
    save_music_database( data, outPath )

# %% [markdown]
# # Audio Analysis Test

# %%
if _TEST_ADV:
    from pprint import pprint
    plTracks = fetch_entire_playlist_with_audio_features( playlist['study01'] )
    
if _TEST_ADV:
    track    = plTracks[0]
    # pprint( track )
    details  = sc.spot.audio_analysis( track['id'] )
    pprint( details )
    pprint( audio_analysis_summary( details ) )
# Out:
# > > > > 	Obtained basic track info for 400 tracks!
# > > > > 	Obtained detailed track info for 400 tracks!
# > > > > 	Obtained detailed audio info for 400 tracks!
# {'bars': [{'confidence': 0.468, 'duration': 1.6651, 'start': 0.02346},
#           {'confidence': 0.519, 'duration': 1.67591, 'start': 1.68856},
#           {'confidence': 0.353, 'duration': 1.67899, 'start': 3.36447},
#           {'confidence': 0.412, 'duration': 1.68212, 'start': 5.04345},
#           {'confidence': 0.8, 'duration': 1.68041, 'start': 6.72557},
#           {'confidence': 0.361, 'duration': 1.67592, 'start': 8.40598},
#           {'confidence': 0.639, 'duration': 1.68096, 'start': 10.0819},
#           {'confidence': 0.719, 'duration': 1.67707, 'start': 11.76286},
#           {'confidence': 0.483, 'duration': 1.67465, 'start': 13.43993},
#           {'confidence': 0.539, 'duration': 1.68066, 'start': 15.11458},
#           {'confidence': 0.322, 'duration': 1.67617, 'start': 16.79524},
#           {'confidence': 0.52, 'duration': 1.67542, 'start': 18.47141},
#           {'confidence': 0.665, 'duration': 1.67928, 'start': 20.14684},
#           {'confidence': 0.346, 'duration': 1.68116, 'start': 21.82612},
#           {'confidence': 0.541, 'duration': 1.67693, 'start': 23.50728},
#           {'confidence': 0.653, 'duration': 1.68227, 'start': 25.18421},
#           {'confidence': 0.478, 'duration': 1.67933, 'start': 26.86649},
#           {'confidence': 0.307, 'duration': 1.68114, 'start': 28.54582},
#           {'confidence': 0.624, 'duration': 1.67592, 'start': 30.22696},
#           {'confidence': 0.44, 'duration': 1.67653, 'start': 31.90287},
#           {'confidence': 0.565, 'duration': 1.6803, 'start': 33.5794},
#           {'confidence': 0.214, 'duration': 1.67676, 'start': 35.2597},
#           {'confidence': 0.314, 'duration': 1.67788, 'start': 36.93646},
#           {'confidence': 0.513, 'duration': 1.67804, 'start': 38.61434},
#           {'confidence': 0.133, 'duration': 1.67857, 'start': 40.29238},
#           {'confidence': 0.826, 'duration': 1.66934, 'start': 41.97094},
#           {'confidence': 0.274, 'duration': 1.67805, 'start': 43.64028},
#           {'confidence': 0.457, 'duration': 1.68115, 'start': 45.31833},
#           {'confidence': 0.589, 'duration': 1.68259, 'start': 46.99948},
#           {'confidence': 0.641, 'duration': 1.67341, 'start': 48.68208},
#           {'confidence': 0.438, 'duration': 1.67639, 'start': 50.35548},
#           {'confidence': 0.298, 'duration': 1.68085, 'start': 52.03188},
#           {'confidence': 0.814, 'duration': 1.68172, 'start': 53.71273},
#           {'confidence': 0.291, 'duration': 1.67846, 'start': 55.39445},
#           {'confidence': 0.638, 'duration': 1.67618, 'start': 57.07291},
#           {'confidence': 0.113, 'duration': 1.67505, 'start': 58.74909},
#           {'confidence': 0.625, 'duration': 1.67989, 'start': 60.42414},
#           {'confidence': 0.233, 'duration': 1.67832, 'start': 62.10402},
#           {'confidence': 0.315, 'duration': 1.67917, 'start': 63.78234},
#           {'confidence': 0.493, 'duration': 1.67909, 'start': 65.46151},
#           {'confidence': 0.619, 'duration': 1.67915, 'start': 67.14059},
#           {'confidence': 0.452, 'duration': 1.6788, 'start': 68.81974},
#           {'confidence': 0.515, 'duration': 1.6789, 'start': 70.49854},
#           {'confidence': 0.152, 'duration': 1.67836, 'start': 72.17744},
#           {'confidence': 0.604, 'duration': 1.67778, 'start': 73.85579},
#           {'confidence': 0.331, 'duration': 1.67527, 'start': 75.53357},
#           {'confidence': 0.184, 'duration': 1.67918, 'start': 77.20885},
#           {'confidence': 0.242, 'duration': 1.68029, 'start': 78.88803},
#           {'confidence': 0.662, 'duration': 1.68124, 'start': 80.56832},
#           {'confidence': 0.05, 'duration': 1.6795, 'start': 82.24955},
#           {'confidence': 0.192, 'duration': 1.67837, 'start': 83.92905},
#           {'confidence': 0.58, 'duration': 1.68202, 'start': 85.60742},
#           {'confidence': 0.361, 'duration': 1.67942, 'start': 87.28944},
#           {'confidence': 0.597, 'duration': 1.67935, 'start': 88.96886},
#           {'confidence': 0.193, 'duration': 1.67802, 'start': 90.6482},
#           {'confidence': 0.248, 'duration': 1.67474, 'start': 92.32623},
#           {'confidence': 0.524, 'duration': 1.67979, 'start': 94.00097},
#           {'confidence': 0.681, 'duration': 1.67942, 'start': 95.68075},
#           {'confidence': 0.123, 'duration': 1.68135, 'start': 97.36017},
#           {'confidence': 0.386, 'duration': 1.67392, 'start': 99.04152},
#           {'confidence': 0.337, 'duration': 1.67759, 'start': 100.71545},
#           {'confidence': 0.406, 'duration': 1.68154, 'start': 102.39303},
#           {'confidence': 0.104, 'duration': 1.67662, 'start': 104.07457},
#           {'confidence': 0.39, 'duration': 1.67318, 'start': 105.75119},
#           {'confidence': 0.593, 'duration': 1.68525, 'start': 107.42437},
#           {'confidence': 0.458, 'duration': 1.68411, 'start': 109.10962},
#           {'confidence': 0.184, 'duration': 1.68036, 'start': 110.79373},
#           {'confidence': 0.413, 'duration': 1.67894, 'start': 112.4741},
#           {'confidence': 0.584, 'duration': 1.67105, 'start': 114.15303},
#           {'confidence': 0.587, 'duration': 1.67299, 'start': 115.82408},
#           {'confidence': 0.54, 'duration': 1.67612, 'start': 117.49707},
#           {'confidence': 0.321, 'duration': 1.6785, 'start': 119.17319},
#           {'confidence': 0.314, 'duration': 1.67805, 'start': 120.85169},
#           {'confidence': 0.553, 'duration': 1.6762, 'start': 122.52974},
#           {'confidence': 0.194, 'duration': 1.67808, 'start': 124.20594},
#           {'confidence': 0.413, 'duration': 1.6801, 'start': 125.88402},
#           {'confidence': 0.241, 'duration': 1.67689, 'start': 127.56411},
#           {'confidence': 0.506, 'duration': 1.67877, 'start': 129.241},
#           {'confidence': 0.367, 'duration': 1.67886, 'start': 130.91977},
#           {'confidence': 0.502, 'duration': 1.68293, 'start': 132.59863},
#           {'confidence': 0.475, 'duration': 1.67907, 'start': 134.28157},
#           {'confidence': 0.229, 'duration': 1.67155, 'start': 135.96065},
#           {'confidence': 0.415, 'duration': 1.67888, 'start': 137.63219},
#           {'confidence': 0.612, 'duration': 1.67535, 'start': 139.31107},
#           {'confidence': 0.645, 'duration': 1.67441, 'start': 140.9864},
#           {'confidence': 0.531, 'duration': 1.6761, 'start': 142.66083},
#           {'confidence': 0.22, 'duration': 1.67929, 'start': 144.33693},
#           {'confidence': 0.364, 'duration': 0.42024, 'start': 146.01622},
#           {'confidence': 0.524, 'duration': 1.67742, 'start': 146.43646},
#           {'confidence': 0.427, 'duration': 1.67725, 'start': 148.11388},
#           {'confidence': 0.613, 'duration': 1.68423, 'start': 149.79112},
#           {'confidence': 0.605, 'duration': 1.68117, 'start': 151.47536},
#           {'confidence': 0.493, 'duration': 1.67458, 'start': 153.15652},
#           {'confidence': 0.382, 'duration': 1.67769, 'start': 154.83112},
#           {'confidence': 0.23, 'duration': 1.67679, 'start': 156.5088},
#           {'confidence': 0.373, 'duration': 1.67508, 'start': 158.1856},
#           {'confidence': 0.443, 'duration': 1.68068, 'start': 159.86066},
#           {'confidence': 0.328, 'duration': 1.67711, 'start': 161.54134},
#           {'confidence': 0.605, 'duration': 1.68902, 'start': 163.21844},
#           {'confidence': 0.211, 'duration': 1.68646, 'start': 164.90747},
#           {'confidence': 0.38, 'duration': 1.68894, 'start': 166.59393},
#           {'confidence': 0.506, 'duration': 1.67421, 'start': 168.28287},
#           {'confidence': 0.47, 'duration': 1.64473, 'start': 169.95708},
#           {'confidence': 0.695, 'duration': 1.67756, 'start': 171.6018},
#           {'confidence': 0.857, 'duration': 1.66136, 'start': 173.27937},
#           {'confidence': 0.613, 'duration': 1.65221, 'start': 174.94073},
#           {'confidence': 0.763, 'duration': 1.6715, 'start': 176.59294},
#           {'confidence': 0.719, 'duration': 1.67996, 'start': 178.26443},
#           {'confidence': 0.381, 'duration': 1.696, 'start': 179.9444},
#           {'confidence': 0.263, 'duration': 1.71629, 'start': 181.6404}],
#  'beats': [{'confidence': 0.412, 'duration': 0.41242, 'start': 0.02346},
#            {'confidence': 0.59, 'duration': 0.41574, 'start': 0.43587},
#            {'confidence': 0.49, 'duration': 0.41877, 'start': 0.85161},
#            {'confidence': 0.526, 'duration': 0.41818, 'start': 1.27038},
#            {'confidence': 0.381, 'duration': 0.41843, 'start': 1.68856},
#            {'confidence': 0.471, 'duration': 0.41955, 'start': 2.10699},
#            {'confidence': 0.442, 'duration': 0.41916, 'start': 2.52654},
#            {'confidence': 0.542, 'duration': 0.41877, 'start': 2.9457},
#            {'confidence': 0.483, 'duration': 0.41951, 'start': 3.36447},
#            {'confidence': 0.537, 'duration': 0.4197, 'start': 3.78398},
#            {'confidence': 0.506, 'duration': 0.4197, 'start': 4.20368},
#            {'confidence': 0.539, 'duration': 0.42007, 'start': 4.62338},
#            {'confidence': 0.491, 'duration': 0.42007, 'start': 5.04345},
#            {'confidence': 0.509, 'duration': 0.42044, 'start': 5.46352},
#            {'confidence': 0.426, 'duration': 0.421, 'start': 5.88396},
#            {'confidence': 0.457, 'duration': 0.42061, 'start': 6.30496},
#            {'confidence': 0.394, 'duration': 0.42059, 'start': 6.72557},
#            {'confidence': 0.512, 'duration': 0.42058, 'start': 7.14616},
#            {'confidence': 0.561, 'duration': 0.41981, 'start': 7.56674},
#            {'confidence': 0.57, 'duration': 0.41942, 'start': 7.98655},
#            {'confidence': 0.58, 'duration': 0.41922, 'start': 8.40598},
#            {'confidence': 0.644, 'duration': 0.41884, 'start': 8.8252},
#            {'confidence': 0.701, 'duration': 0.41884, 'start': 9.24404},
#            {'confidence': 0.772, 'duration': 0.41902, 'start': 9.66288},
#            {'confidence': 0.719, 'duration': 0.41939, 'start': 10.0819},
#            {'confidence': 0.634, 'duration': 0.42015, 'start': 10.50129},
#            {'confidence': 0.57, 'duration': 0.42109, 'start': 10.92144},
#            {'confidence': 0.546, 'duration': 0.42034, 'start': 11.34252},
#            {'confidence': 0.543, 'duration': 0.42015, 'start': 11.76286},
#            {'confidence': 0.64, 'duration': 0.41997, 'start': 12.18301},
#            {'confidence': 0.626, 'duration': 0.41847, 'start': 12.60298},
#            {'confidence': 0.551, 'duration': 0.41847, 'start': 13.02145},
#            {'confidence': 0.413, 'duration': 0.41847, 'start': 13.43993},
#            {'confidence': 0.385, 'duration': 0.41791, 'start': 13.8584},
#            {'confidence': 0.406, 'duration': 0.41885, 'start': 14.27632},
#            {'confidence': 0.395, 'duration': 0.41941, 'start': 14.69517},
#            {'confidence': 0.415, 'duration': 0.4196, 'start': 15.11458},
#            {'confidence': 0.45, 'duration': 0.42073, 'start': 15.53418},
#            {'confidence': 0.451, 'duration': 0.42035, 'start': 15.95491},
#            {'confidence': 0.449, 'duration': 0.41998, 'start': 16.37526},
#            {'confidence': 0.468, 'duration': 0.4196, 'start': 16.79524},
#            {'confidence': 0.491, 'duration': 0.41923, 'start': 17.21485},
#            {'confidence': 0.488, 'duration': 0.41886, 'start': 17.63408},
#            {'confidence': 0.46, 'duration': 0.41848, 'start': 18.05293},
#            {'confidence': 0.441, 'duration': 0.41829, 'start': 18.47141},
#            {'confidence': 0.442, 'duration': 0.41867, 'start': 18.88971},
#            {'confidence': 0.432, 'duration': 0.41923, 'start': 19.30838},
#            {'confidence': 0.432, 'duration': 0.41923, 'start': 19.72761},
#            {'confidence': 0.403, 'duration': 0.41922, 'start': 20.14684},
#            {'confidence': 0.432, 'duration': 0.41959, 'start': 20.56606},
#            {'confidence': 0.457, 'duration': 0.41996, 'start': 20.98566},
#            {'confidence': 0.441, 'duration': 0.42051, 'start': 21.40561},
#            {'confidence': 0.432, 'duration': 0.4205, 'start': 21.82612},
#            {'confidence': 0.457, 'duration': 0.41992, 'start': 22.24662},
#            {'confidence': 0.453, 'duration': 0.42047, 'start': 22.66654},
#            {'confidence': 0.437, 'duration': 0.42027, 'start': 23.08701},
#            {'confidence': 0.416, 'duration': 0.41877, 'start': 23.50728},
#            {'confidence': 0.451, 'duration': 0.41858, 'start': 23.92606},
#            {'confidence': 0.479, 'duration': 0.41951, 'start': 24.34463},
#            {'confidence': 0.459, 'duration': 0.42007, 'start': 24.76414},
#            {'confidence': 0.437, 'duration': 0.42044, 'start': 25.18421},
#            {'confidence': 0.441, 'duration': 0.42043, 'start': 25.60465},
#            {'confidence': 0.504, 'duration': 0.42061, 'start': 26.02509},
#            {'confidence': 0.554, 'duration': 0.42079, 'start': 26.4457},
#            {'confidence': 0.404, 'duration': 0.42059, 'start': 26.86649},
#            {'confidence': 0.276, 'duration': 0.41983, 'start': 27.28708},
#            {'confidence': 0.286, 'duration': 0.41945, 'start': 27.70691},
#            {'confidence': 0.19, 'duration': 0.41945, 'start': 28.12637},
#            {'confidence': 0.298, 'duration': 0.41907, 'start': 28.54582},
#            {'confidence': 0.433, 'duration': 0.41982, 'start': 28.96489},
#            {'confidence': 0.529, 'duration': 0.42113, 'start': 29.3847},
#            {'confidence': 0.554, 'duration': 0.42113, 'start': 29.80583},
#            {'confidence': 0.466, 'duration': 0.42019, 'start': 30.22696},
#            {'confidence': 0.399, 'duration': 0.4187, 'start': 30.64715},
#            {'confidence': 0.467, 'duration': 0.41814, 'start': 31.06585},
#            {'confidence': 0.59, 'duration': 0.41889, 'start': 31.48398},
#            {'confidence': 0.511, 'duration': 0.41908, 'start': 31.90287},
#            {'confidence': 0.471, 'duration': 0.4189, 'start': 32.32196},
#            {'confidence': 0.533, 'duration': 0.4189, 'start': 32.74085},
#            {'confidence': 0.576, 'duration': 0.41965, 'start': 33.15975},
#            {'confidence': 0.593, 'duration': 0.42078, 'start': 33.5794},
#            {'confidence': 0.643, 'duration': 0.42059, 'start': 34.00018},
#            {'confidence': 0.762, 'duration': 0.41984, 'start': 34.42077},
#            {'confidence': 0.785, 'duration': 0.41909, 'start': 34.84061},
#            {'confidence': 0.712, 'duration': 0.41891, 'start': 35.2597},
#            {'confidence': 0.733, 'duration': 0.4191, 'start': 35.67861},
#            {'confidence': 0.739, 'duration': 0.4191, 'start': 36.09771},
#            {'confidence': 0.738, 'duration': 0.41966, 'start': 36.5168},
#            {'confidence': 0.723, 'duration': 0.41985, 'start': 36.93646},
#            {'confidence': 0.727, 'duration': 0.41947, 'start': 37.35631},
#            {'confidence': 0.737, 'duration': 0.41928, 'start': 37.77578},
#            {'confidence': 0.72, 'duration': 0.41928, 'start': 38.19506},
#            {'confidence': 0.758, 'duration': 0.41928, 'start': 38.61434},
#            {'confidence': 0.765, 'duration': 0.41928, 'start': 39.03362},
#            {'confidence': 0.731, 'duration': 0.41927, 'start': 39.45289},
#            {'confidence': 0.634, 'duration': 0.42021, 'start': 39.87217},
#            {'confidence': 0.487, 'duration': 0.42096, 'start': 40.29238},
#            {'confidence': 0.395, 'duration': 0.4202, 'start': 40.71333},
#            {'confidence': 0.371, 'duration': 0.41908, 'start': 41.13354},
#            {'confidence': 0.364, 'duration': 0.41833, 'start': 41.55262},
#            {'confidence': 0.347, 'duration': 0.41832, 'start': 41.97094},
#            {'confidence': 0.315, 'duration': 0.41832, 'start': 42.38927},
#            {'confidence': 0.353, 'duration': 0.41663, 'start': 42.80759},
#            {'confidence': 0.383, 'duration': 0.41606, 'start': 43.22422},
#            {'confidence': 0.352, 'duration': 0.41812, 'start': 43.64028},
#            {'confidence': 0.365, 'duration': 0.41961, 'start': 44.0584},
#            {'confidence': 0.365, 'duration': 0.42017, 'start': 44.47801},
#            {'confidence': 0.359, 'duration': 0.42016, 'start': 44.89817},
#            {'confidence': 0.39, 'duration': 0.41959, 'start': 45.31833},
#            {'confidence': 0.378, 'duration': 0.42015, 'start': 45.73792},
#            {'confidence': 0.409, 'duration': 0.42089, 'start': 46.15807},
#            {'confidence': 0.391, 'duration': 0.42051, 'start': 46.57897},
#            {'confidence': 0.374, 'duration': 0.42089, 'start': 46.99948},
#            {'confidence': 0.38, 'duration': 0.42163, 'start': 47.42037},
#            {'confidence': 0.464, 'duration': 0.42069, 'start': 47.842},
#            {'confidence': 0.55, 'duration': 0.41938, 'start': 48.26269},
#            {'confidence': 0.548, 'duration': 0.41863, 'start': 48.68208},
#            {'confidence': 0.468, 'duration': 0.41844, 'start': 49.10071},
#            {'confidence': 0.431, 'duration': 0.41845, 'start': 49.51915},
#            {'confidence': 0.409, 'duration': 0.41788, 'start': 49.9376},
#            {'confidence': 0.4, 'duration': 0.41732, 'start': 50.35548},
#            {'confidence': 0.421, 'duration': 0.41826, 'start': 50.77281},
#            {'confidence': 0.455, 'duration': 0.42013, 'start': 51.19106},
#            {'confidence': 0.433, 'duration': 0.42069, 'start': 51.61119},
#            {'confidence': 0.439, 'duration': 0.42012, 'start': 52.03188},
#            {'confidence': 0.437, 'duration': 0.41993, 'start': 52.452},
#            {'confidence': 0.451, 'duration': 0.4203, 'start': 52.87193},
#            {'confidence': 0.432, 'duration': 0.42049, 'start': 53.29224},
#            {'confidence': 0.434, 'duration': 0.42105, 'start': 53.71273},
#            {'confidence': 0.439, 'duration': 0.42085, 'start': 54.13377},
#            {'confidence': 0.567, 'duration': 0.4201, 'start': 54.55463},
#            {'confidence': 0.56, 'duration': 0.41972, 'start': 54.97473},
#            {'confidence': 0.574, 'duration': 0.42009, 'start': 55.39445},
#            {'confidence': 0.461, 'duration': 0.41971, 'start': 55.81454},
#            {'confidence': 0.414, 'duration': 0.41933, 'start': 56.23425},
#            {'confidence': 0.351, 'duration': 0.41933, 'start': 56.65358},
#            {'confidence': 0.37, 'duration': 0.41876, 'start': 57.07291},
#            {'confidence': 0.373, 'duration': 0.4197, 'start': 57.49168},
#            {'confidence': 0.346, 'duration': 0.41951, 'start': 57.91138},
#            {'confidence': 0.344, 'duration': 0.4182, 'start': 58.33089},
#            {'confidence': 0.346, 'duration': 0.41895, 'start': 58.74909},
#            {'confidence': 0.342, 'duration': 0.4197, 'start': 59.16804},
#            {'confidence': 0.331, 'duration': 0.4182, 'start': 59.58774},
#            {'confidence': 0.346, 'duration': 0.4182, 'start': 60.00594},
#            {'confidence': 0.352, 'duration': 0.41932, 'start': 60.42414},
#            {'confidence': 0.335, 'duration': 0.42044, 'start': 60.84346},
#            {'confidence': 0.327, 'duration': 0.42062, 'start': 61.2639},
#            {'confidence': 0.297, 'duration': 0.4195, 'start': 61.68452},
#            {'confidence': 0.324, 'duration': 0.41912, 'start': 62.10402},
#            {'confidence': 0.333, 'duration': 0.41967, 'start': 62.52314},
#            {'confidence': 0.351, 'duration': 0.41986, 'start': 62.94282},
#            {'confidence': 0.378, 'duration': 0.41967, 'start': 63.36267},
#            {'confidence': 0.379, 'duration': 0.41947, 'start': 63.78234},
#            {'confidence': 0.382, 'duration': 0.41947, 'start': 64.20181},
#            {'confidence': 0.375, 'duration': 0.42002, 'start': 64.62128},
#            {'confidence': 0.355, 'duration': 0.4202, 'start': 65.0413},
#            {'confidence': 0.367, 'duration': 0.42057, 'start': 65.46151},
#            {'confidence': 0.365, 'duration': 0.41963, 'start': 65.88208},
#            {'confidence': 0.388, 'duration': 0.41888, 'start': 66.30171},
#            {'confidence': 0.399, 'duration': 0.42, 'start': 66.72059},
#            {'confidence': 0.374, 'duration': 0.42055, 'start': 67.14059},
#            {'confidence': 0.334, 'duration': 0.42017, 'start': 67.56115},
#            {'confidence': 0.432, 'duration': 0.41959, 'start': 67.98132},
#            {'confidence': 0.508, 'duration': 0.41883, 'start': 68.40091},
#            {'confidence': 0.49, 'duration': 0.41974, 'start': 68.81974},
#            {'confidence': 0.407, 'duration': 0.42009, 'start': 69.23948},
#            {'confidence': 0.367, 'duration': 0.41931, 'start': 69.65957},
#            {'confidence': 0.335, 'duration': 0.41966, 'start': 70.07889},
#            {'confidence': 0.309, 'duration': 0.41944, 'start': 70.49854},
#            {'confidence': 0.299, 'duration': 0.41904, 'start': 70.91798},
#            {'confidence': 0.3, 'duration': 0.41994, 'start': 71.33702},
#            {'confidence': 0.296, 'duration': 0.42048, 'start': 71.75696},
#            {'confidence': 0.318, 'duration': 0.42046, 'start': 72.17744},
#            {'confidence': 0.318, 'duration': 0.41969, 'start': 72.59789},
#            {'confidence': 0.336, 'duration': 0.41892, 'start': 73.01758},
#            {'confidence': 0.356, 'duration': 0.41929, 'start': 73.43651},
#            {'confidence': 0.341, 'duration': 0.41965, 'start': 73.85579},
#            {'confidence': 0.318, 'duration': 0.41964, 'start': 74.27544},
#            {'confidence': 0.32, 'duration': 0.41944, 'start': 74.69508},
#            {'confidence': 0.276, 'duration': 0.41905, 'start': 75.11452},
#            {'confidence': 0.26, 'duration': 0.41866, 'start': 75.53357},
#            {'confidence': 0.257, 'duration': 0.41846, 'start': 75.95224},
#            {'confidence': 0.289, 'duration': 0.41862, 'start': 76.3707},
#            {'confidence': 0.292, 'duration': 0.41953, 'start': 76.78932},
#            {'confidence': 0.305, 'duration': 0.41987, 'start': 77.20885},
#            {'confidence': 0.295, 'duration': 0.41948, 'start': 77.62872},
#            {'confidence': 0.306, 'duration': 0.41946, 'start': 78.0482},
#            {'confidence': 0.31, 'duration': 0.42037, 'start': 78.46765},
#            {'confidence': 0.319, 'duration': 0.42092, 'start': 78.88803},
#            {'confidence': 0.3, 'duration': 0.42035, 'start': 79.30895},
#            {'confidence': 0.336, 'duration': 0.4196, 'start': 79.7293},
#            {'confidence': 0.357, 'duration': 0.41942, 'start': 80.1489},
#            {'confidence': 0.338, 'duration': 0.41998, 'start': 80.56832},
#            {'confidence': 0.335, 'duration': 0.42054, 'start': 80.9883},
#            {'confidence': 0.309, 'duration': 0.42054, 'start': 81.40884},
#            {'confidence': 0.354, 'duration': 0.42017, 'start': 81.82939},
#            {'confidence': 0.259, 'duration': 0.42016, 'start': 82.24955},
#            {'confidence': 0.22, 'duration': 0.42016, 'start': 82.66972},
#            {'confidence': 0.237, 'duration': 0.41978, 'start': 83.08987},
#            {'confidence': 0.216, 'duration': 0.4194, 'start': 83.50965},
#            {'confidence': 0.248, 'duration': 0.41903, 'start': 83.92905},
#            {'confidence': 0.257, 'duration': 0.41903, 'start': 84.34808},
#            {'confidence': 0.264, 'duration': 0.41978, 'start': 84.7671},
#            {'confidence': 0.228, 'duration': 0.42053, 'start': 85.18688},
#            {'confidence': 0.255, 'duration': 0.42073, 'start': 85.60742},
#            {'confidence': 0.277, 'duration': 0.42055, 'start': 86.02815},
#            {'confidence': 0.325, 'duration': 0.42037, 'start': 86.4487},
#            {'confidence': 0.339, 'duration': 0.42037, 'start': 86.86907},
#            {'confidence': 0.429, 'duration': 0.42056, 'start': 87.28944},
#            {'confidence': 0.574, 'duration': 0.41981, 'start': 87.70999},
#            {'confidence': 0.661, 'duration': 0.41944, 'start': 88.1298},
#            {'confidence': 0.669, 'duration': 0.41962, 'start': 88.54924},
#            {'confidence': 0.608, 'duration': 0.41961, 'start': 88.96886},
#            {'confidence': 0.706, 'duration': 0.41979, 'start': 89.38847},
#            {'confidence': 0.728, 'duration': 0.41997, 'start': 89.80827},
#            {'confidence': 0.75, 'duration': 0.41996, 'start': 90.22824},
#            {'confidence': 0.68, 'duration': 0.42014, 'start': 90.6482},
#            {'confidence': 0.617, 'duration': 0.41956, 'start': 91.06834},
#            {'confidence': 0.612, 'duration': 0.41917, 'start': 91.4879},
#            {'confidence': 0.565, 'duration': 0.41915, 'start': 91.90707},
#            {'confidence': 0.562, 'duration': 0.41858, 'start': 92.32623},
#            {'confidence': 0.677, 'duration': 0.41874, 'start': 92.7448},
#            {'confidence': 0.706, 'duration': 0.41872, 'start': 93.16354},
#            {'confidence': 0.696, 'duration': 0.4187, 'start': 93.58227},
#            {'confidence': 0.602, 'duration': 0.41942, 'start': 94.00097},
#            {'confidence': 0.543, 'duration': 0.41959, 'start': 94.42039},
#            {'confidence': 0.541, 'duration': 0.41993, 'start': 94.83998},
#            {'confidence': 0.559, 'duration': 0.42084, 'start': 95.25991},
#            {'confidence': 0.48, 'duration': 0.4197, 'start': 95.68075},
#            {'confidence': 0.587, 'duration': 0.41893, 'start': 96.10045},
#            {'confidence': 0.595, 'duration': 0.42003, 'start': 96.51938},
#            {'confidence': 0.599, 'duration': 0.42076, 'start': 96.93941},
#            {'confidence': 0.504, 'duration': 0.42093, 'start': 97.36017},
#            {'confidence': 0.475, 'duration': 0.42054, 'start': 97.7811},
#            {'confidence': 0.498, 'duration': 0.41995, 'start': 98.20163},
#            {'confidence': 0.451, 'duration': 0.41993, 'start': 98.62159},
#            {'confidence': 0.471, 'duration': 0.41935, 'start': 99.04152},
#            {'confidence': 0.542, 'duration': 0.4184, 'start': 99.46087},
#            {'confidence': 0.544, 'duration': 0.41819, 'start': 99.87927},
#            {'confidence': 0.524, 'duration': 0.41799, 'start': 100.29746},
#            {'confidence': 0.455, 'duration': 0.41853, 'start': 100.71545},
#            {'confidence': 0.476, 'duration': 0.41889, 'start': 101.13397},
#            {'confidence': 0.533, 'duration': 0.41944, 'start': 101.55286},
#            {'confidence': 0.514, 'duration': 0.42073, 'start': 101.9723},
#            {'confidence': 0.433, 'duration': 0.42072, 'start': 102.39303},
#            {'confidence': 0.483, 'duration': 0.41997, 'start': 102.81376},
#            {'confidence': 0.52, 'duration': 0.42015, 'start': 103.23372},
#            {'confidence': 0.529, 'duration': 0.4207, 'start': 103.65387},
#            {'confidence': 0.453, 'duration': 0.42032, 'start': 104.07457},
#            {'confidence': 0.415, 'duration': 0.41939, 'start': 104.4949},
#            {'confidence': 0.428, 'duration': 0.41864, 'start': 104.91428},
#            {'confidence': 0.371, 'duration': 0.41827, 'start': 105.33292},
#            {'confidence': 0.391, 'duration': 0.41846, 'start': 105.75119},
#            {'confidence': 0.385, 'duration': 0.41866, 'start': 106.16965},
#            {'confidence': 0.359, 'duration': 0.41793, 'start': 106.58831},
#            {'confidence': 0.348, 'duration': 0.41814, 'start': 107.00623},
#            {'confidence': 0.351, 'duration': 0.42004, 'start': 107.42437},
#            {'confidence': 0.293, 'duration': 0.42138, 'start': 107.84441},
#            {'confidence': 0.318, 'duration': 0.4218, 'start': 108.2658},
#            {'confidence': 0.299, 'duration': 0.42203, 'start': 108.68759},
#            {'confidence': 0.309, 'duration': 0.42133, 'start': 109.10962},
#            {'confidence': 0.354, 'duration': 0.42064, 'start': 109.53096},
#            {'confidence': 0.381, 'duration': 0.42105, 'start': 109.95159},
#            {'confidence': 0.451, 'duration': 0.42109, 'start': 110.37264},
#            {'confidence': 0.452, 'duration': 0.4204, 'start': 110.79373},
#            {'confidence': 0.531, 'duration': 0.4197, 'start': 111.21413},
#            {'confidence': 0.522, 'duration': 0.41955, 'start': 111.63382},
#            {'confidence': 0.372, 'duration': 0.42072, 'start': 112.05338},
#            {'confidence': 0.385, 'duration': 0.42094, 'start': 112.4741},
#            {'confidence': 0.475, 'duration': 0.41986, 'start': 112.89504},
#            {'confidence': 0.492, 'duration': 0.41933, 'start': 113.31489},
#            {'confidence': 0.516, 'duration': 0.41881, 'start': 113.73423},
#            {'confidence': 0.484, 'duration': 0.41846, 'start': 114.15303},
#            {'confidence': 0.505, 'duration': 0.41793, 'start': 114.5715},
#            {'confidence': 0.497, 'duration': 0.41703, 'start': 114.98943},
#            {'confidence': 0.408, 'duration': 0.41762, 'start': 115.40646},
#            {'confidence': 0.472, 'duration': 0.41821, 'start': 115.82408},
#            {'confidence': 0.574, 'duration': 0.41767, 'start': 116.24229},
#            {'confidence': 0.628, 'duration': 0.41826, 'start': 116.65997},
#            {'confidence': 0.674, 'duration': 0.41884, 'start': 117.07822},
#            {'confidence': 0.681, 'duration': 0.41886, 'start': 117.49707},
#            {'confidence': 0.704, 'duration': 0.41907, 'start': 117.91593},
#            {'confidence': 0.726, 'duration': 0.4189, 'start': 118.335},
#            {'confidence': 0.633, 'duration': 0.41929, 'start': 118.75389},
#            {'confidence': 0.649, 'duration': 0.4195, 'start': 119.17319},
#            {'confidence': 0.665, 'duration': 0.41934, 'start': 119.59269},
#            {'confidence': 0.652, 'duration': 0.41992, 'start': 120.01202},
#            {'confidence': 0.641, 'duration': 0.41975, 'start': 120.43194},
#            {'confidence': 0.668, 'duration': 0.4194, 'start': 120.85169},
#            {'confidence': 0.663, 'duration': 0.41941, 'start': 121.27108},
#            {'confidence': 0.652, 'duration': 0.41961, 'start': 121.6905},
#            {'confidence': 0.598, 'duration': 0.41963, 'start': 122.11011},
#            {'confidence': 0.518, 'duration': 0.41889, 'start': 122.52974},
#            {'confidence': 0.42, 'duration': 0.41872, 'start': 122.94863},
#            {'confidence': 0.475, 'duration': 0.41929, 'start': 123.36735},
#            {'confidence': 0.535, 'duration': 0.4193, 'start': 123.78664},
#            {'confidence': 0.553, 'duration': 0.41875, 'start': 124.20594},
#            {'confidence': 0.553, 'duration': 0.41876, 'start': 124.62469},
#            {'confidence': 0.54, 'duration': 0.4199, 'start': 125.04346},
#            {'confidence': 0.513, 'duration': 0.42066, 'start': 125.46336},
#            {'confidence': 0.5, 'duration': 0.4201, 'start': 125.88402},
#            {'confidence': 0.474, 'duration': 0.41992, 'start': 126.30412},
#            {'confidence': 0.448, 'duration': 0.41993, 'start': 126.72405},
#            {'confidence': 0.538, 'duration': 0.42013, 'start': 127.14398},
#            {'confidence': 0.554, 'duration': 0.41977, 'start': 127.56411},
#            {'confidence': 0.523, 'duration': 0.41884, 'start': 127.98388},
#            {'confidence': 0.457, 'duration': 0.41885, 'start': 128.40273},
#            {'confidence': 0.433, 'duration': 0.41943, 'start': 128.82158},
#            {'confidence': 0.414, 'duration': 0.41963, 'start': 129.241},
#            {'confidence': 0.522, 'duration': 0.42001, 'start': 129.66063},
#            {'confidence': 0.542, 'duration': 0.41965, 'start': 130.08064},
#            {'confidence': 0.608, 'duration': 0.41948, 'start': 130.50029},
#            {'confidence': 0.611, 'duration': 0.42006, 'start': 130.91977},
#            {'confidence': 0.565, 'duration': 0.41989, 'start': 131.33983},
#            {'confidence': 0.597, 'duration': 0.41972, 'start': 131.75972},
#            {'confidence': 0.631, 'duration': 0.4192, 'start': 132.17944},
#            {'confidence': 0.57, 'duration': 0.41928, 'start': 132.59863},
#            {'confidence': 0.521, 'duration': 0.42106, 'start': 133.01791},
#            {'confidence': 0.481, 'duration': 0.42115, 'start': 133.43898},
#            {'confidence': 0.382, 'duration': 0.42144, 'start': 133.86012},
#            {'confidence': 0.25, 'duration': 0.42041, 'start': 134.28157},
#            {'confidence': 0.179, 'duration': 0.41844, 'start': 134.70198},
#            {'confidence': 0.131, 'duration': 0.42019, 'start': 135.1204},
#            {'confidence': 0.053, 'duration': 0.42003, 'start': 135.5406},
#            {'confidence': 0.144, 'duration': 0.41779, 'start': 135.96065},
#            {'confidence': 0.319, 'duration': 0.41761, 'start': 136.37843},
#            {'confidence': 0.541, 'duration': 0.41723, 'start': 136.79604},
#            {'confidence': 0.686, 'duration': 0.41892, 'start': 137.21326},
#            {'confidence': 0.711, 'duration': 0.42117, 'start': 137.63219},
#            {'confidence': 0.687, 'duration': 0.41967, 'start': 138.05334},
#            {'confidence': 0.485, 'duration': 0.41893, 'start': 138.47302},
#            {'confidence': 0.26, 'duration': 0.41911, 'start': 138.89195},
#            {'confidence': 0.297, 'duration': 0.41949, 'start': 139.31107},
#            {'confidence': 0.338, 'duration': 0.4193, 'start': 139.73056},
#            {'confidence': 0.363, 'duration': 0.41856, 'start': 140.14986},
#            {'confidence': 0.389, 'duration': 0.41799, 'start': 140.56842},
#            {'confidence': 0.434, 'duration': 0.41781, 'start': 140.9864},
#            {'confidence': 0.48, 'duration': 0.41856, 'start': 141.40422},
#            {'confidence': 0.498, 'duration': 0.41931, 'start': 141.82278},
#            {'confidence': 0.383, 'duration': 0.41874, 'start': 142.24208},
#            {'confidence': 0.399, 'duration': 0.41781, 'start': 142.66083},
#            {'confidence': 0.407, 'duration': 0.41837, 'start': 143.07864},
#            {'confidence': 0.376, 'duration': 0.42006, 'start': 143.49701},
#            {'confidence': 0.399, 'duration': 0.41987, 'start': 143.91705},
#            {'confidence': 0.436, 'duration': 0.41875, 'start': 144.33693},
#            {'confidence': 0.483, 'duration': 0.41949, 'start': 144.75568},
#            {'confidence': 0.528, 'duration': 0.42024, 'start': 145.17517},
#            {'confidence': 0.415, 'duration': 0.4208, 'start': 145.59541},
#            {'confidence': 0.388, 'duration': 0.42024, 'start': 146.01622},
#            {'confidence': 0.387, 'duration': 0.41856, 'start': 146.43646},
#            {'confidence': 0.391, 'duration': 0.41931, 'start': 146.85503},
#            {'confidence': 0.402, 'duration': 0.42024, 'start': 147.27432},
#            {'confidence': 0.447, 'duration': 0.41931, 'start': 147.69456},
#            {'confidence': 0.483, 'duration': 0.41856, 'start': 148.11388},
#            {'confidence': 0.484, 'duration': 0.41894, 'start': 148.53244},
#            {'confidence': 0.34, 'duration': 0.41969, 'start': 148.95139},
#            {'confidence': 0.352, 'duration': 0.42006, 'start': 149.37106},
#            {'confidence': 0.399, 'duration': 0.41988, 'start': 149.79112},
#            {'confidence': 0.437, 'duration': 0.42044, 'start': 150.21101},
#            {'confidence': 0.448, 'duration': 0.42176, 'start': 150.63145},
#            {'confidence': 0.466, 'duration': 0.42214, 'start': 151.05322},
#            {'confidence': 0.413, 'duration': 0.42084, 'start': 151.47536},
#            {'confidence': 0.303, 'duration': 0.42029, 'start': 151.8962},
#            {'confidence': 0.352, 'duration': 0.42011, 'start': 152.31648},
#            {'confidence': 0.291, 'duration': 0.41993, 'start': 152.73659},
#            {'confidence': 0.336, 'duration': 0.41994, 'start': 153.15652},
#            {'confidence': 0.399, 'duration': 0.41827, 'start': 153.57648},
#            {'confidence': 0.393, 'duration': 0.41753, 'start': 153.99474},
#            {'confidence': 0.424, 'duration': 0.41885, 'start': 154.41226},
#            {'confidence': 0.431, 'duration': 0.41979, 'start': 154.83112},
#            {'confidence': 0.361, 'duration': 0.4198, 'start': 155.2509},
#            {'confidence': 0.347, 'duration': 0.41924, 'start': 155.6707},
#            {'confidence': 0.358, 'duration': 0.41887, 'start': 156.08994},
#            {'confidence': 0.385, 'duration': 0.41981, 'start': 156.5088},
#            {'confidence': 0.382, 'duration': 0.41999, 'start': 156.9286},
#            {'confidence': 0.335, 'duration': 0.41887, 'start': 157.3486},
#            {'confidence': 0.337, 'duration': 0.41812, 'start': 157.76747},
#            {'confidence': 0.36, 'duration': 0.41887, 'start': 158.1856},
#            {'confidence': 0.289, 'duration': 0.41924, 'start': 158.60445},
#            {'confidence': 0.328, 'duration': 0.41811, 'start': 159.0237},
#            {'confidence': 0.352, 'duration': 0.41886, 'start': 159.4418},
#            {'confidence': 0.333, 'duration': 0.42017, 'start': 159.86066},
#            {'confidence': 0.307, 'duration': 0.42073, 'start': 160.28082},
#            {'confidence': 0.268, 'duration': 0.42036, 'start': 160.70155},
#            {'confidence': 0.287, 'duration': 0.41942, 'start': 161.12192},
#            {'confidence': 0.34, 'duration': 0.41998, 'start': 161.54134},
#            {'confidence': 0.355, 'duration': 0.42017, 'start': 161.96132},
#            {'confidence': 0.331, 'duration': 0.41867, 'start': 162.38148},
#            {'confidence': 0.353, 'duration': 0.41829, 'start': 162.80016},
#            {'confidence': 0.333, 'duration': 0.41941, 'start': 163.21844},
#            {'confidence': 0.337, 'duration': 0.42109, 'start': 163.63786},
#            {'confidence': 0.292, 'duration': 0.42351, 'start': 164.05894},
#            {'confidence': 0.248, 'duration': 0.425, 'start': 164.48245},
#            {'confidence': 0.271, 'duration': 0.42444, 'start': 164.90747},
#            {'confidence': 0.158, 'duration': 0.42312, 'start': 165.3319},
#            {'confidence': 0.072, 'duration': 0.41993, 'start': 165.75502},
#            {'confidence': 0.099, 'duration': 0.41898, 'start': 166.17496},
#            {'confidence': 0.128, 'duration': 0.42066, 'start': 166.59393},
#            {'confidence': 0.148, 'duration': 0.42215, 'start': 167.01459},
#            {'confidence': 0.143, 'duration': 0.42289, 'start': 167.43674},
#            {'confidence': 0.046, 'duration': 0.42325, 'start': 167.85962},
#            {'confidence': 0.068, 'duration': 0.42193, 'start': 168.28287},
#            {'confidence': 0.0, 'duration': 0.41987, 'start': 168.7048},
#            {'confidence': 0.005, 'duration': 0.41724, 'start': 169.12466},
#            {'confidence': 0.032, 'duration': 0.41517, 'start': 169.54192},
#            {'confidence': 0.066, 'duration': 0.41255, 'start': 169.95708},
#            {'confidence': 0.146, 'duration': 0.40955, 'start': 170.36963},
#            {'confidence': 0.203, 'duration': 0.41029, 'start': 170.77917},
#            {'confidence': 0.182, 'duration': 0.41234, 'start': 171.18945},
#            {'confidence': 0.185, 'duration': 0.41758, 'start': 171.6018},
#            {'confidence': 0.236, 'duration': 0.42188, 'start': 172.01938},
#            {'confidence': 0.328, 'duration': 0.42056, 'start': 172.44125},
#            {'confidence': 0.321, 'duration': 0.41755, 'start': 172.86182},
#            {'confidence': 0.214, 'duration': 0.41624, 'start': 173.27937},
#            {'confidence': 0.151, 'duration': 0.41511, 'start': 173.6956},
#            {'confidence': 0.232, 'duration': 0.4151, 'start': 174.1107},
#            {'confidence': 0.264, 'duration': 0.41491, 'start': 174.52582},
#            {'confidence': 0.4, 'duration': 0.41136, 'start': 174.94073},
#            {'confidence': 0.453, 'duration': 0.4093, 'start': 175.3521},
#            {'confidence': 0.393, 'duration': 0.41418, 'start': 175.76138},
#            {'confidence': 0.353, 'duration': 0.41737, 'start': 176.17557},
#            {'confidence': 0.33, 'duration': 0.41738, 'start': 176.59294},
#            {'confidence': 0.303, 'duration': 0.41721, 'start': 177.01031},
#            {'confidence': 0.255, 'duration': 0.41704, 'start': 177.42754},
#            {'confidence': 0.184, 'duration': 0.41987, 'start': 177.84457},
#            {'confidence': 0.151, 'duration': 0.42157, 'start': 178.26443},
#            {'confidence': 0.119, 'duration': 0.41896, 'start': 178.686},
#            {'confidence': 0.182, 'duration': 0.41878, 'start': 179.10497},
#            {'confidence': 0.305, 'duration': 0.42066, 'start': 179.52374},
#            {'confidence': 0.391, 'duration': 0.42327, 'start': 179.9444},
#            {'confidence': 0.467, 'duration': 0.42382, 'start': 180.36768},
#            {'confidence': 0.326, 'duration': 0.42268, 'start': 180.79149},
#            {'confidence': 0.265, 'duration': 0.42623, 'start': 181.21419},
#            {'confidence': 0.244, 'duration': 0.42902, 'start': 181.6404},
#            {'confidence': 0.232, 'duration': 0.42807, 'start': 182.06943},
#            {'confidence': 0.163, 'duration': 0.42727, 'start': 182.4975},
#            {'confidence': 0.093, 'duration': 0.43193, 'start': 182.92476},
#            {'confidence': 0.097, 'duration': 0.42715, 'start': 183.35669},
#            {'confidence': 0.061, 'duration': 0.42715, 'start': 183.78384}],
#  'meta': {'analysis_time': 8.7455,
#           'analyzer_version': '4.0.0',
#           'detailed_status': 'OK',
#           'input_process': 'libvorbisfile L+R 44100->22050',
#           'platform': 'Linux',
#           'status_code': 0,
#           'timestamp': 1444768544},
#  'sections': [{'confidence': 1.0,
#                'duration': 7.56674,
#                'key': 9,
#                'key_confidence': 0.438,
#                'loudness': -15.88,
#                'mode': 0,
#                'mode_confidence': 0.509,
#                'start': 0.0,
#                'tempo': 143.007,
#                'tempo_confidence': 0.484,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.648,
#                'duration': 19.29975,
#                'key': 4,
#                'key_confidence': 0.517,
#                'loudness': -9.807,
#                'mode': 0,
#                'mode_confidence': 0.462,
#                'start': 7.56674,
#                'tempo': 143.044,
#                'tempo_confidence': 0.498,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.694,
#                'duration': 12.16713,
#                'key': 1,
#                'key_confidence': 0.0,
#                'loudness': -10.016,
#                'mode': 1,
#                'mode_confidence': 0.0,
#                'start': 26.86649,
#                'tempo': 143.093,
#                'tempo_confidence': 0.564,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.606,
#                'duration': 47.41508,
#                'key': 2,
#                'key_confidence': 0.064,
#                'loudness': -9.683,
#                'mode': 1,
#                'mode_confidence': 0.184,
#                'start': 39.03362,
#                'tempo': 142.932,
#                'tempo_confidence': 0.372,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 1.0,
#                'duration': 29.37538,
#                'key': 2,
#                'key_confidence': 0.021,
#                'loudness': -19.41,
#                'mode': 1,
#                'mode_confidence': 0.489,
#                'start': 86.4487,
#                'tempo': 143.028,
#                'tempo_confidence': 0.499,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.568,
#                'duration': 20.13656,
#                'key': 2,
#                'key_confidence': 0.19,
#                'loudness': -12.874,
#                'mode': 1,
#                'mode_confidence': 0.471,
#                'start': 115.82408,
#                'tempo': 143.081,
#                'tempo_confidence': 0.529,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 0.364,
#                'duration': 33.16403,
#                'key': 4,
#                'key_confidence': 0.638,
#                'loudness': -9.94,
#                'mode': 0,
#                'mode_confidence': 0.491,
#                'start': 135.96065,
#                'tempo': 143.102,
#                'tempo_confidence': 0.354,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0},
#               {'confidence': 1.0,
#                'duration': 19.58721,
#                'key': 2,
#                'key_confidence': 0.252,
#                'loudness': -19.769,
#                'mode': 1,
#                'mode_confidence': 0.463,
#                'start': 169.12466,
#                'tempo': 143.436,
#                'tempo_confidence': 0.231,
#                'time_signature': 4,
#                'time_signature_confidence': 1.0}],
#  'segments': [{'confidence': 0.0,
#                'duration': 0.20726,
#                'loudness_end': 0.0,
#                'loudness_max': -18.031,
#                'loudness_max_time': 0.02426,
#                'loudness_start': -24.279,
#                'pitches': [0.004,
#                            0.005,
#                            0.01,
#                            0.15,
#                            1.0,
#                            0.131,
#                            0.009,
#                            0.003,
#                            0.008,
#                            0.002,
#                            0.002,
#                            0.015],
#                'start': 0.0,
#                'timbre': [39.821,
#                           28.025,
#                           -99.44,
#                           -42.135,
#                           58.998,
#                           -47.306,
#                           7.856,
#                           12.332,
#                           -19.522,
#                           13.344,
#                           -3.278,
#                           10.72]},
#               {'confidence': 0.214,
#                'duration': 0.21057,
#                'loudness_end': 0.0,
#                'loudness_max': -18.653,
#                'loudness_max_time': 0.00975,
#                'loudness_start': -22.173,
#                'pitches': [0.1,
#                            0.008,
#                            0.004,
#                            0.033,
#                            0.17,
#                            0.026,
#                            0.022,
#                            0.002,
#                            0.005,
#                            0.01,
#                            0.061,
#                            1.0],
#                'start': 0.20726,
#                'timbre': [37.934,
#                           -32.909,
#                           -77.862,
#                           -22.514,
#                           64.864,
#                           -70.292,
#                           -18.835,
#                           -1.362,
#                           -22.419,
#                           -13.821,
#                           -9.822,
#                           17.338]},
#               {'confidence': 0.941,
#                'duration': 0.19156,
#                'loudness_end': 0.0,
#                'loudness_max': -12.43,
#                'loudness_max_time': 0.00846,
#                'loudness_start': -26.067,
#                'pitches': [0.014,
#                            0.011,
#                            0.014,
#                            0.179,
#                            1.0,
#                            0.159,
#                            0.022,
#                            0.043,
#                            0.018,
#                            0.007,
#                            0.014,
#                            0.077],
#                'start': 0.41782,
#                'timbre': [42.528,
#                           67.994,
#                           -89.776,
#                           1.007,
#                           16.347,
#                           -71.097,
#                           -26.476,
#                           0.683,
#                           -25.044,
#                           8.956,
#                           -26.819,
#                           3.87]},
#               {'confidence': 0.335,
#                'duration': 0.2283,
#                'loudness_end': 0.0,
#                'loudness_max': -18.631,
#                'loudness_max_time': 0.0298,
#                'loudness_start': -23.126,
#                'pitches': [0.099,
#                            0.011,
# ...
#             {'confidence': 0.163, 'duration': 0.21364, 'start': 182.71114},
#             {'confidence': 0.093, 'duration': 0.21596, 'start': 182.92476},
#             {'confidence': 0.093, 'duration': 0.21596, 'start': 183.14073},
#             {'confidence': 0.097, 'duration': 0.21358, 'start': 183.35669},
#             {'confidence': 0.097, 'duration': 0.21358, 'start': 183.57027},
#             {'confidence': 0.061, 'duration': 0.21358, 'start': 183.78384},
#             {'confidence': 0.061, 'duration': 0.21358, 'start': 183.99742}],
#  'track': {'analysis_channels': 1,
#            'analysis_sample_rate': 22050,
#            'code_version': 3.15,
#            'codestring': 'eJxdm1mi5CoORLeSS2AUsP-NVZwAX-Pqj9eXwSRoVkgVPfcxVvRf-rVSctTZ5y-v8ou_lTrbtRZpXmszpV-OkvNIWX-l0n4l96y9a_yyvvnNWrS1ZZ3aWmJ1jFxb_uXZ47fmSnnMWX4lTa32taLltH6ljOLVyKlq2FY8qz3_SkzfouXVY_zKyuVccaT6q7nGff9a5vWA2vvndaPdz6sr7ve1HOk3V1napUs2aKEnzJpy0Wof-iHdtK-S169BjTJybj3r2w41tKrrlDp_HWqsocf21sqvQ43QZEkRGkb1e5umU_t1iDNzi8ilLP-GfnykVPOsvzA1Sp8jhX5S3-sJNVqZ5hzU4Akrz9V_I3Neg0NddBlQQ6uxmmZ-oxdxPo026xJnB9QQy1YMse03lr5YvaySmqg2TY1a21qr8peoIVqLc2LIb0KNNfWGlETJCTX0EyMPnTTX4n1zjh661IIYelwPfTV_-sSXmhKkvn4LYuhBs4nbSZ-JGBIDLcbMVX-mNiFHEYH0dIndOC8uEay3aPv7ygNyOuKidTFOY93tPHrqh3OGRGJr7ZE4Pxfoq1NmicI6RCojiXZtsT4yAttGDU1qbDKJdhAtIff6qkeT5Oq9GlcRr6xZdS_9kkQHudHvZ56vsd7ldZEnWIdYfL1q7vpeTG-sZykL962Qy-u6aIYFolefSzwtvLdOBELnl1pZb9DL66NPrbfS0t96QzFr2efXhvq3EMEluPqga2duc38vXSuSAPFE9BbVVymipC7YTbAFy2OxoYngY-UVEWI-bE6s6_-1SWMIttelK7IgEOxaDwi2CVAr69KWmwABwS4CxIp0r4_8fL_XBwS711Gbex2CXeszIZ61jzILDJplfy-GNbFe7IDgIo9kMkTQaYKJgWN2BHJKU35dbNLNY8meQjDWpYXojOS0yS5JvcrAUC7oxe-XrlM1jvncTwTReKX7fiVBr_f-JVUJ6CsAJXUM4p8AlGR6NSnPkkhrDL1g9-hNolaQcL0npSXyV41ra4fBumJHN7aEHgaXPPhMEiIFr3ywtoSmwNrJNkEwM7gvEbCUI2GHwaWgt1ImkUs7NEbC-L6ujqjU1HxBLazMuJzvJYPonuQ0HgHhfInxzeBSIdhFoJa2gD7rrZb0WYdgdRWdvjgJ1f7J2_SautfXFlDRUSokTwTBZBhR8KGX9Jp9P7mCQBQ79DKDa7bnGkdAN4PlMHCqchi1JugZEkmNeW9ip-wE7jSlIdsql1Zs4_Vb0t_JhoGEyPxL06RjGuunNe7SFx8guY09znPoe9vqZ6yrzr4vLNW2T5s8UIay6XpbGRGB4ByrBveXn8dAc53F_UWpLtGUL4ddVvsk9zTlVFPHEYlMsv_iRJX8i976dMB0jVGQ1nV7KZCGduBdolRE_Zrhvn5TPgnpEG1Rt9R1VFv6tQz3JbtzNh5bM9zX48Rb2a7feeLgrYUxZko-vsnN4CCldLpT8PQGt7VPt6vyJnLzsu8SKbgPk4eeBx8hacp6fhO3qoRUxJbOSnnlBxXNDLyMhEy_rECg4nusLnIFSRdokEM_KqLiemobf9zQLRSSpDQv7sj61fIZnwc-4xCjPuNmaXjHc4v74W4dNT_21AQeo9zqUvWurb4zBuyb5_4aB99Lb9NnPGa7xyulz37FC5_9MkvNbnnEMsUlZBbPQMMYT6IhhUayR8RZCnQsEPpdNLclxJlQcjZbxkDaSyhaEQc15r1yvhIv8URRW8KLKAwR-7FPLUMATYyQgDTiOjyCJEznKpj7EWf4hqNtbsrScwNN6AgixPySbBatSJBuC9IKX70kxQ7Pz3r_uKjGUz7r6_t9NQm3D65DYxF1k7ApuA7CG3xMWbp4z2yYmwd6qZgoYwIJt4_lqMYNLhMsyrV5-eDWoCk-YODUME6SsSILhw_QuvRPSpFlGteA5r1sny57hI9vvY1HxnSWxvjY1yc1nCkmXVo-FNKiEumYdIX5PzGqtcuk65Ufn0dMkrbPTQsOxjhB1fa5LZaVUKZHNkgsHwqupKRjSJtZHxCwSrRZ0E1lPhqRSSfK03kD-kk4Ez9UHMzrVrqcyA99xXXup0ymOzyb7c_lEP1Aro9ATNPvvf9Kj8va66t8XJbkeJTPenxcViN4vgRCxm5b8ONyu1zJE7RJ3DGXW2D_1qHX65K7qNgueSBpu-WhE9h_1vtsV0wmKn9iKoXIn5iql_KJqcSjv5gIF9HxcT9J8-j4NI3ndvESpK6Qw573sVmyqd1BsGOYaIOToJ8MsUJDBWWcPB4XLLeqsd6hnCRwI_7lnUUUrAJRtlKijBXveDEFsb0dgZPxxUfrXP13B2lydxqTRej3o1gBZanIs2Y42BCBoZgfEF1c0Lg_FkLRi0Q3UrotgOKK-BAsINC9Tqp9MTwOgR6GjrRzH5JGjJwUrD1BGlFqH6SYbxSuGCQ-HB9zfjg-ScFfC0CW-6QRA47P_phApwlKP0uyzZwKgIszhC2SGks7dBQU2RToyoOI-j8UWP0Tpney7M86yfiOshSyKmPCe79RViSc24nCRBF5xS2Sf-ukoG8UFhuf-IvCFOi0E6UpANP-jVBc6xDsDcPDkMV7vzBm8d4_DFq8Ji-MWrxhOFl8uggYxi1kTgv-SxFJzUcCR_P5Ri4Oh3FHpEXp4nBUJ6J_YXg43X1FJAxf7DAbRCJ2rPcXZocBjGMTKiHRSUSPhETD0vmCkNBwRdwXNIjx2AQwl3gSyU2gfhJRZaQ6UQl_emyetNnAhW2e1wkYoz0286yjckcAeG_M7XMeBhvbmFLnjMhpvBN3xQHD5xndkKURNWTCY2z5kucN_YbGZAmyBtYQqbKpxbICa53mmHmzVzr_CwMc1-vmNwsNYxyvhQqDHHqdg22tr78sVIwVt9adhYr6a6ybesMwx2E_aSgKf7N_GOd42U86cLOfXPPOwkZ-5GuzdxjneA3AyEe8_tZHvtPwYZzjfeAoOw19HjgenOM8cGCbrwcSoN0EhFu3_oz_cI5B4H3pv75ON_uHcQ67fEVf2PJk8RzSJiWgGpOFbv2WgGlsXGhKKtMAnDLOAbCHSwpH9MkuXgHrABs7aTsuHvr0um57NfrIH4YZ1rjWH1jjWTesYZc0dCeNu3OsGspxAUTiqJ-uEPBrwxr2ALrrbxAw3_wdptefy1eoM77r0Ovi_zgC9vDXMMfF_3nk62_dMIcczeyKVzV-YA7id50_ka-tvrN2nfRHL6vvMMzxqvf4gzme9Zi3Aoz_YI7p2P_l_9wwh5gBj1nvNoKysk26qDHyJS1VCqzAQuMDC8WGWaZhDgmH3plFr2lUA2BR6p0y-CaJnpREMZ9OzDItUIgdA7BOR5QNOLJDEVjXxDJU8u4wdGFwUtrEuOxgQwEf2K2Ih-iKUrFwRyLcBO8F7AweUSHKUtqMVrE-UDWZpqKQn_MgktKoJBv2k6ikrQhJGUJiTGiieEYujCEUW7pNGBDY6aByHf0cL5sAksaeuaV-zLiHIvO1Ohog_koCSKMVXCsom8ZBCJqBHbTe8wkBdF5V1EUoPg85ZDOY2DR-CdYdhejnZI7Xgl0LNFyqInfGOtCCRKAhlBqHCwPQXT5HT8Lrnv3Kz3_TUEkpCh5EIJ0X3U5Tgb8MlT-AZR1bIOrwAdjD0osHkZzGcHAZQurQZMDAPcYeyNpUJ5uA-rrqHM2BZJbUdng5NxYjFslO-oNpeFQbdDSPQRBBeRWlAG_PWZyeFvkzAB5NdKenoloHcdHESPvOg680Xg9q3xN3XkgyH1SeJzkwXLM_UCqpMRCGqNSVKyF1BnD2mNhuGsARlSr0REYS-auORdyIuozoUGFoqLXGfruSY8UsJEpGcDLSrRC4akwso-NJsbMOMiKQgdQUpZE3WpDkM6e3bwgn4_OAxJchHEgi_ikkRwEI8vUgJBX-pK1GPEgpvqHnU8cgViObSqfMEUZvxk7oZSQCikimCVEtBoMHGPQ5B0 ...
#            'duration': 188.71188,
#            'echoprint_version': 4.12,
#            'echoprintstring': 'eJzlnQuOBDeSZK8U_JPH4ff-R9hnnhqVJCCYM1vQNjALNVzqysoIftzNzUgn63keN56L8etm4nMzpdxMbTfTxs0sfzM7XYwL52aSu5m8bqZfzQ4X4596M6HczJkXE3y4mdRvpo6b2TcTQ7yZ3G6mrJuxx7-ZFNbNpHoz9dzMCReTn3Mzevy76f1iSn9uZvibOeNiaowX09y5mZRv5tSL6cHdTK43U-fNzHAzK93M6RczUroZBcS7EWa9mun2zZR2M23dzPQXs9y6mX5uZrqb2flijuDw3azxbtwD0F5MyzdzzsW4HG-mz4vxadxMvZmgx7-b-tzMuJoVb-bki4nq1rtZ9WZ2v5kzLyYBlhfT3c3o8a8mP_tmgr-Zsm_mxIspesC7ifFmgNKLKeNm2rmZMS6mFnczvd4MUPpuWto309LN9HIzp12MMOvdDGjWxcR5M2ndTPU3o4a_mqmXvxufb6a6i1kCvB-zxSK_6IAcb6acm-nxZta4GBfrzejx76b1m9nrYrxPNxPazYx0M7NcjPjPxaR2M93fzFkXE72_GWD9Yq58PNrj38zvGPe-Ge9uRtT51QiaLyaVm7mz9RlvZpWLqc-6mXo1gP7F6OXvZteLaXr5uxnuYvozb0Yj9m6uOmA842aiv5lcbkYU9tXMUm9G5PjVfOHjesC7afNi9igXc_y-GWH0u0nhZupzM7O9G6fEcjF93czJF-N8uBkSy8XUdjOrX4x3V5PcxYQQbybPm_miIdbNbH8xMZ6baf1mZrqZ7S4mPelmWrmZ3i8mu3IzIsevpjzxZoq_mRpvZq6LqUiYi_H1Zmq4mSvTb0-4GZHjd6PHv5sr0--SCu9mtIsZ4WpavJl9LmY5fzPwiosR4P3FbKPd_maMsr-aNG5G4Pturmzd6eXvRo9_N1_YuruZ69q619L9u8nzZq583APcF7PnxXzh8rHczJ3pr5v5wuXv6_K_WHn_wvSzu5n_0Mp7ce5m7mx9t4upWgZ_N9rmeDdl3MzKN_Mbth7TzUgqvJquxep3E8PNtH0z9zX9XS5mPPNmUryZ-6q9pMKrWUiYi6lXc-fy5Wq0xflqjpLDu5nPzdzX5Z92M1oGfzd738x91d7PmynnYvxTbkZi4N2IxLybfDMh7JsROX43s97MHhcTSR0X066GZHgxV7YetQz-alJMN3Pl8l_Yum83M-PFfOHybd3MfW39N2w9nZs57mJa6DdzZ-ujX0zXcvS78eVmtAz-bua4mC9cPo6buTP9tS7mvvK-crqZVf5qtlax_0Wm_5t1-VlvRovkr-YL0-_hYnxIN3Pn8r9Yeb8z_SDq_G5UsfRu7uvyI17MFy5_Z-v3Vfs7W3f1Zv69VXutv78bQP9i7lU09zV9Edx3c62xqdptfzcqWnk3WgZ_N1em37QM_m6uK-_NxMCrUcHLq_nC5VVa8m6uFThf-Hi7ml5u5r5qrwX2dyNS_m60g_xutNL9au5r-l_Yeuw3c195v1fg3NflQ76ZO9O_V-_sq7nrgHA1Iqmvxrt0M6JH7-bK9L3KQ15NKOlmRLvfzW9W7SVg3s19TX_2m7HHv5kv6_L7uZishf13c2X65ck30-rNXLl8WediqqTCu7kz_TuXv7P1e52MlsHfzZwX00Ws3819Xf7K5b_U57h4MyppeTc938x9TX-Xi9la2H83I__NzH-X6f9iTf8Rtr8aB6xfzG9W_H-jAwDQi7kz_fuq_Z3p39fl87iZ39TLx3wzv9EB92r67m7mN0w_hJu56oCiDZR386XGJt_MfU3_zuXvVTS_WbXXjtG7-QXT_1KBo9L2V_OlxkbL_u9Gxevv5rryPla8mC9cfoWLWdHdzG8qcHQw6d2ccjEntpsR0L4bHaZ6NzemD6_O78bpANjFaIH91bin3ozKYd5NDxejM00XE_vN3Fft09V0fzMj3szMFxNV-P5uUr2ZdjUj3Iy9_NXc63P0-FfzGy6fa7qZMS_mS42NRMi7uVfg_GbV_lov_ysdcGX6X9bl70xfcv3d3Nf0f8P087mZ65o-A3IzX9b0r2a1v5mz_1eu6asg4t38izrguZn7qv2drUsqvJvfsPVf8PFf1cnc2bo9_tX8hsur8P3djHAxX6rpr1z-y8r7lwqc_3su_6WKpqSLkU9fzL3m_UudzC9W3vXyd3Ovl9dR03dzX3mXVHg3WvZ_NznfzH3l_V6fo-L1d3PXAV9OxqaL-TdrbG5r685fzb2K5l4nI7rwbsrN3BeewmcJ_c18YdznYqKrN-PHzcR8M9ndzJ2tf-Hj15X3e728Xv5urvXyX1btw7yZL1z-Xmu_b-bK5f_Fevk7W7_Xy9_rc37D5e_r8iLH7-bO1v9TNTYCrVezAdq_mlX-f-Tj_Wb-vXV5LUm9m_vK-331_F5Fc2frovvv5t-rovnfx-Xv52ZVnv5u7lz-frr1NydUS7wZUedX82V9_M7l73z8Xrd-5-NXxv0rTn2vdTHK_maWPzdz59RXXrxOu5hvtS77Zr6sgJd3842P3-tkeryZ-_nVL7Uu9WK8Uv67qeViQh83c61IiU--Gd9v5l6RUsLN_GYVW017N6Kw7-Zet37nxZI376a3m7mz5pZvRoT-1fynTpl-4dQiuO_mvj5uD3gz93OkXST11fyLvNiFm7mz5p5uBgp2MWdfzJ75YrQR-VdT3b_Kx_-1SphvfPx6MvbOuEX3X80Xxv3v1brc18evfFz75Rfzr_HxL4z7N6z5zot1-O7d1H0xX1izrm95N_fbH39zfjWum_nFfTJfbo4sN_OFj98r06_VLF2FJ6_mS63LvZrlN2xd8fJu7lz-S61LvxmV1L8bUed384XL14v5Uq_ym5sjfbyZ--r5_baZ39St32-bua68u-UuRsnhYu5167VeTNBli6_mC9O_r49_WQE_N3Pn8ne2rgXndzP3xfyqmqX4i_nC1r_UnoebuXP5-60vv2Hc99sf73Xr18r0ZjeIvJkvK-D_KS7_K7Z-Mzu4v5n5HD98ijh7Q1Ov2OLoY-fTWiq5LVdD3fZpnyEv-7Tn7qN92o5_5oDnDPs08Z0l3l9GL9Xbk08uu4-1z1-eXMhQZa0cvT151_Lss1MCQ7Y7EV04aiSpp7CPb-60w9M9U937On4eslSaxc-ZBs9Ns--Tehyr1ExrnfcZuuBD6IemVxfXfhpEbZ4aj8991mptKXxh-7EjQVNWTXwpev5j1ZJntS70Wmsetfq0_OZzOuTqgLm1fVxdHvfMe9WYSUJlzsBvjSdMHSuMM8TaXYfY8D8fVzirjRBSWjG2pG0SxiXvOdtcp-t8-AwBTAqHr0PS-lk9lBNj7L4tXszX41lrJI-k25OWpNlGjiT81Bv_9dTgRtpt-prOHttvXujL2CP73PpA6TOhZS9m0z9but_RmlL4z7Lr2SvqWumQcmoNAT5zSmHMyiz4ji6Ia6w69yiROUz8QgcWNN2ZZyffcYEzcKt66KpzZ4y-20k2qweF13l7Hn6MykS2hEu4lTIeMQOzsZtfuhq1xEJfTpmMcOi52OV63buyCxM6s2eSUsuzh2lTFoLOXLSd3dxrefRJbf4gGFauuM8KMfpDT0j2mWFymie8yQfX_YnPCbiFi4Hh5Rs4XUQf7T173Cn0Olzp6bjFIMbZfZ0l1Lwe5rSNwXzH45hkKf9nMoYt5kpg7Cqno6c4Au8vc-f6rHR6cm1YBVKv2TPBKTwDZxrFrxM8Aeanxx3PJjyJn-e05xOc5qeMwip7141r7Vhj6f38MQEpxtXzbjngWrEDyLEfXCKEEkofsxD-mx5kHIKYai5kfoRLZB2FKfhJ6k_ujEVNdYhhEEYHdCjT0acKmBamY8mRd28rzhborJv0Wk-J9dTcVw354DD-KcSDy_vZs0TfIrpwPdWHp4MZySKFWdrZoszi3PoG2qRhaFHCqC2snBxsN0z7vXmKOeqGENawXV71mGd7WjhyBwpGKQGkaCN9H ...
#            'end_of_fade_in': 0.0,
#            'key': 2,
#            'key_confidence': 0.27,
#            'loudness': -10.888,
#            'mode': 1,
#            'mode_confidence': 0.355,
#            'num_samples': 4161097,
#            'offset_seconds': 0,
#            'rhythm_version': 1.0,
#            'rhythmstring': 'eJyVWwe2IzkOu0odQTnc_2IrAKSkst09ve9Nj_0rKFAMIEjHGFJ9cnrGU1t8Yu1Py8-oT51PXBfW37GUJ4b8lPT09V98euaXtO40-xvP9Pr0tr6lp431QnhGeua6UKueqHpKL-drIP4_Dv87hs6nz93CL9Xu2Fhh6rOuN_IZf81Yo55Ka_L14gxP6Vyrnsn2Pe9r64mauXI9sZZfon3ma5Y1yhJWbJAH7q-B21lm63rMJukB4li32lpoWEPFxGHxfOPdiP8i1lbLA-GvLXUbYL2AVfV9YW1tdJ4KjmOshYe1tf5gkWvWVrmKQGH5-XRtysS6N2xHuoVQbcr48E89NstTwxp6vTulBeuRPLl2bcJfbVqATsiWys-0PlvjPpLUYOyRluw6l5xmprLgJUxY_J8db1q7TNjVOQYd2gjYNCerVMtGdeMYfnB9b2cJbE09l0Lj-Qgl73rbto5Jlwqus107bCbmNdD6OoKGWROPdVBN2sGJEidZ-m6avyXiAsZTmaNwOhd94ZVgV7odEa516BG368_mJ8W6lQNqHwPeTdUtYejp0LSMaMZR7FbjLb4V9db6mmLTY-sRbDBrulRtqqiXh9ujBlu6QCXQuvgE_029NKmHkXOmFLSWWHSifMhOJHCnqejdtXtetIXHgeOJa4H4GCYlzAP1z5EngW10e2HtLq2jXTKpA3LGa3VtrwXTFlt1oARxjBH2NoaJe31PSyRLexJWM9ZfnYq0drN0ZUTKeZ3O0sTClUOd-CVm6r3pEh6pnHcej0SvJxXGgtLaR6MIsSv4kiWkkaGHMPB1F8NGs8QgHxNuPwBnvGaHMsPLwVEn_luqCXvLuq5Vr02tM1y6P6ZG9JEx2HoHFhUDTyYtwR9fLl-WKblt0lTneT5te0flo_vsLD0YtDbep5Nebm08xY2l0zmY47brciLr5SL3DZ2Nnf6DSsppbS-Xh4bunWF3NJDB-_LLcRhUjCrH7WJdRyLDhrji2RWuTPreOHni2FKWfiTIFWYRgkZg9IRzTuu1tFa7FpDWe_QpkWtP62ymuZ0WTUdNillRZNiJB86eUuY-1gFBDFFSLbAmONR13Albg8S5taLjX2JbDmFKjhUKe-LOuiJ3t0SEqHYHDc5cGEoi_x9oKMPu8Thg3ZHhqSq44rZkpnBqA-4oX-hyTL92kOQUQ9dhsvGXUpVznkXRvV64w08W0_4466_vn8-ca9IWySCvcy2MUJVuj27ovGYiglcywFPyFp2NOBlFDSopRluESXusFHeI51dJ8AZZ58uS_Drx5SriFLL66xb_dM2dEc599vfDDgF-v7c_mxztWg-Uun3O9pfZ3Xf89UB-zexYRYHx8_C_R3KAkr_GdehKtMqD82vS8d97-ZNSEUb0sHXCIuodFc93udd9ewe_tLZX2h3bESyyZItAFWTTIW-YzBAEVwSntzZSqFvwJFNhc3nbpXx0kLTktHxP4aHB6yPETDeiIdCwjjQlwn_sZ1Bf4bDWBoswa3nystEVpeDWoKrDME1IvrPuWKEo8IfEQA4M1IVBENAd-paj2oP_Yb-CCjSIaJFPi6ycdNnlEgkEEBj81rBpbRtaUbFEc1PambzWWkdXnJndXVp2N9XMHmTjKXDfKd5BjwMVXTF5LRSyBG3X8E2CXrfM-8-9xbe3GryOBEsYymF69buNo9RxvBITiUop5ZZu77GlZ4MDK5b-Q23_y0S30diZ_HrrBIaXOe2rCuU9O66V9_-7Wb9nAaQ3vBSFMT_9dN6wf6OlH25CiuRJEoMowhWcFdBSHgKfkzkZ1H59xQl3RnHo6QqIaSYDbHgOdjDMChkl0rDolAT4BJUCczlGsmL_6PK2suMuBgFiIyytByDBMUbZ51rKQJCVu2_Z87sFAwBIYfXUamXl2jncmUIxjCYr5PDYPPDCunhtqV8Klh7EjQiGgatm-OAEH3mQqHOhy8ICpgB8JDRu4_Ksfzpk97D541j9KUuH_8949gkW0hLWVK4-0-spSiUKKBaItqVfav1y4l0-LbnrpM-RgJsZeCXnYKP-CNyagbk7PscFc-rX6v-0S3M30IXAHHH5GKaE-90P416qX_4UJKWziWlif5pLyW977lwsQdru6eTcGzIMxqTPc1AqGItDnnv6MTatVATqR7hJpfI47uVIVzr-4a5Mm2588Bv49aox3quhABETh_aY9-qRQp1gzuQu-Yfy6XEn5Gl0eQ3mkF3ZVN8qp-iWwvCoRCkam8PUPsi7JKal5OCiZ1CYIiUsECihEf9WnW6LjizxDyJFYhDJ2EzBc6po6lTRJG6DKWVldoL4vaGmskCG2LVsHB4hb1PSHgQ38X6Xk0Gca30byfH-4xF2gJxrsOyT-6BkKvS3D-V1g5IY9EmT_hPZd6DyDLnrEZXPB3c7mT5xybooc8G1SpVxqC0HFmiRlVk5tN2ZssYDt2PVtnCtK7UZSqmWzEyFG9FWNQVZsWPyAJwzrEboiZvYjrrt82cqqbCN4bSPoWC7NrHCSKJclEXk8PYeQhsrKqT8L47w9zMUddu7fT8my5kKf9edBQ_NAj3Xq1dKLD74G5__N8h4zQ6Ktuk9szmsZTwfIKY2974W9BmnpJ5THMbSlNzA3CTutdG65N4p5qXVc7rSweqWEpSsSD5kOXCvcJrlccYoNsX8AiuN8qdI1pdGJUCIaXQbzoaJfKczFF-x4m5iUKxizIiuJl13Jg00w873LJ6QbmKQypYnkpNJYhmMz8aM7RDDcAl3pMkbWhecISBCh0gJSoTQZxRe_RWC__b5icb-rnmDlv6nu6Ku83IHMC1Y6vzACklkZKb_aId5sPupJHocYpormdL9vjmz_jgxK4ZJ2vWRWHv6BkKMLgav5Ln93v9neYXeoE47jHvV_4xp8pCRTQSpOOaPp-_vd1Hj1xH9xQb3-x_XM6nQj7j8L8gs7_ejkzX5ToZ-I576Nc-5Y94pHr73PnDEKYchI-68fyimWYzuzBnN0IyuSnth4hQN2-BRUrqNxKxzBGa-jFyT-ZtY_ba1qZKptwRTZOSdA3bag5WIul7XLTDRqvY0Zy7AdFVCAvg7coCcp2UHmtHQ2ybWj0hM9xHRu0gIZDOdTk-bwukAh5CCA1hmcatZXHROsHgsIyPRTI1ztyRAFT9Udab2y3AOfFDJruOFNKw8coob6ZVGMCZ37QCoJdfjzMB7qjJRjSqURjGLd96pWooHaQ-P-XDTRgMsD5_Iiey6lSta2oCA1-DNk5NLgwiiVMvgxnSeQoxMY-RI4fllElaW-4vJTxYwUv6Kuv8yBPGyYiEU_aeTLcS27Wvcv_uhf33uvRpLy5lRqsC5ZJPXOYKASsxS4QJTZkxAWTAjlOWgrFIYC8rHKJfloqsKBklBF2lxTzt1TsPQZDqVwspqDHEkdACaA0i2Pq1CiWBOBFbIhcfwzo73B00_WYmpsvjpxIiAciMZ1POBL-BNDTHseNPcELPHofXHoHKvExvQnsIVBKbPzVLqtwtuhAL3gfixWtow5h-O5k_HeH23quutluLd1vqHuNFsRnm9ijCM4kJ1qo3oZ8e9LkJlWN3vMLFF6QJOIEiIeLGx6imo8M13691sFGP64Hxliq8rbVfIA9MY_-Dswpvy7suB_0TDdyy94hmGsSl41MtBNq9FZjFLdyCT7wZR9D5QydfSAstdPb-tVhq8c-m6ScbfUMyy2ThhMkdwk1B9z50tSsUN-n7hjShmAhZWz-7ho4VHnef-WEVUjfVWJOKmKhMeAsJebN6huooiphrODxaB9ZbDzFQayKGkmMs7NI6bUo-7PSVug2MIwqqXrOvmuY5BRq9xYUOwpoyksh0qP4pAVqbRVaE_UElNBV_jBW9aoU0jvbA1IufuvmMFbbMfROQuOeREIrQXC0zI_JNQRselIt5dGxtqL2HuUVjE7szdPSF28qGdoHfQ2P5Ws9ftVQI1oRxmedME1RLJaQxkTxKvlHcL ...
#            'sample_md5': '',
#            'start_of_fade_out': 181.20853,
#            'synch_version': 1.0,
#            'synchstring': 'eJxFmImB6zgMQ1tRCaZOq__GhnigM7v-mVgHTxCi0vuznjbafN8W-be3mZ_5nv9v3nZb-W_mZ9d8MNVZdDz0tj5afrSIle8xo8WTL5qO3vbT9vsTvPK5-XZS6ta6bq0TpTl52hnaMDSZY6dtjR-t2wORq5b0tl6NxXyQHT1nx22BvSlr5au8iLetXnq7dgwL03P19eTekE2e3l530GX5-bIlXWNHY2NiC-Kf8ujd7R4-n_bednOkt5vKbpv5mgEmAHe2d7XbWRN8T5Gz1ujJ7fnatfg88qcEMn53ewcbFeFMnMZSwNGOjbhvRX45bwYjN6bS0pV7Uo5Mm_JuKTy4FGQg3VO8FNLMZ-5SvjP7j5L5kv5cWUFopJM0KX-Zc76k48pkWj8V-dMIozAwhwa2lR2l6ERBI90FBcp9J4FKSCMKS2pPoOScRqyWgerkHkQ6EzF3M56A1c7xsUDoBtDxLOa3hB8cTQQnHIHFLHNeO7KN8hTCgojLe8zB3yWB0jAtXVWQpTSC8IDXzOzptjYGwM6SiWcLxc5R4ivFJVAymQWOIN-99asYXRYHYBK8UjrFoexUsjvgIr0Zi62MrFDIclNBTC9PO1kgTwj4V4F8c5EEHsr1MThy5GrGEVZscyI3Xj74fC3mBZjT5Z0ZJ2oKFCWcdhGRzTeQsoU4QUMVuUl72iUVLqQTznMHfQQ-QbRPsY2zI83K8zUEU6F4Q-7sssMSHm3JCtjXCResURpYjMplOQndzbBY5OMUf_-4QH5nRp6z8z947_IsBB3lRIP5MKvXrQUJvk5dpZ2v0tQhV_TnChHlEKBFeLlUARMdaGrVlBDyNJClR1qH2G9QidBtswFHApJzhWgNBIXRlbvwrlNyRI0PijqrMXdSdRJhjB0J0EoYYH7LdR5o7irjcm7oixRARArmJ1EWEZU0N2Ofuv129HagHb0u3JkqOfl4UQrDi8ZXRcmvB1XBltTgAssFMUXSe0Gag9cQ6q4qpesk62auyf6jVzHLg6yDh-xMF9aXTwX3wbupKVh2QIfB0Ks4i2IgtCDMF8eX4lTBIXnKlgc9Oyo-YE9HzUMIL0sI3iLWGj_aLT3sW-Nfg9IUnDHnJwwUaPUVqsHotFEA0ajt8IFOy0Cm4fdoHGhQ18JKskeBoT8VuSAOhtPo2uLwZKgWcX0_EJC8hXtLh82VyHnMYJJun8hV7A-Jdmt_BdW_InJB0ZYEDmwKCqqw0FprcGLWivJ8ExCZ28vPFMZhcQg5idn7i82uAu2zIq1ABt6PKhEfTZ3w2-8xyojNVBDgPKH1GpU0HX4E55wya5De4yN5FxyzOKbr6pVLqf3Mynx6lRrF5h7BYK2kWAfndz-VREI0CJvkdRBMfzGs8Cl-Gax0GCeuTPIw9zey5bpRRE8jUhsY52w5LYt9w42YsNYhXsL5Fv7k01YAAroZT4V_dOr2txi0ZVVf6kHomXhJGonFAnVKYyfcy-Q6sXW4np1ycNoBe8Cpizj1_8do1zOLSl2_2oReg8KQ688n0uU6vxFAGvObdfCNN8oi7NeqcjVV9V0GuPILn-Oji5eAPOh1vakbU1UxHPMzBOt8IlwMtVeG8SmsapPLErT8dA8gyryKCCZS_KBEtUJLce2QvwqR4h-uO0Lvk0lbPo41C_loMNNGLz4ehNRsYuVpyySMauO7ZmkBXxdorh_keJOaCTcEV5Dw8Um-zi2c1AH0sYGD3z-aU7tQpPXhD34PEDg4QuOpOA2OQzfjdeT1opfu8-L5uJ2GeqjFjrcIrs9Kfifbadey4WqGyix8Kxa6VRI5XtX9MffoRQ7G0CxyH0raZkMYRCQ4Lb0qnjpmED7oN7s6-U6PKMoOnTRjF9jkPvw0OIHCjEFOO922CIwm7X7pFZ2kvnufTpIPvW5wij51jVRPdbiDCDyEWmt1r8p0uIHnPrF1OdnctNS3I82Uo-201vmdUs1u4F1cSUCRaoJO472lkvuSOigBa1MuhxsCtT-cCbRnR55ev_JVW9SJ092_PrguqFqcsTlu7YhGYoBIKJ-4R11g5ZSPZEkKrZ0Q_PDxQvqX-XHyb3OyHN-AF7dqdRSqATnmS_JLTN1LLy5JX9_kgn3lX6MvNheAqndbJudSwmUC1FldpYoPQEh71H3OF0CVqeD5kg9uFbrd0IurY0eGyl3ua0VaIzjeSY4FvkXebuFColXxONwI55bNofv8G_6bfR5F2XFVlOmzUTYZTrQ3vQ4E8f8-9Pk0ZNGoc3z2ff1yEVUrx4Hp-ysxPhRlCtfJtNut-8zkh4FZTYr0Didii4OGer-LrYs7yuxfhwTzXBK-v0vLotGQm9fUTDFGfJQTkp17tgLUHffHQHAUOvfqdkyxo1pTWYkzxoTbWH5wCbNQ99WYz-4z0vr67zFOVW66CtV1fdfVRkUVDijo8fUK9Zsyiaib9caQLSpZ5Gzod6XLheraX6qSK79-0rndzbVX9UcCNolXZw3d6MqQqyg__Q3_ihC6kdcPAI765hjCj-c7VPRcIOojJmRjqLsYf8CkUz4=',
#            'tempo': 143.009,
#            'tempo_confidence': 0.895,
#            'time_signature': 4,
#            'time_signature_confidence': 1.0,
#            'window_seconds': 0}}
# {'BAR_DUR': 1.6666661818181812,
#  'BEAT_STRENGTH': 0.4250159453302961,
#  'KEY_SPREAD': 12.0,
#  'SECT_DUR': 23.588985}

# %% [markdown]
# # Segment Micro-Genres && Give Them Names

# %%
def remove_disallowed_entries_by_key( dct ):
    """ Remove segments unsuitable for a genre name """
    # 2024-09-02: THERE ARE RACIAL SLURS IN THE PyEnchant MODULE! WHY?!? (Also: HITLER)
    blocked = ['soundtrack', 'for', 'nigger', 'gypsy', 'Hitler', 'klan',] 
    qKeys   = list( dct.keys() )
    qLen    = len( qKeys )
    delSet  = set([])
    difFrac = 0.25
    for i, k in enumerate( qKeys ):
        kLo     = str(k).lower()
        removed = False
        # Remove short keys
        if (len( kLo.strip() ) <= 2) and (k in dct):
            del dct[k]
            removed = True
        # Remove keys with apostrophees
        elif ("'" in kLo) and (k in dct):
            del dct[k]
            removed = True
        # Remove keys too similar to the blocked list
        else:
            for blkd in blocked:
                if ((levenshtein_dist( kLo, blkd ) / len( blkd )) < difFrac) and (k in dct):
                    del dct[k]
                    removed = True
                    break
        # If the current key is suitable, Then remove all following keys that are too similar
        if not removed:
            for j in range( i+1, qLen ):
                key_j    = qKeys[j]
                if (key_j in dct):
                    key_jLo  = str( key_j ).lower()
                    distance = levenshtein_dist( kLo, key_jLo )
                    fracRght = distance / len( key_jLo )
                    fracLeft = distance / len( kLo     )
                    if (fracRght < difFrac) or (fracLeft < difFrac):
                        if key_j in dct:
                            del dct[ key_j ]
                        

def repair_keys( dct ):
    """ Replace keys that have characters we don't like """
    badChars = ['(', ')', ':', '"']
    dctKeys  = list( dct.keys() )
    for key in dctKeys:
        nuKey = str( key )
        p_bad = False
        for ch in badChars:
            if ch in key:
                nuKey.replace( ch, '' )
                p_bad = True
        if p_bad and (key in dct):
            dct[ nuKey ] = dct[ key ]
            del dct[ key ]


def Proper_Namify( namStr ):
    """ Capitalize every split string, and reassemble """
    namSeg = str( namStr ).split()
    Nseg   = len( namSeg )
    rtnNam = ""
    for i, seg in enumerate( namSeg ):
        rtnNam += seg[0].upper() + seg[1:].lower()
        if i+1 < Nseg:
            rtnNam += ' '
    return rtnNam
    

def extract_and_generate_genre_names( genreDct, pause_s = 0.25 ):
    """ Extract Spotify genre and Generate local genre """
    global data
    mainDist = dict()
    loclDist = dict()
    artSet   = set([])
    englishD = enchant.Dict( "en_US" )
    segments = list()
    # Get artist info and local genre candidate substrings
    for track in genreDct['tracks']:
        # Gather artist IDs
        for artist in track['track']['album']['artists']:
            artSet.add( artist['id'] )
            segments.extend( artist['name'].split() )
        # Gather naming strings
        segments.extend( track['track']['album']['name'].split() )
        segments.extend( track['track']['name'].split() )
    qSegmnts = segments[:]
    nglshSeg = list()
    Norig    = len( segments )
    for qSeg in qSegmnts:
        segments.extend( englishD.suggest( qSeg ) ) # https://stackoverflow.com/a/3789057
    for i, seg in enumerate( segments ):
        if i < Norig:
            value = 1.0
        else:
            value = 0.5
        if seg in loclDist:
            loclDist[ seg ] += value
        else:
            loclDist[ seg ]  = value
    
    repair_keys( loclDist )
    remove_disallowed_entries_by_key( loclDist )
    # pprint( loclDist )

    # Extract Spotify genre from the artist set
    artSetLs = list( artSet )
    Nartists = len( artSetLs )
    artQList = list()
    if Nartists <= _ARTIST_Q_LIM:
        artQList.append( artSetLs )
    else:
        bgn = 0
        end = 0
        while end < Nartists:
            bgn = end
            end = min( end+_ARTIST_Q_LIM, Nartists )
            artQList.append( artSetLs[bgn:end] )

    for qArtLs in artQList:
        nuLst = list()
        for qArtist in qArtLs:
            if (qArtist not in data['artists']):
                data['artists'][ qArtist ] = { 
                    'name'    : None, 
                    'count'   : 0, 
                    'releases': list(), 
                    'genres'  : list(), 
                }
            if ('genres' not in data['artists'][ qArtist ]):
                data['artists'][ qArtist ]['genres'] = list()
            if (len( data['artists'][ qArtist ]['genres'] ) == 0):
                nuLst.append( qArtist )

        if len( nuLst ):
            sc.check_API_token() # 2024-09-01: WHY DOES IT KEEP FAILING HERE IT HAS NOT BEEN AN HOUR
            response = sc.spot.artists( nuLst )
            for artist in response['artists']:
                qArtist = artist['id']
                data['artists'][ qArtist ]['name'  ] = artist['name'  ]
                data['artists'][ qArtist ]['genres'] = artist['genres']
            sleep( pause_s )

        for qArtist in qArtLs:
            for spGenre in data['artists'][ qArtist ]['genres']:
                if spGenre not in mainDist:
                    mainDist[ spGenre ]  = 1
                else:
                    mainDist[ spGenre ] += 1

    if len( mainDist ):
        topSpGenre = sort_keys_by_value( mainDist, reverse = True )[0]
    else:
        topSpGenre = _NULL_GENRE

    genreDct['nameSpot'] = topSpGenre

    loclDist = normalize_dist( loclDist )
    mainDist = normalize_dist( mainDist )
    genreDct['nameDist'] = mainDist

    localName = ""
    namLast   = roll_outcome( mainDist )
    if namLast is None:
        namLast = "Music"
        P_last    = 1.0
        running   = True
    else:
        P_last    = max( 0.333, mainDist[ namLast ] )
        running   = (random() < P_last)
    
    localName += Proper_Namify( roll_outcome( loclDist ) ) + '-' + Proper_Namify( namLast )

    nPart = 0
    while running:
        namLast = roll_outcome( loclDist )
        P_last  = max( 0.333, loclDist[ namLast ] )
        running = random() < min( P_last*10.0, 0.95 )
        localName += ' ' + Proper_Namify( namLast ) 
        nPart += 1
        if nPart >= _NAME_PT_LIM:
            break

    genreDct['nameLocal'] = localName

    print( f"{genreDct['nameLocal']} | {genreDct['nameSpot']} | {genreDct['nameDist']}" )


def generate_genres_from_track_list( tracks ):
    """ Use DBSCAN to generate clusters based on track vectors, Give them names, Then return as a `dict` """
    # NOTE: This function assumes that `tracks` was built using `fetch_entire_playlist_with_audio_features`                
    global data
    print( f"\n########## Extract genre info from {len(tracks)} tracks! ##########\n" )

    ### Compute Clusters ###
    trkVecs = get_tracks_as_vectors( tracks )
    clustrs = DBSCAN( eps = _DBS_EPSILON, min_samples = _DBS_MIN_MMBR ).fit( trkVecs )
    genres  = dict()
    for i, trk_i in enumerate( tracks ):
        lbl_i = clustrs.labels_[i]
        if (lbl_i not in genres):
            genres[ lbl_i ] = {
                'nameSpot' : None, # --- Most prominent Spotify genre across all artists
                'nameDist' : None, # --- Discrete distribution of Spotify genre across all artists
                'nameLocal': None, # --- Humorous (semi-)unique name given to micro-genre
                'tracks'   : [trk_i,], # Tracks that belong to this micro-genre
                'len'      : 1, # ------ Number of identified tracks in the micro-genre
                'vectors'  : None, # --- Vector representation of the tracks
                'origins'  : list(), # Playlist(s) that tracks come from
            }
        else:
            genres[ lbl_i ]['tracks'].append( trk_i )
            genres[ lbl_i ]['len'   ] += 1

    # Erase outliers
    if -1 in genres:
        del genres[-1]
    print( f"Identified {len(genres)} genres in this collection of {len(tracks)} tracks!" )
    # Generate unique keys for genres
    rtnGenres = dict()
    for k, v in genres.items():
        rtnGenres[ str( uuid4() ) ] = v

    ### Compute Center and kdTree for genre ###
    for gnre in rtnGenres.values():
        genre_vector_ops( gnre )

        # Generate micro-genre names {Spotify, Distribution, Local}
        extract_and_generate_genre_names( gnre )
    
    print( f"\n########## Genre extraction COMPLETE! ##########\n" )

    return rtnGenres


def extract_micro_genres_from_collection( eraseExisting = True ):
    """ Extract and merge micro-genres from the entire collection defined by `data` """
    global data
    
    if eraseExisting:
        data['genres'] = dict()
    
    for plName_i, playls_i in data['playlists'].items():
        print( f"\n### Playlist: {plName_i}, {playls_i['ID']} ###\n" )
        bgn_i    = now()
        tracks_i = playls_i['tracks']
        N_trks_i = len( tracks_i )
        bgn      = 0
        end      = 0
        while end < N_trks_i:
            bgn     = end
            end     = min( end+_N_GN_CHUNK, N_trks_i )
            print( f"\n## Chunk[ {bgn}:{end} ] ##\n" )
            
            gnres_i = generate_genres_from_track_list( tracks_i[ bgn:end ] )
            
            for gnre_j in gnres_i.values():
                gnre_j['origins'] = [playls_i['ID'],]
                
            data['genres'].update( gnres_i )
            sc.check_API_token() # 2024-08-21: This process can take a while on my home machine

        # break
            
        dur_i = now() - bgn_i
        print( f"\nGenre generation from {plName_i} took {dur_i/60.0} minutes!\n" )

# %% [markdown]
# ## Micro-Genre Creation

# %%
import cProfile

if _REGEN_DBASE:
    # cProfile.run("extract_micro_genres_from_collection( data )")
    extract_micro_genres_from_collection( )

# %% [markdown]
# ## Merge Micro-Genres into Mini-Genres

# %%
def merge_micro_genres_in_db( ):
    """ Attempt to merge similar genres in the `data` """
    global data
    print( f"########## Attempt to merge similar genres in the music database ##########" )
    
    ### Init ###
    Ngenres = len( data['genres'] )
    IDs     = list()
    trees   = list()
    pntLsts = list()
    
    # Gather track vectors
    for k, v in data['genres'].items():
        IDs.append( k )
        trees.append( v['kdTree'] )
        pntLsts.append( v['vectors'] )
    
    ### Search for merge candidates ###
    mergeLst = list()
    for i, gID_i in enumerate( IDs ):
        pts_i = pntLsts[i]
        if len( pts_i ) > 1:
            for j in range( i+1, Ngenres ):
                gID_j = IDs[j]
                kdt_j = trees[j]
                dif_j = list()
                for pnt_k in pts_i:
                    dif_j.append( kdt_j.query( pnt_k )[0] )
                if (np.mean( dif_j ) < (_DBS_EPSILON/_MRG_D_FACTOR)):
                    found = False
                    for mrgSet in mergeLst:
                        if ((gID_i in mrgSet) or (gID_j in mrgSet)):
                            mrgSet.add( gID_i )
                            mrgSet.add( gID_j )
                            found = True
                            break
                    if not found:
                        mergeLst.append( set([gID_i, gID_j,]) )

    print( f"There are {len(mergeLst)} merge jobs to perform!" )
    
    ### Perform all merge jobs ###
    for mrgJob in mergeLst:
        mDct = {
            'nameSpot' : None, # --- Most prominent Spotify genre across all artists
            'nameDist' : dict(), # --- Discrete distribution of Spotify genre across all artists
            'nameLocal': None, # --- Humorous (semi-)unique name given to micro-genre
            'tracks'   : list(), # Tracks that belong to this micro-genre
            'len'      : 0, # ------ Number of identified tracks in the micro-genre
            'vectors'  : None, # --- Vector representation of the tracks
            'kdTree'   : None, # --- Spatial tree for 'vectors'
            'origins'  : list(), # Playlist(s) that tracks come from
        }
        namSplt = list()
        keys_i = list( mrgJob )
        print( "\nMerge:" )
        for j, key_ij in enumerate( keys_i ):
            if key_ij in data['genres']:
                if j > 0:
                    print( "\t\t-and-" )
                print( f"\t{data['genres'][ key_ij ]['nameLocal']}" )
            
        for mID in mrgJob:
            if mID in data['genres']:
                # Local name components
                namSplt.append( [data['genres'][ mID ]['len'], data['genres'][ mID ]['nameLocal'].split(),] )
                # Tracks
                mDct['tracks'].extend( data['genres'][ mID ]['tracks'] )
                # Vectors
                if mDct['vectors'] is None:
                    mDct['vectors'] = data['genres'][ mID ]['vectors']
                else:
                    mDct['vectors'] = np.vstack( (mDct['vectors'], data['genres'][ mID ]['vectors'],) )
                # Len
                mDct['len'] += data['genres'][ mID ]['len']
                # Origins
                mDct['origins'].extend( data['genres'][ mID ]['origins'] )
                # Name Distribution
                for k, v in data['genres'][ mID ]['nameDist'].items():
                    if k in mDct['nameDist']:
                        mDct['nameDist'][k] += v * data['genres'][ mID ]['len']
                    else:
                        mDct['nameDist'][k]  = v * data['genres'][ mID ]['len']
                # Delete the merged genre
                del data['genres'][ mID ]
        if (mDct['vectors'] is not None) and (len( mDct['vectors'] ) > 1):
            # Recalc the spatial tree
            mDct['kdTree'] = cKDTree( mDct['vectors'], balanced_tree = False, compact_nodes = False )
        # Normalize Name Distribution
        mDct['nameDist'] = normalize_dist( mDct['nameDist'] )
        # Choose the top Spotify genre
        if len( mDct['nameDist'] ):
            topSpGenre = sort_keys_by_value( mDct['nameDist'], reverse = True )[0]
        else:
            topSpGenre = _NULL_GENRE
        mDct['nameSpot'] = topSpGenre
        
        # Construct a new local name
        lenLst = [len( item[1] ) for item in namSplt]
        if len( lenLst ) > 0:
            lenMax = max( lenLst )
            lclNam = ""
            for j in range( lenMax ):
                dice = dict()
                for k, (mag_k, lst_k) in enumerate( namSplt ):
                    # print( f"Components: {k}, {mag_k}, {lst_k}" )
                    len_k = len( lst_k )
                    if j < len_k:
                        dice[ lst_k[j] ] = mag_k
                token = roll_outcome( dice )
                # print( namSplt )
                # print( lenLst )
                # pprint( dice )
                # print( f"Token: {token}" )
                if j > 0:
                    lclNam += ' '
                lclNam += (token if (token is not None) else _NULL_GENRE)
            mDct['nameLocal'] = lclNam
        else:
            mDct['nameLocal'] = _NULL_GENRE

        # Store the merged mini-genre
        nuID = str( uuid4() )
        data['genres'][ nuID ] = mDct
        print( f"Merge Complete!: New Mini-Genre {mDct['nameLocal']} ({nuID}) created with {mDct['len']} tracks!" )


def move_mini_genre_outliers_to_better_homes( ):
    """ Attempt to rehome outlier tracks that were collected during the micro-genre creation and merge """
    global data
    
    ### Search for split candidates ###
    Ngenres = len( data['genres'] )
    IDs     = list()
    trees   = list()
    pntLsts = list()
    dstLsts = list()

    # Gather track vectors
    for k, v in data['genres'].items():
        IDs.append( k )
        trees.append( v['kdTree'] )
        pntLsts.append( v['vectors'] )

    # Evaluate spread within each mini-genre
    for i, pts_i in enumerate( pntLsts ):
        avgDist = list()
        if pts_i is not None:
            for j, pnt_j in enumerate( pts_i ):
                dists = list()
                for k, pnt_k in enumerate( pts_i ):
                    dists.append( np.linalg.norm( np.subtract( pnt_j, pnt_k ) ) )
                avgDist.append( np.mean( dists ) )
            dstLsts.append( avgDist )
        else:
            dstLsts.append( _ONE_BILLION )

    ## Evaluate relative closeness of every point in a genre to every other genre ##
    # For every mini-genre, do
    for i, gID_i in enumerate( IDs ):
        if pntLsts[i] is None:
            continue
        pts_i = pntLsts[i][:].tolist()
        dst_i = dstLsts[i][:]
        # For every vector in the mini-genre, do
        j = 0 
        while (j < len( pts_i )):
            pnt_j = pts_i[j]
            dst_j = dst_i[j]
            dMn_j = 1e6
            gnr_j = None
            # For every other mini-genre, Search for the shortest dist
            for k, gID_k in enumerate( IDs ):
                if i != k:
                    tre_k  = data['genres'][ gID_k ]['kdTree']
                    if tre_k is not None:
                        dst_jk = tre_k.query( pnt_j )[0]
                        if ((dst_jk < dst_j) and (dst_jk < dMn_j)):
                            dMn_j = dst_jk
                            gnr_j = gID_k
            # If a new home was found, then move
            if gnr_j is not None:
                print( f"Moving track {j} of  {data['genres'][ gID_i ]['nameLocal']}  --to->  {data['genres'][ gnr_j ]['nameLocal']}" )
                trk_j = data['genres'][ gID_i ]['tracks'][j]
                data['genres'][ gID_i ]['tracks'].pop(j)
                pts_i.pop(j)
                dst_i.pop(j)
                data['genres'][ gnr_j ]['tracks'].append( trk_j )
                data['genres'][ gnr_j ]['changed'] = True
                data['genres'][ gID_i ]['changed'] = True
            else:
                j += 1
                
    # For every mini-genre, Recalc vectors if it has changed
    for i, gID_i in enumerate( IDs ):
        genre_vector_ops( data['genres'][ gID_i ] )
        data['genres'][ gID_i ]['changed'] = False
            

    print( "\n########## Genre Report ##########\n" )
    print( f"Filter {len( data['genres'] )} to filter...\n" )
    lstDel = list()
    
    for gID, genre in data['genres'].items():
        if genre['len'] >= _MIN_GNR_MMBR:
            print( f"{genre['nameLocal']}, {genre['len']}" )
        else:
            lstDel.append( gID )

    print( "Deleting ...", end = " " )
    for gID in lstDel:
        print( gID, end = ", " )
        del data['genres'][ gID ]
        
    print( f"\nDeleted {len( lstDel )} mini-genres, {len( data['genres'] )} remain" )
    print( "\n########## Report Complete ##########\n" )

# %%
if _REGEN_DBASE:
    merge_micro_genres_in_db( )
    move_mini_genre_outliers_to_better_homes( )
    save_music_database( data, outPath )

# %% [markdown]
# # Search Version 02, Graded by Mini-Genre Proximity

# %% [markdown]
# ## Sub-Searches

# %%
def get_tracks_from_new_releases( N, div = 12, pause_s = 0.25 ):
    """ Get `N` tracks from newly-released albums """
    global data
    
    totTrks = list()
    Nalbums = int( ceil( N / div ) )
    albOfst =  0
    count   =  0
    Niter   =  0
    itrLim  = 20

    while count < N: 

        Niter += 1

        if Niter > itrLim:
            break
        
        if data is not None:
            if _NU_REL_Q_KEY in data['queries']:
                albOfst = data['queries'][ _NU_REL_Q_KEY ]
                data['queries'][ _NU_REL_Q_KEY ] += Nalbums
            else:
                data['queries'][ _NU_REL_Q_KEY ] = Nalbums
        
        response = sc.spot.new_releases( limit = Nalbums, offset = albOfst )
        nuAlbums = [item['id'] for item in response['albums']['items']]
        sleep( pause_s )
        
        for albumID in nuAlbums:
            res    = sc.spot.album_tracks( albumID, limit = 50, offset = 0 )
            tracks = res['items']
            totTrks.extend( tracks )
            count += len( tracks )
            sleep( pause_s )

    return totTrks


def get_recommended_tracks_from_db( N_tracks, pause_s = 0.25 ):
    """ Recommended tracks by both artists and genres """
    global data
    count  = 0
    gIDs   = list( data['genres'].keys() )
    rtnLst = list()
    while count < N_tracks:
        recArt = list()
        recTrk = list()
        recGnr = list()
        gID    = choice( gIDs )
        gnre   = data['genres'][ gID ]
        for i in range( 5 ):
            trk_i = choice( gnre['tracks'] )
            art_i = choice( trk_i['track']['album']['artists'] )
            if i % 3 == 0:
                recArt.append( art_i['id'] )
            elif i % 2 == 0:    
                recTrk.append( trk_i['track']['id'] )
            else:
                recGnr.append( roll_outcome( gnre['nameDist'] ) )
                
        nFetch = min( sc._RESPONSE_LIMIT, max( N_tracks-count, 0 ) )
        if nFetch > 0:
            response = sc.spot.recommendations(
                seed_artists = recArt, 
                seed_genres  = recGnr, 
                seed_tracks  = recTrk, 
                limit        = nFetch
            )
            sleep( pause_s )
            # pprint( response )
            tracks = response['tracks']
            count += len( tracks )
            rtnLst.extend( tracks )
        else:
            break
    return rtnLst
        

def get_tracks_from_related_artists( N_tracks, pause_s = 0.25 ):
    """ Attempt to get fresh tracks from Spotify given artists currently in the collection """
    global data
    skipN  = 5
    count  = 0
    plNam  = list( data['playlists'].keys() )
    rtnLst = list()

    while count < N_tracks:
        tracks = data['playlists'][ choice( plNam ) ]['tracks']
        artist = choice( choice( tracks )['track']['album']['artists'] )['id']
        res    = sc.spot.artist_related_artists( artist )
        artLst = [item['id'] for item in res['artists']]
        Nart   = len( artLst )
        sleep( pause_s )

        # For each artist, Get top tracks
        for art_i in artLst:
            qArtist = _ART_Q_PREFIX + str( art_i )
            if qArtist not in data['queries']:
                res = sc.spot.artist_top_tracks( art_i )
                sleep( pause_s )
                count += len( res['tracks'] )
                rtnLst.extend( res['tracks'] )
                data['queries'][ qArtist ] = 1

        # For each group of artists, Get recommendations
        bgn  = 0
        end  = 0
        grps = list()
        while end < Nart:
            bgn = end
            end = min( end+skipN, Nart )
            grps.append( artLst[ bgn:end ] )
        for artGrp in grps:
            nFetch = min( sc._RESPONSE_LIMIT, max( N_tracks-count, 0 ) )
            if nFetch > 0:
                response = sc.spot.recommendations(
                    seed_artists = artGrp, 
                    limit        = nFetch
                )
                sleep( pause_s )
                # pprint( response )
                tracks = response['tracks']
                count += len( tracks )
                rtnLst.extend( tracks )
            else:
                break

    return rtnLst


def get_tracks_from_featured_playlists( N_tracks, pause_s = 0.25 ):
    """ Attempt to get fresh tracks from Spotify featured playlists, one at a time """
    global data
    step    = 1
    count   = 0
    totTrks = list()
    while count < N_tracks:
        ofst  = data['queries'][ _FEAT_PL_Q_KY ] if (_FEAT_PL_Q_KY in data['queries']) else 0
        data['queries'][ _FEAT_PL_Q_KY ] = data['queries'].get( _FEAT_PL_Q_KY, 0 ) + 1
        response = sc.spot.featured_playlists( limit = step, offset = ofst )
        if len( response['playlists']['items'] ):
            plylstID = response['playlists']['items'][0]['id']
            tracks   =  fetch_entire_playlist_with_audio_features( plylstID )
            count   += len( tracks )
            totTrks.extend( tracks )
    return totTrks

# %% [markdown]
# ## Search and Filter

# %%
from ShuffleSoGood import get_track_vector, _MIN_LEN_S

def add_audio_features_to_track_list( tracks, pause_s = 0.25 ):
    """ Add audio features and calc vector for all `tracks` """
    ## Init ##
    N_trks = len( tracks )
    featrs = list()
    rtnLst = list()

    if N_trks:
    
        bgn    = 0
        end    = 0
        
        ## Get Features ##
        while end < N_trks:
            bgn = end
            end = min( end+sc._RESPONSE_LIMIT, N_trks )
            # pprint( tracks[0] )
            lst = [item['id'] for item in tracks[ bgn:end ]]
            featrs.extend( sc.spot.audio_features( lst ) )
            sleep( pause_s )
    
            
        ## Add Features and Vectors ##
        for i, track_i in enumerate( tracks ):
            updat_i = featrs[i]
            if updat_i is not None:
                track_i.update( updat_i )
                track_i['vector'] = get_track_vector( track_i )
            rtnLst.append( track_i )
    return tracks


def filter_short_and_explicit_tracks( qTracks ):
    """ Remove short (<1:45) and explicit (guaranteed vocal) songs and Return filtered tracks """
    tracks = qTracks[:]
    # 3. For every track j in playlist, do
    j = 0
    while j < len( tracks ):
        track_j   = tracks[j]
        trackID_j = track_j['id']
        len_s_j   = track_j['duration_ms']/1000.0
        explc_j   = track_j.get( 'explicit', False )

        if ((len_s_j < _MIN_LEN_S) or explc_j):
            tracks.pop(j)
        else:
            j += 1
    return tracks


def filter_collected_and_reviewed_tracks( qTracks ):
    """ Remove songs that are either already in the collection or have been reviewed and Return filtered tracks """
    global data
    tracks = qTracks[:]
    trkSet = set([])
    # 3. For every track j in playlist, do
    j = 0
    while j < len( tracks ):
        track_j   = tracks[j]
        trackID_j = track_j['id']
        p_collect = (trackID_j in data['collectID'])
        p_reviewd = (trackID_j in data['reviewID' ])
        p_intake  = (trackID_j in trkSet)

        if (p_collect or p_reviewd or p_intake):
            tracks.pop(j)
        else:
            trkSet.add( trackID_j )
            j += 1
    return tracks


def guided_multi_search_version_02( N_tracks ):
    global data
    print( "\n########## Guided Multi-Search, Version_02 ##########\n" )
    
    ### Search && Gather ###
    print( f"Search for {N_tracks} new releases ..." )
    tracks = get_tracks_from_new_releases( N_tracks, div = 12,  pause_s = 0.25 )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} recommendations ..." )
    tracks.extend( get_recommended_tracks_from_db( N_tracks, pause_s = 0.25 ) )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} tracks from artists similar to collection ..." )
    tracks.extend( get_tracks_from_related_artists( N_tracks, pause_s = 0.25 ) )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} tracks in Spotify featured playlists ..." )
    tracks.extend( get_tracks_from_featured_playlists( N_tracks, pause_s = 0.25 ) )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} tracks using Version 01 ..." )
    tracks.extend( basic_new_music_search_01( N_tracks, Mper = 5, pause_s = 0.125 ) )
    # pprint( tracks[-1] )
    
    print( f"Multi-Search COMPLETE: Retreived {len(tracks)} tracks!\n" )

    ### Filter ###
    print( f"About to filter {len(tracks)} tracks ..." )
    
    # for i in range( 0, int(N_tracks/2), len(tracks) ):
    #     print( f"\n\n Track {i}:" )
    #     pprint( tracks[i] )
        
    tracks = add_audio_features_to_track_list( tracks, pause_s = 0.25 )
    
    tracks = filter_short_and_explicit_tracks( tracks )
    tracks = filter_collected_and_reviewed_tracks( tracks )
    
    ### Rank by Ascending Distance to Nearest Mini-Genre ###
    print( f"About to rank {len(tracks)} tracks ..." )
    for trk_i in tracks:
        dMin_i = _ONE_BILLION
        gnre_i = _NULL_GENRE
        for gnID_j, mGenre_j in data['genres'].items():
            dist_j = mGenre_j['kdTree'].query( trk_i['vector'] )[0]
            if dist_j < dMin_i:
                dMin_i = dist_j
                gnre_i = gnID_j
        trk_i['minGenreDist' ] = dMin_i
        trk_i['mini-genre_ID'] = gnre_i
    tracks.sort( key = lambda item: item['minGenreDist'] )
    print( "\n########## Multi-Search 02: COMPLETE ##########\n" )

    ### Return Top Hits ###
    if len( tracks ) < N_tracks:
        return tracks
    else:
        return tracks[ :N_tracks ]


def refill_playlist_with_new_tracks_02( plID, Ntot = _N_BACKFILL, pause_s = 0.50 ):
    """ Top off the playlist with new tracks """
    global data, outPath
    plLen = get_playlist_length( plID )
    if Ntot > plLen:
        nRem = Ntot - plLen
        print( f"About to add {nRem} tracks ..." )
        addTrks = guided_multi_search_version_02( nRem )
        addID   = [item['id'] for item in addTrks]
        Nadd    = len( addID )
        bgn     = 0
        end     = 0
        while end < Nadd:
            bgn    = end
            end    = min( end+sc._RESPONSE_LIMIT, Nadd )
            result = sc.spot.user_playlist_add_tracks( sc.CLIENT_ID, plID, addID[ bgn:end ] )
        save_music_database( data, outPath ) # Save queries we made
        print( "Playlist refill complete!" )
    else:
        print( "No room for new tracks!" )

# %% [markdown]
# # Genre Cleanup

# %%
from random import shuffle


def set_genre_membership( ):
    """ Make sure all genres have a membership ID hash """
    global data
    for gnreID_k, genre_k in data['genres'].items():
        if ('trackIDs' not in genre_k):
            genre_k['trackIDs'] = set([])
        for l, track_l in enumerate( genre_k['tracks'] ):
            genre_k['trackIDs'].add( track_l['id'] )
    

def get_homeless_tracks( ):
    """ Return a list of tracks not assicated with a current mini-genre """
    global data
    set_genre_membership( )
    rtnLst = list()
    for plName_i, playls_i in data['playlists'].items():
        for j, track_j in enumerate( playls_i['tracks'] ):
            found   = False
            trkID_j = track_j['id']
            for gnreID_k, genre_k in data['genres'].items():
                if trkID_j in genre_k['trackIDs']:
                    found = True
                    break
            if not found:
                rtnLst.append( track_j )
    shuffle( rtnLst )
    print( f"Found {len(rtnLst)} unaffiliated tracks!" )
    return rtnLst


def genretize_remainder( chunkSize = _N_RM_CHUNK ):
    """ Try to generate affliations for free tracks """
    global data
    freeTrks = get_homeless_tracks( )
    NfreTrks = len( freeTrks )
    
    bgn      = 0
    end      = 0
    trkChnks = list()
    while end < NfreTrks:
        bgn = end
        end = min( end+chunkSize, NfreTrks )
        trkChnks.append( freeTrks[ bgn:end ] )

    for i, tracks_i in enumerate( trkChnks ):
        bgn_i    = now()
        gnres_i  = generate_genres_from_track_list( tracks_i )
        for gnre_j in gnres_i.values():
            gnre_j['origins'] = ['FreeTracks',]
        data['genres'].update( gnres_i )
        dur_i = now() - bgn_i
        print( f"\nGenre generation from {len(tracks_i)} tracks took {dur_i/60.0} minutes!\n" )
        sc.check_API_token() # 2024-08-21: This process can take a while on my home machine


def recruit_remainder( ):
    """ Attempt to move free tracks to already-generated mini-genres """
    global data
    freeTrks = get_homeless_tracks( )
    NfreTrks = len( freeTrks )
    totCount = 0

    def membership_score( qPnt, kNNpts ):
        """ Return a score that expresses cluster membership, Higher is better, -1 means not a member """
        if (len(kNNpts) < _DBS_MIN_MMBR):
            return -1
        dists = sorted( [item[0] for item in kNNpts] )
        insid = 0
        score = 0
        for i, p_i in enumerate( kNNpts ):
            d_i    = np.linalg.norm( np.subtract( qPnt, p_i ) )
            score += np.exp( -d_i ) # The closer it is, the larger this number    
        return score

    for i, track_i in enumerate( freeTrks ):
        if (i%100==0):
            print( '.', end='', flush=1 )
        hiScore = -1
        hiGenre = None
        
        for gnreID_j, genre_j in data['genres'].items():
            nn_j = genre_j['kdTree'].query_ball_point( track_i['vector'], _DBS_EPSILON )
            nn_j = [genre_j['vectors'][ index ] for index in nn_j]
            sc_j = membership_score( track_i['vector'], nn_j )
            if sc_j > hiScore:
                hiScore = sc_j
                hiGenre = gnreID_j
                
        if (hiGenre is not None):
            data['genres'][ hiGenre ]['tracks' ].append( track_i )
            data['genres'][ hiGenre ]['changed'] = True
            totCount += 1
    print()

    for gnre in data['genres'].values():         
        if gnre.get( 'changed', False ):
            print( f"Recalculating  {gnre['nameLocal']}  ..." )
            genre_vector_ops( gnre )
            gnre['changed'] = False

    set_genre_membership()
    print( f"Found homes for {totCount} free tracks!" )
    get_homeless_tracks()


def populate_releases( ):
    """ Make sure releases are populated """
    global data
    print( type( data ) )
    for plName_i, plyLst_i in data['playlists'].items():
        print( plName_i, '-', plyLst_i['ID'], '...' )
        tracks_i = plyLst_i['tracks']
        assign_vectors_to_tracks( tracks_i )

        # Catalog artists from collection tracks (Req'd for (Sub-)Search 01)
        for track_j in tracks_i:
            for artist_k in track_j['track']['artists']:
                artistID_j = artist_k['id']
                if artistID_j not in data['artists']:
                    data['artists'][ artistID_j ] = { 
                        'name'    : track_j['track']['artists'][0]['name'], 
                        'count'   : 1, 
                        'releases': [track_j['track']['album']['release_date'],], 
                    }
                else:
                    data['artists'][ artistID_j ]['count'   ] += 1
                    data['artists'][ artistID_j ]['releases'].append( track_j['track']['album']['release_date'] )

# %%
if _REGEN_DBASE:
    genretize_remainder( chunkSize = _N_RM_CHUNK )
    merge_micro_genres_in_db( )
    move_mini_genre_outliers_to_better_homes( )
    recruit_remainder(  )
    save_music_database( data, outPath ) # Save queries we made

# %%
if _SEARCH_BKFL:
    sc.check_API_token()
    populate_releases()

# %%
if _SEARCH_BKFL:
    sc.check_API_token()
    refill_playlist_with_new_tracks_02( _FILL_PL_ID, Ntot = _N_BACKFILL )

# %%
if _SEARCH_BKFL:
    save_music_database( data, outPath ) # Save queries we made
