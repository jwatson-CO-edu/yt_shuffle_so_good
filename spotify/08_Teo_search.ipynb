# %% [markdown]
# `python3.11 -m pip install jupyterlab PyEnchant scipy numpy spotipy scikit-learn --user`

# %% [markdown]
# # Init & Login

# %%
import time, pickle, os
now = time.time
from math import ceil
from random import randrange, choice, random
from time import sleep
from pprint import pprint
from datetime import datetime
from uuid import uuid4

import spotipy
import spotipy.util as util

from IPython.display import clear_output
import enchant
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
from scipy.spatial import cKDTree

## Client Info ##
CLIENT_ID     = ""
CLIENT_SECRET = ""
CLIENT_SCOPE  = "user-follow-modify playlist-modify-private playlist-modify-public"
USER_NAME     = "31ytgsr7wdmiaroy77msqpiupdsi"
REDIR_URI     = "https://github.com/jwatson-CO-edu/yt_shuffle_so_good"
AUTH_URL      = 'https://accounts.spotify.com/api/token'
BASE_URL      = 'https://api.spotify.com/v1/'

## API Info ##
_RESPONSE_LIMIT =  100
_ARTIST_Q_LIM   =   50
_MAX_OFFSET     = 1000
_T_LOGIN_S      = 60.0 * 10 #20 # 25 # 50
tLastAuth       = 0.0

with open( "../keys/spot_ID.txt" , 'r' ) as f:
    CLIENT_ID = f.readlines()[0].strip()

with open( "../keys/spot_SECRET.txt" , 'r' ) as f:
    CLIENT_SECRET = f.readlines()[0].strip()

token = None
spot  = None


def check_API_token():
    global tLastAuth, token, _T_LOGIN_S, spot
    tNow    = now()
    elapsed = tNow - tLastAuth
    if elapsed >= _T_LOGIN_S:
        token = util.prompt_for_user_token(
            username      = USER_NAME,
            scope         = CLIENT_SCOPE,
            client_id     = CLIENT_ID,
            client_secret = CLIENT_SECRET,
            redirect_uri  = REDIR_URI
        )
        spot = spotipy.Spotify( auth = token )
        print( token )
        clear_output( wait = True )
        sleep( 2 )
        print( "TOKEN OBTAINED" )
        tLastAuth = tNow
    else:
        print( f"TOKEN STILL VALID, AGE: {elapsed/60.0} MINUTES" )

# %%
check_API_token()
# Out:
# TOKEN OBTAINED

# %% [markdown]
# ## Playlists

# %%
playlist = {
    # 'Sunset'  : "0keOSCLGajpgaLgQ4UubFr",
    # 'Melt'    : "5y0FUGKZzuDQMLo2hDjNPQ",
    'Faves'   : "1orrdNx6XLlaSQV7Cmr967",
    # 'study03' : "3o3lN2qntdEV7UKTuuC77K",
    # 'study04' : "41sFSisljvBDMBXtpp5NIw",
    # 'study05' : "02iS5AFGp8YVuUUqcQf8ys",
    # 'study06' : "6KI7A4MWrSM7EyKRUjxIi1",
    # 'study07' : "3V055Md2JdrUT8tX0af7di",
    # 'study08' : "0tspdJlwSgiyf2O9PO6QaP",
    # 'study09' : "5mHRBFoQtYy2izeZ66pG95",
    # 'study10' : "3832xeKGEOAXFJqE4K8kIq",
    # 'study11' : "65MXR4dubPL9t0P4dgTWvn",
    # 'study12' : "0ecSAfnD4CulIVnLt26ukI",
    # 'study13' : "7K9ucByFRgDuZk8KMHeJkL",
}

review = {
    'tryouts' : "5Ir4Xlq8vUjpr7LrIv4ltf",
    # 'ze_Over' : "6SqlfurCBP7eeMOojaDNtS",
    # 'zf_Over' : "5TtKaKCouyJp7Hhtu4YlYm",
    # 'zg_Over' : "5qX1Tq3IQ74iSgrlMfRhty",
}

backfill = review['tryouts']

# %% [markdown]
# ## Session Database

# %% [markdown]
# * FILTER TYPES: {'album', 'artist', 'track', 'year', 'upc', 'tag:hipster', 'tag:new', 'isrc', 'genre',}
# * SEARCH TYPES: {"album", "artist", "playlist", "track", "show", "episode", "audiobook",}

# %%
##### Session Database Params #####
_MOD_T_DAY_S  = 60.0 * 60 * 24
_STALE_TIME_S = _MOD_T_DAY_S * 31
_MIN_LEN_S    = 60.0 + 45.0
_DATA_DIR     = "data/"
_DATA_PREFIX  = "Teo-Music-Data_"
_DATA_POSTFIX = ".pkl"
_NULL_GENRE   = "Music"

# %%
##### Init Session Database #####
data = {
    'time'     : now()  , # Data Structure Creation Time
    'playlists': dict() , # Study Playlist Info
    'collectID': set([]), # Currently accepted track IDs
    'review'   : dict() , # Review Playlist Info
    'reviewID' : set([]), # Previously reviewed track IDs
    'artists'  : dict() , # Study Artist Info
    'queries'  : dict() , # Queries made during music searches
    'genres'   : dict() , # Study Genre Info
    # 2024-08-11: Track info does NOT contain play count
}
# Pre-emptively Name Session File #
timestamp = datetime.now().strftime( '%Y-%m-%dT%H:%M:%S' )
outFilNam = _DATA_PREFIX + timestamp + _DATA_POSTFIX
outPath   = os.path.join( 'data/', outFilNam )

# %% [markdown]
# ## Settings

# %%
## General Params ##
_N_BKFL = 200

## Search 01 Params ##
_N_MAX_SEARCH = 50
_N_DEF_SEARCH = 10
_YEAR_PADDING =  5

## DBSCAN Params ##
_DBS_EPSILON  =  0.500 # 0.200 # 0.300 # 0.400 # 0.500 # 0.750
_DBS_MIN_MMBR =  4

## Mini-Genre Params ##
_MRG_D_FACTOR =  1.5 # 1.0 # 2.0 #3.0
_MIN_GNR_MMBR = 15
_ONE_BILLION  = 1e9

## Query History Keys ##
_NU_REL_Q_KEY = "NewReleases:Albums" # Query Key for New Releases
_FEAT_PL_Q_KY = "Featured:Playlists" # Query Key for Featured Playlists
_ART_Q_PREFIX = "ArtistTopTracks:" # - Query Key Prefix for Artist Top Tracks

## Vector Representation ##
_V_NUM_FEATURES  = 10
_V_SPEECH_FACTOR =  (1.0/0.3724) * (2.0/3.0) * (2.0/3.0)
_V_INSTR_FACTOR  =  1.0 * 5.0
_V_ACOUST_FACTOR =  1.0
_V_DANCE_FACTOR  =  1.0 / 0.8701 * 5.0
_V_DURATN_FACTOR =  1.0 / 1000.0 / _MIN_LEN_S * 2.0 / 18.7821619
_V_ENERGY_FACTOR =  1.0
_V_LIVENS_FACTOR =  1.0 /  0.9173
_V_LOUDNS_FACTOR =  1.0 / 38.53 * 1.25
_V_TEMPO_FACTOR  =  1.0 / (174.331-45.7) * (3.0/4.0)
_V_VALENC_FACTOR =  1.0 * 3.0

# %%
_SKIP_GENRE_BUILD = False
_SKIP_GENRE_MERGE = False

# %% [markdown]
# # Query Functions

# %%
def get_playlist_length( playlist_ID ):
    """ Get the number of total tracks in the playlist """
    response = spot.user_playlist_tracks(
        CLIENT_ID, 
        playlist_ID, 
        fields = 'items,uri,name,id,total', 
        limit  = _RESPONSE_LIMIT
    )
    return response['total']
    

def fetch_entire_playlist( playlist_ID ):
    """ Get infodump on all plalist tracks """
    plTracks = []
    trCount  = 0
    response = spot.user_playlist_tracks(
        CLIENT_ID, 
        playlist_ID, 
        fields = 'items,uri,name,id,total', 
        limit  = _RESPONSE_LIMIT
    )
    Ntracks = response['total']
    while 1:
        trCount += len(response['items'])
        plTracks.extend( response['items'] )
        
        if trCount >= Ntracks:
            break
    
        response = spot.user_playlist_tracks(
            CLIENT_ID, 
            playlist_ID, 
            fields = 'items,uri,name,id,total', 
            limit  = _RESPONSE_LIMIT,
            offset = trCount
        )
    return plTracks


def update_music_database( db, fDb ):
    """ Update the database without overwriting important info """
    
    db['playlists'].update( fDb['playlists'] )
    
    db['collectID'] = db['collectID'].union( fDb['collectID'] )
    
    db['review'].update( fDb['review'] )
    
    db['reviewID'] = db['reviewID'].union( fDb['reviewID'] )

    for artID, artDct in fDb['artists'].items():
        dct_i = dict()
        dct_i.update( artDct )
        if artID in db['artists']:
            dct_i.update( db['artists'][ artID ] )
            dct_i['releases'] = artDct['releases']
            dct_i['releases'].extend( db['artists'][ artID ]['releases'] )
        db['artists'][ artID ] = dct_i

    for query in fDb['queries']:
        db['queries'][ query ] = db['queries'].get( query, 0 ) + fDb['queries'][ query ]

    db['genres'].update( fDb['genres'] )
    

def load_music_database( dataDir = _DATA_DIR, forceLoad = False ):
    """ Find the latest music database, test for freshness, and set current db if fresh """
    global data
    dbFiles = [os.path.join( dataDir, f ) for f in os.listdir( dataDir ) if (_DATA_PREFIX in str(f))]
    if len( dbFiles ):
        dbFiles.sort( reverse = True )
        with open( dbFiles[0], 'rb' ) as f:
            db = pickle.load( f )
        if (((data['time'] - db['time']) <= _STALE_TIME_S) or forceLoad):
            
            # data.update( db )
            update_music_database( data, db )
            
            print( f"Loaded {dbFiles[0]}!" )
            return dbFiles[0]
        else:
            print( f"File {dbFiles[0]} was STALE by {(data['time']-db['time']-_STALE_TIME_S)/_MOD_T_DAY_S} days!" )
    return None


def save_music_database( dataDct ):
    """ Pickle `dataDct` to store current music collection data as well as search activity """
    print( f"About to write {outPath} ..." )
    with open( outPath, 'wb' ) as f:
        pickle.dump( dataDct, f )
    print( "COMPLETE!" )


def populate_playlist_data( dataDct, plDict, pause_s = 1.0 ):
    """ Gather data across specified playlists """
    print( "\n### READ MUSIC COLLECTION ###\n" )
    nuDB = load_music_database()
    if nuDB is not None:
        print( f"Found current collection data at {nuDB}!" )
    else:
        for plName_i, plID_i in plDict.items():
            print( plName_i, '-', plID_i, '...' )
            dataDct['playlists'][ plName_i ] = {
                'ID'    : plID_i,
                'tracks': fetch_entire_playlist( plID_i ),
            }
            
            plSet_i = set([item['track']['id'] for item in dataDct['playlists'][ plName_i ]['tracks']])
            dataDct['collectID'] = dataDct['collectID'].union( plSet_i )
    
            for track_j in dataDct['playlists'][ plName_i ]['tracks']:
    
                for artist_k in track_j['track']['artists']:
                    artistID_j = artist_k['id']
                    if artistID_j not in dataDct['artists']:
                        dataDct['artists'][ artistID_j ] = { 
                            'name'    : track_j['track']['artists'][0]['name'], 
                            'count'   : 1, 
                            'releases': [track_j['track']['album']['release_date'],], 
                        }
                    else:
                        dataDct['artists'][ artistID_j ]['count'   ] += 1
                        dataDct['artists'][ artistID_j ]['releases'].append( track_j['track']['album']['release_date'] )
    
            sleep( pause_s )
    
    print( "\n### COMPLETE ###\n" )

# %% [markdown]
# # Search Version 01, Query by Existing Artist and Year

# %%
def search_artist_within_era( artistName, releaseDate, 
                              db = None, N = _N_MAX_SEARCH, yearPadding = _YEAR_PADDING, pause_s = 0.5 ):
    """ Return `N` tracks within `yearPadding` of `trackDict` and by the same artist """
    rtnLs = list()
    query = "artist%3A" + str( artistName ).replace( " ", "%20")
    try:
        rYear = int( str( releaseDate )[:4] )
    except Exception:
        rYear = 2024
    bYear   = rYear - yearPadding
    eYear   = rYear + yearPadding
    years   = list( range( bYear, eYear+1 ) )
    miniLim = max( int(N/(eYear - bYear)), 1 )
    Nloop   = int(N / miniLim * 2)
    for i in range( Nloop ):
        iYear = choice( years )
        qry_i = query + "%20year%3A" + str( iYear )
        print( f"Search: {qry_i}" )

        if (db is not None):
            if (qry_i in db['queries']):
                ofst = db['queries'][ qry_i ]
                db['queries'][ qry_i ] += miniLim
            else:
                ofst = 0
                db['queries'][ qry_i ] = miniLim
        else:
            ofst = 0
        
        res = spot.search( qry_i, 
                           limit  = miniLim, 
                           offset = min( ofst, _MAX_OFFSET ), 
                           type   = 'track' )
        sleep( pause_s )
        
        # tracks_i = [item['id'] for item in res['tracks']['items']]
        tracks_i = res['tracks']['items']
        
        if (db is not None):
            tracks_ii = list()
            for trk_j in tracks_i:
                if trk_j['id'] not in db['collectID']:
                    tracks_ii.append( trk_j )
            tracks_i = tracks_ii[:]

        rem = N - len( rtnLs )
        if len( tracks_i ) > rem:
            rtnLs.extend( tracks_i[:rem] )
            return rtnLs
        else:
            rtnLs.extend( tracks_i )
            # sleep( pause_s )
    return rtnLs


def choose_N_artist_year_pairs_from_db( N, db ):
    """ Fetch `N` random (<Artist>, <Date>) pairs from the `db` for searching """
    rtnPairs = list()
    artList  = list( db['artists'].keys() )
    print( f"How Many Artists?: {len(artList)}" )
    for i in range(N):
        artKey_i = choice( artList )
        artist_i = db['artists'][ artKey_i ]['name']
        rlYear_i = choice( db['artists'][ artKey_i ]['releases'] ) if len( db['artists'][ artKey_i ]['releases'] ) else '2024'
        rtnPairs.append( (artist_i, rlYear_i,) )
    return rtnPairs


def basic_new_music_search_01( db, Ntot, Mper = 5, pause_s = 0.125 ):
    """ Choose random `db` entries as search queries, Return a list of `Ntot` tracks consisting of `Mper` entries for each artist """  
    rtnLst   = list()
    searches = choose_N_artist_year_pairs_from_db( int( ceil( Ntot/Mper ) )*2, db )
    addSet   = set([])
    for (art_i, rel_i) in searches:
        print( f"\tSearch, Artist: {art_i}, Around Year: {rel_i}" )
        rem    = Ntot - len( rtnLst )
        Mper   = min( Mper, rem )
        trks   = search_artist_within_era( art_i, rel_i, db, N = Mper, yearPadding = 3, pause_s = 0.5 )
        trks_i = list()
        for trk in trks:
            if trk['id'] not in addSet:
                trks_i.append( trk )
                addSet.add( trk['id'] )
        rem = Ntot - len( rtnLst )
        if rem > len( trks_i ):
            rtnLst.extend( trks_i )
        else:
            rtnLst.extend( trks_i[ :rem ] )
            break
        sleep( pause_s )
        check_API_token()
    return rtnLst


def refill_playlist_with_new_tracks( plID, db, Ntot = 400, Mper = 5 ):
    """ Top off the playlist with new tracks """
    plLen = get_playlist_length( plID )
    if Ntot > plLen:
        nRem    = Ntot - plLen
        print( f"About to add {nRem} tracks ..." )
        addTrks = basic_new_music_search_01( db, nRem, Mper )
        result  = spot.user_playlist_add_tracks( CLIENT_ID, plID, addTrks )
        print( result )
    else:
        print( "No room for new tracks!" )


def scrub_short_and_explicit_tracks( plID ):
    """ Remove short (<1:45) and explicit (guaranteed vocal) songs """
    tracks = fetch_entire_playlist( plID )

    # 3. For every track j in playlist, do
    j = 0
    while j < len( tracks ):
        track_j   = tracks[j]
        # pprint( track_j )
        # break
        p_dump_j  = False
        trackID_j = track_j['track']['id']
        len_s_j   = track_j['track']['duration_ms']/1000.0
        explc_j   = track_j['track']['explicit']

        if ((len_s_j < _MIN_LEN_S) or explc_j):
            res = spot.playlist_remove_specific_occurrences_of_items( 
                plID, 
                [{'uri': trackID_j, 'positions':[j,]},]
            )
            print( "\tRemove:", trackID_j, j, res )
            tracks.pop(j)
        else:
            j += 1


def scrub_and_refill_playlist_with_new_tracks( plID, db, Ntot = 400, Mper = 5, pause_s = 1.0 ):
    """ Remove suspect tracks and refill backfill in a loop until full """
    scrub_short_and_explicit_tracks( plID )
    plLen = get_playlist_length( plID )
    if Ntot > plLen:
        print( f"\n########## About to top off backfill with {Ntot-plLen} tracks! ##########\n" )
        i = 0
        while plLen < Ntot:
            i += 1
            sleep( pause_s )
            print( f"\n##### Iteration {i} #####\n" )
            refill_playlist_with_new_tracks( plID, db, Ntot, Mper )
            scrub_short_and_explicit_tracks( plID )
            plLen = get_playlist_length( plID )
            
        print( f"\n########## COMPLETE after {i} iterations! ##########\n" )
    else:
        print( f"\n########## NO additional backfill required! ##########\n" )

# %% [markdown]
# # Helper Functions

# %%
########## CONTAINER FUNCTIONS #####################################################################

def sort_keys_by_value( dct, reverse = True ):
    """ Return a list of keys sorted by their (numeric) values """
    srtLst = list()
    for k, v in dct.items():
        srtLst.append( [v,k,] )
    srtLst.sort( key = lambda x: x[0], reverse = reverse )
    return [pair[1] for pair in srtLst] 



########## STRING ANALYSIS #########################################################################

def levenshtein_dist( s1, s2 ):
    """ Get the edit distance between two strings """
    # Author: Salvador Dali, https://stackoverflow.com/a/32558749
    if len(s1) > len(s2):
        s1, s2 = s2, s1
    distances = range(len(s1) + 1)
    for i2, c2 in enumerate(s2):
        distances_ = [i2+1]
        for i1, c1 in enumerate(s1):
            if c1 == c2:
                distances_.append(distances[i1])
            else:
                distances_.append(1 + min((distances[i1], distances[i1 + 1], distances_[-1])))
        distances = distances_
    return distances[-1]



########## STATS & SAMPLING ########################################################################


def total_pop( odds ):
    """ Sum over all categories in the prior odds """
    total = 0
    for k in odds:
        total += odds[k]
    return total


def normalize_dist( odds_ ):
    """ Normalize the distribution so that the sum equals 1.0 """
    total  = total_pop( odds_ )
    rtnDst = dict()
    for k in odds_:
        rtnDst[k] = odds_[k] / total
    return rtnDst


def roll_outcome( odds ):
    """ Get a random outcome from the distribution """
    oddsNorm = normalize_dist( odds )
    distrib  = []
    outcome  = []
    total    = 0.0
    for o, p in oddsNorm.items():
        total += p
        distrib.append( total )
        outcome.append( o )
    roll = random()
    for i, p in enumerate( distrib ):
        if roll <= p:
            return outcome[i]
    return None

# %% [markdown]
# # Mini-Genre Extraction

# %%
def fetch_entire_playlist_with_audio_features( playlist_ID, pause_s = 1.00 ):
    """ Get maximum infodump on all playlist tracks """

    plTracks = []
    Ntracks  = get_playlist_length( playlist_ID )
    trCount  = 0
    trOffst  = 0

    while trCount < Ntracks:

        lim = min( _RESPONSE_LIMIT, Ntracks-trCount )

        response = spot.user_playlist_tracks(
            CLIENT_ID, 
            playlist_ID, 
            fields = 'items,uri,name,id,total', 
            limit  = lim,
            offset = trCount
        )
        sleep( pause_s )

        trCount  += len( response['items'] )
        resTracks = response['items']
        resIDs    = list()
        gudTracks = list()
        
        for item in resTracks:
            id_i = item['track']['id']
            if id_i is not None:
                resIDs.append( id_i )
                gudTracks.append( item )

        # resIDs = [item for item in resIDs if (item is not None)]

        if None in resIDs:
            print( "BAD ID: NONE" )

        resFeatrs = None
        while resFeatrs is None:
            resFeatrs = spot.audio_features( resIDs )
            sleep( pause_s )

        for i, track_i in enumerate( gudTracks ):
            track_i.update( resFeatrs[i] )
            if (i%20==0):
                print( '.', end='', flush=True )
        

        plTracks.extend( gudTracks )
    print()
    return plTracks


def get_track_vector( track ):
    """ Express the track characteristics as a vector """
    return np.array([
        track['speechiness'] * _V_SPEECH_FACTOR,
        track['instrumentalness'] * _V_INSTR_FACTOR,
        track['acousticness'] * _V_ACOUST_FACTOR,
        track['danceability'] * _V_DANCE_FACTOR,
        track['duration_ms'] * _V_DURATN_FACTOR,
        track['energy'] * _V_ENERGY_FACTOR,
        track['liveness'] * _V_LIVENS_FACTOR,
        track['loudness'] * _V_LOUDNS_FACTOR,
        (track['tempo']-45.7) * _V_TEMPO_FACTOR,
        track['valence'] * _V_VALENC_FACTOR,
    ])


def get_tracks_as_vectors( tracks ):
    """ Convert all tracks to vectors """
    Mrows  = len( tracks )
    if Mrows > 0:
        Ncols  = len( get_track_vector( tracks[0] ) )
        rtnMtx = np.zeros( (Mrows, Ncols,) ) 
        for i, trk in enumerate( tracks ):
            rtnMtx[i,:] = get_track_vector( trk )
        return rtnMtx
    else:
        return list()


def vector_distance_to_genre( qVec, genreDct ):
    """ Get Euclidean distance between `qVec` and the nearest track vector of `genreDct` """
    return genreDct['kdTree'].query( qVec )[0]
    

def track_distance_to_genre( qTrack, genreDct ):
    """ Get Euclidean distance between `qTrack` and the nearest track vector of `genreDct` """
    return vector_distance_to_genre( get_track_vector( qTrack ), genreDct )


def assign_vectors_to_tracks( tracks ):
    """ Store vector info in each track dictionary """
    matxTrks = get_tracks_as_vectors( tracks )
    for i, vec_i in enumerate( matxTrks ):
        trk_i = tracks[i]
        trk_i['vector'] = vec_i
    print( f"Stored vectors for {len(tracks)} tracks!" )


def fetch_collection_with_audio_features( dataDct, plDct, rvDct = None, pause_s = 3.0, renewSets = True ):
    """ Get maximum infodump on all playlists """

    if renewSets:
        dataDct['collectID'] = set([])
    
    print( "##### Get Collection Data #####" )
    for plName_i, plID_i in plDct.items():
        print( plName_i, '-', plID_i, '...' )
        tracks_i = fetch_entire_playlist_with_audio_features( plID_i )
        assign_vectors_to_tracks( tracks_i )
        dataDct['playlists'][ plName_i ] = {
            'ID'    : plID_i,
            'tracks': tracks_i,
            'len'   : len( tracks_i ),
        }
        dataDct['collectID'] = dataDct['collectID'].union( set([trk['track']['id'] for trk in tracks_i]) )

        # Catalog artists from collection tracks (Req'd for (Sub-)Search 01)
        for track_j in tracks_i:
            for artist_k in track_j['track']['artists']:
                artistID_j = artist_k['id']
                if artistID_j not in dataDct['artists']:
                    dataDct['artists'][ artistID_j ] = { 
                        'name'    : track_j['track']['artists'][0]['name'], 
                        'count'   : 1, 
                        'releases': [track_j['track']['album']['release_date'],], 
                    }
                else:
                    dataDct['artists'][ artistID_j ]['count'   ] += 1
                    dataDct['artists'][ artistID_j ]['releases'].append( track_j['track']['album']['release_date'] )
        
        sleep( pause_s )

    if rvDct is not None:
        print( "\n##### Get Review Data #####" )
        for plName_i, plID_i in rvDct.items():
            print( plName_i, '-', plID_i, '...' )
            tracks_i = fetch_entire_playlist_with_audio_features( plID_i )
            assign_vectors_to_tracks( tracks_i )
            dataDct['review'][ plName_i ] = {
                'ID'    : plID_i,
                'tracks': tracks_i,
                'len'   : len( tracks_i ),
            }
            dataDct['reviewID'] = dataDct['reviewID'].union( set([trk['track']['id'] for trk in tracks_i]) )
            sleep( pause_s )

    print( "\n##### Complete #####" )


def analyze_db_vector_spread( db ):
    """ Gather info for feature scaling and print it for manual scaling update """
    rtnMatx = np.ones( (2, _V_NUM_FEATURES,) )
    rtnMatx[0,:] *=  1e6
    rtnMatx[1,:] *= -1e6
    totlDct = dict()
    totlDct.update( db['playlists'] )
    totlDct.update( db['review'   ] )
    for plName_i, playls_i in totlDct.items():
        if len( playls_i['tracks'] ):
            matx_i = get_tracks_as_vectors( playls_i['tracks'] )
            mMin_i = np.min( matx_i, axis = 0 )
            mMax_i = np.max( matx_i, axis = 0 )
            for j in range( _V_NUM_FEATURES ):
                if mMin_i[j] < rtnMatx[0,j]:
                    rtnMatx[0,j] = mMin_i[j]
                if mMax_i[j] > rtnMatx[1,j]:
                    rtnMatx[1,j] = mMax_i[j]
    for j in range( _V_NUM_FEATURES ):
        print( f"Feature {j+1}, Span: {rtnMatx[1,j] - rtnMatx[0,j]}, Min: {rtnMatx[0,j]}" )
    return rtnMatx

# %%
# load_music_database( forceLoad = 1 );
fetch_collection_with_audio_features( data, playlist, review, pause_s = 3.0 )
analyze_db_vector_spread( data );
save_music_database( data )
# Out:
# ##### Get Collection Data #####
# Faves - 1orrdNx6XLlaSQV7Cmr967 ...
# ..............................................................................................................................................................................................................
# Stored vectors for 4112 tracks!
#
# ##### Get Review Data #####
# tryouts - 5Ir4Xlq8vUjpr7LrIv4ltf ...
#
# Stored vectors for 0 tracks!
#
# ##### Complete #####
# Feature 1, Span: 0.9927198949755339, Min: 0.02768826828977204
# Feature 2, Span: 4.8, Min: 0.0
# Feature 3, Span: 0.9949795, Min: 2.05e-05
# Feature 4, Span: 5.1419377083093885, Min: 0.4263877715205148
# Feature 5, Span: 0.9013750130953472, Min: 0.044297350029764156
# Feature 6, Span: 0.97717, Min: 0.00883
# Feature 7, Span: 1.0538537010792541, Min: 0.016679385152076745
# Feature 8, Span: 1.023780171295095, Min: -1.069199325201142
# Feature 9, Span: 1.0354035963336987, Min: -0.028255241737994756
# Feature 10, Span: 2.8737000000000004, Min: 0.10830000000000001
# About to write data/Teo-Music-Data_2024-09-04T15:37:44.pkl ...
# COMPLETE!

# %%
def remove_disallowed_entries_by_key( dct ):
    """ Remove segments unsuitable for a genre name """
    # 2024-09-02: THERE ARE RACIAL SLURS IN THE PyEnchant MODULE! WHY?!? (Also: HITLER)
    blocked = ['soundtrack', 'for', 'nigger', 'gypsy', 'Hitler',] 
    qKeys   = list( dct.keys() )
    qLen    = len( qKeys )
    delSet  = set([])
    difFrac = 0.25
    for i, k in enumerate( qKeys ):
        kLo     = str(k).lower()
        removed = False
        # Remove short keys
        if (len( kLo.strip() ) <= 2) and (k in dct):
            del dct[k]
            removed = True
        # Remove keys with apostrophees
        elif ("'" in kLo) and (k in dct):
            del dct[k]
            removed = True
        # Remove keys too similar to the blocked list
        else:
            for blkd in blocked:
                if ((levenshtein_dist( kLo, blkd ) / len( blkd )) < difFrac) and (k in dct):
                    del dct[k]
                    removed = True
                    break
        # If the current key is suitable, Then remove all following keys that are too similar
        if not removed:
            for j in range( i+1, qLen ):
                key_j    = qKeys[j]
                key_jLo  = str( key_j ).lower()
                fracRght = levenshtein_dist( kLo, key_jLo ) / len( key_jLo )
                fracLeft = levenshtein_dist( kLo, key_jLo ) / len( kLo     )
                if (fracRght < difFrac) or (fracLeft < difFrac):
                    if key_j in dct:
                        del dct[ key_j ]
                        

def repair_keys( dct ):
    """ Replace keys that have characters we don't like """
    badChars = ['(', ')', ':', '"']
    dctKeys  = list( dct.keys() )
    for key in dctKeys:
        nuKey = str( key )
        p_bad = False
        for ch in badChars:
            if ch in key:
                nuKey.replace( ch, '' )
                p_bad = True
        if p_bad and (key in dct):
            dct[ nuKey ] = dct[ key ]
            del dct[ key ]


def Proper_Namify( namStr ):
    """ Capitalize every split string, and reassemble """
    namSeg = str( namStr ).split()
    Nseg   = len( namSeg )
    rtnNam = ""
    for i, seg in enumerate( namSeg ):
        rtnNam += seg[0].upper() + seg[1:].lower()
        if i+1 < Nseg:
            rtnNam += ' '
    return rtnNam
    

def extract_and_generate_genre_names( genreDct, db, pause_s = 0.25 ):
    """ Extract Spotify genre and Generate local genre """
    mainDist = dict()
    loclDist = dict()
    artSet   = set([])
    englishD = enchant.Dict( "en_US" )
    segments = list()
    # Get artist info and local genre candidate substrings
    for track in genreDct['tracks']:
        # Gather artist IDs
        for artist in track['track']['album']['artists']:
            artSet.add( artist['id'] )
            segments.extend( artist['name'].split() )
        # Gather naming strings
        segments.extend( track['track']['album']['name'].split() )
        segments.extend( track['track']['name'].split() )
    qSegmnts = segments[:]
    nglshSeg = list()
    Norig    = len( segments )
    for qSeg in qSegmnts:
        segments.extend( englishD.suggest( qSeg ) ) # https://stackoverflow.com/a/3789057
    for i, seg in enumerate( segments ):
        if i < Norig:
            value = 1.0
        else:
            value = 0.5
        if seg in loclDist:
            loclDist[ seg ] += value
        else:
            loclDist[ seg ]  = value
    
    repair_keys( loclDist )
    remove_disallowed_entries_by_key( loclDist )
    # pprint( loclDist )

    # Extract Spotify genre from the artist set
    artSetLs = list( artSet )
    Nartists = len( artSetLs )
    artQList = list()
    if Nartists <= _ARTIST_Q_LIM:
        artQList.append( artSetLs )
    else:
        bgn = 0
        end = 0
        while end < Nartists:
            bgn = end
            end = min( end+_ARTIST_Q_LIM, Nartists )
            artQList.append( artSetLs[bgn:end] )

    for qArtLs in artQList:
        nuLst = list()
        for qArtist in qArtLs:
            if (qArtist not in db['artists']):
                db['artists'][ qArtist ] = { 
                    'name'    : None, 
                    'count'   : 0, 
                    'releases': list(), 
                    'genres'  : list(), 
                }
            if ('genres' not in db['artists'][ qArtist ]):
                db['artists'][ qArtist ]['genres'] = list()
            if (len( db['artists'][ qArtist ]['genres'] ) == 0):
                nuLst.append( qArtist )

        if len( nuLst ):
            check_API_token() # 2024-09-01: WHY DOES IT KEEP FAILING HERE IT HAS NOT BEEN AN HOUR
            response = spot.artists( nuLst )
            for artist in response['artists']:
                qArtist = artist['id']
                db['artists'][ qArtist ]['name'  ] = artist['name'  ]
                db['artists'][ qArtist ]['genres'] = artist['genres']
            sleep( pause_s )

        for qArtist in qArtLs:
            for spGenre in db['artists'][ qArtist ]['genres']:
                if spGenre not in mainDist:
                    mainDist[ spGenre ]  = 1
                else:
                    mainDist[ spGenre ] += 1

    if len( mainDist ):
        topSpGenre = sort_keys_by_value( mainDist, reverse = True )[0]
    else:
        topSpGenre = _NULL_GENRE

    genreDct['nameSpot'] = topSpGenre

    loclDist = normalize_dist( loclDist )
    mainDist = normalize_dist( mainDist )
    genreDct['nameDist'] = mainDist

    localName = ""
    namLast   = roll_outcome( mainDist )
    if namLast is None:
        namLast = "Music"
        P_last    = 1.0
        running   = True
    else:
        P_last    = mainDist[ namLast ]
        running   = (random() < P_last)
    
    localName += Proper_Namify( roll_outcome( loclDist ) ) + '-' + Proper_Namify( namLast )

    while running:
        namLast = roll_outcome( loclDist )
        P_last  = loclDist[ namLast ]
        running = random() < P_last
        localName += ' ' + Proper_Namify( namLast ) 

    genreDct['nameLocal'] = localName

    print( f"{genreDct['nameLocal']} | {genreDct['nameSpot']} | {genreDct['nameDist']}" )


def genre_vector_ops( gnre ):
    """ Calculate track vectors and properties derived from them """
    gnre['vectors'] = get_tracks_as_vectors( gnre['tracks'] )
    gnre['len']     = len( gnre['tracks'] )
    if gnre['len'] > 1:
        cntr = np.mean( gnre['vectors'], axis = 0 )
        dim  = len( cntr )
        for i in range( gnre['len'] ):
            pnt_i   = gnre['vectors'][i,:]
            dist_i  = np.linalg.norm( np.subtract( cntr, pnt_i ) )
            alpha_i = np.exp( -dist_i )
            cntr    = cntr * (1.0 - alpha_i) + pnt_i * alpha_i
        gnre['center'] = cntr # 2024-08-16: This is probably guaranteed to be inside the convex hull
        gnre['kdTree'] = cKDTree( gnre['vectors'], balanced_tree = False, compact_nodes = False )
    elif gnre['len'] > 0:
        gnre['center'] = gnre['vectors'][0]
        gnre['kdTree'] = cKDTree( gnre['vectors'], balanced_tree = False, compact_nodes = False )
    else:
        gnre['center'] = None
        gnre['kdTree'] = None
    

def generate_genres_from_track_list( tracks, db ):
    """ Use DBSCAN to generate clusters based on track vectors, Give them names, Then return as a `dict` """
    # NOTE: This function assumes that `tracks` was built using `fetch_entire_playlist_with_audio_features`                

    print( f"\n########## Extract genre info from {len(tracks)} tracks! ##########\n" )

    ### Compute Clusters ###
    trkVecs = get_tracks_as_vectors( tracks )
    clustrs = DBSCAN( eps = _DBS_EPSILON, min_samples = _DBS_MIN_MMBR ).fit( trkVecs )
    genres  = dict()
    for i, trk_i in enumerate( tracks ):
        lbl_i = clustrs.labels_[i]
        if (lbl_i not in genres):
            genres[ lbl_i ] = {
                'nameSpot' : None, # --- Most prominent Spotify genre across all artists
                'nameDist' : None, # --- Discrete distribution of Spotify genre across all artists
                'nameLocal': None, # --- Humorous (semi-)unique name given to micro-genre
                'tracks'   : [trk_i,], # Tracks that belong to this micro-genre
                'len'      : 1, # ------ Number of identified tracks in the micro-genre
                'vectors'  : None, # --- Vector representation of the tracks
                'origins'  : list(), # Playlist(s) that tracks come from
            }
        else:
            genres[ lbl_i ]['tracks'].append( trk_i )
            genres[ lbl_i ]['len'   ] += 1

    # Erase outliers
    if -1 in genres:
        del genres[-1]
    print( f"Identified {len(genres)} genres in this collection of {len(tracks)} tracks!" )
    # Generate unique keys for genres
    rtnGenres = dict()
    for k, v in genres.items():
        rtnGenres[ str( uuid4() ) ] = v

    ### Compute Center and kdTree for genre ###
    for gnre in rtnGenres.values():
        genre_vector_ops( gnre )

        # Generate micro-genre names {Spotify, Distribution, Local}
        extract_and_generate_genre_names( gnre, db )
    
    print( f"\n########## Genre extraction COMPLETE! ##########\n" )

    return rtnGenres


def extract_micro_genres_from_collection( dataDct, eraseExisting = True ):
    """ Extract and merge micro-genres from the entire collection defined by `dataDct` """

    if eraseExisting:
        dataDct['genres'] = dict()
    
    for plName_i, playls_i in dataDct['playlists'].items():
        print( f"\n### Playlist: {plName_i}, {playls_i['ID']} ###\n" )
        bgn_i    = now()
        tracks_i = playls_i['tracks']
        N_trks_i = len( tracks_i )
        bgn      = 0
        end      = 0
        while end < N_trks_i:
            bgn     = end
            end     = min( end+_N_BKFL, N_trks_i )
            print( f"\n## Chunk[ {bgn}:{end} ] ##\n" )
            
            gnres_i = generate_genres_from_track_list( tracks_i[ bgn:end ], dataDct )
            
            for gnre_j in gnres_i.values():
                gnre_j['origins'] = [playls_i['ID'],]
                
            dataDct['genres'].update( gnres_i )
            check_API_token() # 2024-08-21: This process can take a while on my home machine
            
        dur_i = now() - bgn_i
        print( f"\nGenre generation from {plName_i} took {dur_i} seconds!\n" )

# %% [markdown]
# ## Micro-Genre Creation

# %%
# if not _SKIP_GENRE_BUILD:
extract_micro_genres_from_collection( data )
# Out:
# TOKEN OBTAINED
# TOKEN STILL VALID, AGE: 0.04200683037439982 MINUTES
# Oder-Dance Pop | soul | {'blues rock': 0.004901960784313725, 'classic canadian rock': 0.004901960784313725, 'classic rock': 0.00980392156862745, 'cosmic american': 0.004901960784313725, 'country rock': 0.004901960784313725, 'folk': 0.00980392156862745, 'folk rock': 0.004901960784313725, 'heartland rock': 0.004901960784313725, 'jam band': 0.00980392156862745, 'mellow gold': 0.004901960784313725, 'rock': 0.00980392156862745, 'roots rock': 0.00980392156862745, 'southern rock': 0.004901960784313725, 'swamp rock': 0.004901960784313725, 'album rock': 0.004901960784313725, 'british invasion': 0.004901960784313725, 'neo soul': 0.00980392156862745, 'alternative r&b': 0.0196078431372549, 'indie soul': 0.0196078431372549, 'nyc pop': 0.00980392156862745, 'alternative americana': 0.00980392156862745, 'greek downtempo': 0.004901960784313725, 'louisiana blues': 0.004901960784313725, 'new orleans blues': 0.004901960784313725, 'new orleans funk': 0.004901960784313725, 'new orleans soul': 0.004901960784313725, 'southern soul': 0.0196078431372549, 'dance pop': 0.0196078431372549, 'hip hop': 0.00980392156862745, 'hip pop': 0.00980392156862745, 'pop rap': 0.014705882352941176, 'r&b': 0.014705882352941176, 'rap': 0.00980392156862745, 'urban contemporary': 0.00980392156862745, 'virginia hip hop': 0.004901960784313725, 'indietronica': 0.004901960784313725, 'metropopolis': 0.00980392156862745, 'chill r&b': 0.004901960784313725, 'modern psychedelic folk': 0.004901960784313725, 'alt z': 0.00980392156862745, 'electropop': 0.014705882352941176, 'gauze pop': 0.004901960784313725, 'indie poptimism': 0.00980392156862745, 'reggae fusion': 0.004901960784313725, 'alternative country': 0.004901960784313725, 'british soul': 0.004901960784313725, 'pop': 0.014705882352941176, 'pop soul': 0.014705882352941176, 'uk pop': 0.00980392156862745, 'smooth jazz': 0.004901960784313725, 'classic soul': 0.024509803921568627, 'funk': 0.0196078431372549, 'motown': 0.00980392156862745, 'quiet storm': 0.00980392156862745, 'soul': 0.029411764705882353, 'asheville indie': 0.004901960784313725, 'bubblegrunge': 0.004901960784313725, 'indie pop': 0.0196078431372549, 'jazz funk': 0.004901960784313725, 'modern alternative pop': 0.00980392156862745, 'stl indie': 0.004901960784313725, 'modern indie pop': 0.00980392156862745, 'pop rock': 0.00980392156862745, 'post-grunge': 0.00980392156862745, 'uk contemporary r&b': 0.00980392156862745, 'afrofuturism': 0.00980392156862745, 'post-teen pop': 0.004901960784313725, 'pov: indie': 0.024509803921568627, 'swedish americana': 0.004901960784313725, 'swedish singer-songwriter': 0.004901960784313725, 'art pop': 0.00980392156862745, 'chamber pop': 0.004901960784313725, 'indie rock': 0.004901960784313725, 'melancholia': 0.004901960784313725, 'new jersey indie': 0.004901960784313725, 'singer-songwriter': 0.004901960784313725, 'alternative pop rock': 0.004901960784313725, 'english indie rock': 0.00980392156862745, 'liverpool indie': 0.004901960784313725, 'experimental pop': 0.00980392156862745, 'uk alternative pop': 0.00980392156862745, 'black americana': 0.004901960784313725, 'new americana': 0.004901960784313725, 'uk americana': 0.004901960784313725, 'aussietronica': 0.004901960784313725, 'bedroom soul': 0.00980392156862745, 'vancouver indie': 0.004901960784313725, 'memphis soul': 0.014705882352941176, 'soul blues': 0.00980392156862745, 'retro soul': 0.004901960784313725, 'alternative rock': 0.004901960784313725, 'grunge': 0.004901960784313725, 'french psychedelic': 0.004901960784313725, 'funk rock': 0.004901960784313725, 'p funk': 0.004901960784313725, 'disco': 0.00980392156862745, 'girl group': 0.004901960784313725, 'hi-nrg': 0.00980392156862745, 'new wave pop': 0.00980392156862745, 'soft rock': 0.00980392156862745, 'broken beat': 0.004901960784313725, 'instrumental hip hop': 0.004901960784313725, 'indie garage rock': 0.004901960784313725, 'norman ok indie': 0.004901960784313725, 'tulsa indie': 0.004901960784313725, 'indie quebecois': 0.004901960784313 ...
# TOKEN STILL VALID, AGE: 0.061512887477874756 MINUTES
# Might-Modern Rock | modern rock | {'modern rock': 0.125, 'north east england indie': 0.125, 'australian rock': 0.125, 'hard rock': 0.125, 'rock': 0.125, 'austin rock': 0.125, 'austindie': 0.125, 'neo-psychedelic': 0.125}
# TOKEN STILL VALID, AGE: 0.0815185268719991 MINUTES
# Hook-Singer-songwriter Pop | indie pop | {'indie pop': 0.11764705882352941, 'pov: indie': 0.058823529411764705, 'vancouver indie': 0.058823529411764705, 'modern indie pop': 0.058823529411764705, 'singer-songwriter pop': 0.058823529411764705, 'experimental r&b': 0.058823529411764705, 'austindie': 0.058823529411764705, 'pop soul': 0.11764705882352941, 'british soul': 0.058823529411764705, 'pop': 0.058823529411764705, 'uk pop': 0.058823529411764705, 'indie folk': 0.058823529411764705, 'new americana': 0.058823529411764705, 'shimmer pop': 0.058823529411764705, 'stomp and holler': 0.058823529411764705}
# TOKEN STILL VALID, AGE: 0.10481966733932495 MINUTES
# Lome-Brooklyn Indie | bedroom pop | {'art pop': 0.045454545454545456, 'alt z': 0.045454545454545456, 'bedroom pop': 0.09090909090909091, 'indie pop': 0.09090909090909091, 'pov: indie': 0.045454545454545456, 'modern blues': 0.045454545454545456, 'neo soul': 0.045454545454545456, 'soul': 0.045454545454545456, 'brooklyn indie': 0.045454545454545456, 'electropop': 0.045454545454545456, 'indie poptimism': 0.045454545454545456, 'nyc pop': 0.045454545454545456, 'shimmer pop': 0.045454545454545456, 'acoustic pop': 0.045454545454545456, 'indie folk': 0.045454545454545456, 'neo mellow': 0.045454545454545456, 'stomp and holler': 0.045454545454545456, 'indie soul': 0.045454545454545456, 'neo-psychedelic': 0.045454545454545456, 'world': 0.045454545454545456}
#
# ########## Genre extraction COMPLETE! ##########
#
# TOKEN STILL VALID, AGE: 0.11055155992507934 MINUTES
#
# ## Chunk[ 3400:3600 ] ##
#
#
# ########## Extract genre info from 200 tracks! ##########
#
# Identified 2 genres in this collection of 200 tracks!
# TOKEN STILL VALID, AGE: 0.1257118542989095 MINUTES
# 40s-Modern Folk Rock | melancholia | {'alternative rock': 0.058823529411764705, 'melancholia': 0.11764705882352941, 'permanent wave': 0.058823529411764705, 'protopunk': 0.058823529411764705, 'rock': 0.058823529411764705, 'hammond organ': 0.058823529411764705, 'instrumental funk': 0.058823529411764705, 'experimental': 0.058823529411764705, 'singer-songwriter': 0.058823529411764705, 'chamber pop': 0.058823529411764705, 'indie rock': 0.058823529411764705, 'modern folk rock': 0.058823529411764705, 'philly indie': 0.058823529411764705, 'pov: indie': 0.058823529411764705, 'seattle indie': 0.058823529411764705, 'stomp and holler': 0.058823529411764705}
# TOKEN STILL VALID, AGE: 2.032634421189626 MINUTES
# TOKEN STILL VALID, AGE: 2.038985311985016 MINUTES
# TOKEN STILL VALID, AGE: 2.046380360921224 MINUTES
# Mai-Urban Contemporary | singer-songwriter | {'album rock': 0.006349206349206349, 'classic rock': 0.01904761904761905, 'country rock': 0.01904761904761905, 'folk rock': 0.009523809523809525, 'mellow gold': 0.015873015873015872, 'rock': 0.012698412698412698, 'singer-songwriter': 0.02857142857142857, 'soft rock': 0.012698412698412698, 'yacht rock': 0.006349206349206349, 'pov: indie': 0.0031746031746031746, 'stomp and holler': 0.0031746031746031746, 'alternative r&b': 0.022222222222222223, 'heartland rock': 0.006349206349206349, 'permanent wave': 0.006349206349206349, 'contemporary r&b': 0.012698412698412698, 'neo soul': 0.015873015873015872, 'new jack swing': 0.009523809523809525, 'atl hip hop': 0.0031746031746031746, 'conscious hip hop': 0.0031746031746031746, 'hip hop': 0.0031746031746031746, 'old school atlanta hip hop': 0.0031746031746031746, 'indie soul': 0.0031746031746031746, 'la pop': 0.009523809523809525, 'acoustic blues': 0.009523809523809525, 'blues': 0.009523809523809525, 'country blues': 0.0031746031746031746, 'delta blues': 0.0031746031746031746, 'traditional blues': 0.009523809523809525, 'british soul': 0.006349206349206349, 'uk contemporary r&b': 0.0031746031746031746, 'boston rock': 0.006349206349206349, 'indie folk': 0.006349206349206349, 'new americana': 0.015873015873015872, 'rap kreyol': 0.0031746031746031746, 'electra': 0.0031746031746031746, 'r&b': 0.012698412698412698, 'urban contemporary': 0.012698412698412698, 'alternative americana': 0.0031746031746031746, 'countrygaze': 0.009523809523809525, 'american folk revival': 0.0031746031746031746, 'soul blues': 0.0031746031746031746, 'blues rock': 0.009523809523809525, 'southern rock': 0.006349206349206349, 'dance pop': 0.009523809523809525, 'pop rap': 0.0031746031746031746, 'reggae fusion': 0.0031746031746031746, 'classic soul': 0.015873015873015872, 'motown': 0.015873015873015872, 'northern soul': 0.0031746031746031746, 'quiet storm': 0.009523809523809525, 'soul': 0.02857142857142857, 'vocal jazz': 0.006349206349206349, 'disco': 0.012698412698412698, 'funk': 0.006349206349206349, 'post-disco': 0.0031746031746031746, 'southern soul': 0.009523809523809525, 'southern americana': 0.0031746031746031746, 'alternative country': 0.012698412698412698, 'modern blues': 0.009523809523809525, 'modern blues rock': 0.0031746031746031746, 'pop': 0.006349206349206349, 'dutch house': 0.0031746031746031746, 'edm': 0.0031746031746031746, 'electro house': 0.0031746031746031746, 'electronic trap': 0.0031746031746031746, 'viral trap': 0.0031746031746031746, 'bboy': 0.0031746031746031746, 'brass band': 0.0031746031746031746, 'indie pop': 0.012698412698412698, 'modern alternative pop': 0.006349206349206349, 'psychedelic folk rock': 0.0031746031746031746, 'la indie': 0.0031746031746031746, 'afro psych': 0.0031746031746031746, 'afro-funk': 0.0031746031746031746, 'modern old-time': 0.0031746031746031746, 'doo-wop': 0.0031746031746031746, 'rock-and-roll': 0.006349206349206349, 'new romantic': 0.006349206349206349, 'new wave': 0.0031746031746031746, 'new wave pop': 0.006349206349206349, 'rock independant francais': 0.0031746031746031746, 'acid rock': 0.0031746031746031746, 'african rock': 0.0031746031746031746, 'classic afrobeat': 0.0031746031746031746, 'contemporary country': 0.0031746031746031746, 'outlaw country': 0.006349206349206349, 'art pop': 0.0031746031746031746, 'chamber pop': 0.006349206349206349, 'indie rock': 0.009523809523809525, 'melancholia': 0.0031746031746031746, 'new jersey indie': 0.0031746031746031746, 'traditional soul': 0.0031746031746031746, 'dance rock': 0.0031746031746031746, 'alt z': 0.006349206349206349, 'uk pop': 0.0031746031746031746, 'dutch pop': 0.0031746031746031746, 'vocal house': 0.0031746031746031746, 'native american traditional': 0.0031746031746031746, 'new orleans funk': 0.0031746031746031746, 'second line': 0.0031746031746031746, 'gospel blues': 0.0031746031746031746, 'classic country pop': 0.0031746031746031746, 'nashville sound': 0.00317460317460 ...
#
# ########## Genre extraction COMPLETE! ##########
#
# TOKEN STILL VALID, AGE: 2.052785889307658 MINUTES
#
# ## Chunk[ 3600:3800 ] ##
#
#
# ########## Extract genre info from 200 tracks! ##########
#
# Identified 5 genres in this collection of 200 tracks!
# TOKEN STILL VALID, AGE: 3.7820629318555197 MINUTES
# TOKEN STILL VALID, AGE: 3.790637652079264 MINUTES
# Breaky-Country Rock | country | {'louisiana blues': 0.014018691588785047, 'motown': 0.004672897196261682, 'new orleans blues': 0.009345794392523364, 'piano blues': 0.009345794392523364, 'rock-and-roll': 0.009345794392523364, 'rockabilly': 0.009345794392523364, 'atl hip hop': 0.004672897196261682, 'conscious hip hop': 0.009345794392523364, 'hip hop': 0.014018691588785047, 'old school atlanta hip hop': 0.004672897196261682, 'country': 0.028037383177570093, 'country dawn': 0.004672897196261682, 'country road': 0.009345794392523364, 'contemporary country': 0.004672897196261682, 'country pop': 0.004672897196261682, 'modern country rock': 0.004672897196261682, 'austin americana': 0.004672897196261682, 'austindie': 0.004672897196261682, 'indie folk': 0.004672897196261682, 'new americana': 0.018691588785046728, 'seattle indie': 0.004672897196261682, 'stomp and holler': 0.004672897196261682, 'bboy': 0.004672897196261682, 'new orleans funk': 0.004672897196261682, 'funk': 0.009345794392523364, 'jazz funk': 0.004672897196261682, 'p funk': 0.009345794392523364, 'doo-wop': 0.004672897196261682, 'rhythm and blues': 0.014018691588785047, 'modern psychedelic folk': 0.004672897196261682, 'blues rock': 0.004672897196261682, 'electric blues': 0.018691588785046728, 'jam band': 0.009345794392523364, 'modern blues': 0.014018691588785047, 'roots rock': 0.018691588785046728, 'southern rock': 0.014018691588785047, 'alternative r&b': 0.004672897196261682, 'indie soul': 0.004672897196261682, 'southern americana': 0.009345794392523364, 'classic country pop': 0.02336448598130841, 'outlaw country': 0.014018691588785047, 'neo soul': 0.004672897196261682, 'indie pop': 0.004672897196261682, 'modern alternative pop': 0.004672897196261682, 'australian rock': 0.004672897196261682, 'classic rock': 0.009345794392523364, 'folk': 0.018691588785046728, 'folk rock': 0.014018691588785047, 'mellow gold': 0.009345794392523364, 'rock': 0.004672897196261682, 'singer-songwriter': 0.028037383177570093, 'soft rock': 0.009345794392523364, 'classic soul': 0.009345794392523364, 'northern soul': 0.009345794392523364, 'southern soul': 0.014018691588785047, 'new romantic': 0.004672897196261682, 'new wave': 0.004672897196261682, 'new wave pop': 0.009345794392523364, 'synthpop': 0.004672897196261682, 'country rock': 0.02336448598130841, 'east coast hip hop': 0.004672897196261682, 'golden age hip hop': 0.004672897196261682, 'jazz rap': 0.004672897196261682, 'nyc pop': 0.014018691588785047, 'alternative country': 0.009345794392523364, 'classic texas country': 0.009345794392523364, 'nashville sound': 0.004672897196261682, 'new orleans soul': 0.009345794392523364, 'big beat': 0.004672897196261682, 'hip house': 0.004672897196261682, 'jangle pop': 0.004672897196261682, 'paisley underground': 0.004672897196261682, 'power pop': 0.004672897196261682, 'underground power pop': 0.004672897196261682, 'afrobeat': 0.009345794392523364, 'afropop': 0.004672897196261682, 'chicha': 0.004672897196261682, 'mande pop': 0.004672897196261682, 'west african jazz': 0.004672897196261682, 'world': 0.004672897196261682, 'diva house': 0.004672897196261682, 'garage house': 0.004672897196261682, 'vocal house': 0.004672897196261682, 'rock drums': 0.004672897196261682, 'soul': 0.009345794392523364, 'ectofolk': 0.004672897196261682, 'lilith': 0.004672897196261682, 'rap': 0.004672897196261682, 'west coast rap': 0.004672897196261682, 'acid rock': 0.004672897196261682, 'psychedelic rock': 0.009345794392523364, 'jump blues': 0.004672897196261682, 'acoustic blues': 0.014018691588785047, 'blues': 0.02336448598130841, 'chicago blues': 0.014018691588785047, 'traditional blues': 0.02336448598130841, 'reggae': 0.004672897196261682, 'roots reggae': 0.004672897196261682, 'classic oklahoma country': 0.004672897196261682, 'canadian rock': 0.004672897196261682, 'modern blues rock': 0.004672897196261682, 'neo r&b': 0.004672897196261682, 'pop soul': 0.009345794392523364, 'british folk': 0.004672897196261682, 'british invasion': 0.00467 ...
# TOKEN STILL VALID, AGE: 3.8385928432146708 MINUTES
# Please-Country Rock | indie folk | {'indie folk': 0.11764705882352941, 'new americana': 0.11764705882352941, 'western americana': 0.058823529411764705, 'blues': 0.058823529411764705, 'blues rock': 0.058823529411764705, 'country rock': 0.058823529411764705, 'electric blues': 0.058823529411764705, 'modern blues': 0.058823529411764705, 'southern rock': 0.058823529411764705, 'modern blues rock': 0.058823529411764705, 'stomp and holler': 0.058823529411764705, 'bedroom soul': 0.058823529411764705, 'reggae': 0.058823529411764705, 'roots reggae': 0.058823529411764705, 'ska': 0.058823529411764705}
# TOKEN STILL VALID, AGE: 3.870436656475067 MINUTES
# Fob-Folk Mose | folk | {'blues rock': 0.027777777777777776, 'classic canadian rock': 0.027777777777777776, 'classic rock': 0.05555555555555555, 'cosmic american': 0.05555555555555555, 'country rock': 0.05555555555555555, 'folk': 0.08333333333333333, 'folk rock': 0.05555555555555555, 'heartland rock': 0.027777777777777776, 'jam band': 0.027777777777777776, 'mellow gold': 0.027777777777777776, 'rock': 0.05555555555555555, 'roots rock': 0.05555555555555555, 'southern rock': 0.027777777777777776, 'swamp rock': 0.027777777777777776, 'jazz blues': 0.027777777777777776, 'jazz piano': 0.027777777777777776, 'singer-songwriter': 0.05555555555555555, 'chamber pop': 0.027777777777777776, 'stomp and holler': 0.027777777777777776, 'acoustic blues': 0.027777777777777776, 'appalachian folk': 0.027777777777777776, 'jug band': 0.027777777777777776, 'traditional blues': 0.027777777777777776, 'traditional folk': 0.027777777777777776, 'alternative country': 0.027777777777777776, 'american folk revival': 0.027777777777777776, 'outlaw country': 0.027777777777777776}
# TOKEN STILL VALID, AGE: 3.8897754351298013 MINUTES
# Lips-Art Pop | swedish electropop | {'art pop': 0.045454545454545456, 'chillwave': 0.045454545454545456, 'downtempo': 0.045454545454545456, 'electronica': 0.045454545454545456, 'gothenburg indie': 0.045454545454545456, 'indie soul': 0.045454545454545456, 'indietronica': 0.045454545454545456, 'neo-synthpop': 0.045454545454545456, 'swedish electropop': 0.09090909090909091, 'swedish synthpop': 0.09090909090909091, 'trip hop': 0.045454545454545456, 'modern blues': 0.045454545454545456, 'neo soul': 0.045454545454545456, 'soul': 0.045454545454545456, 'pop soul': 0.045454545454545456, 'british soul': 0.045454545454545456, 'dance pop': 0.045454545454545456, 'metropopolis': 0.045454545454545456, 'pop': 0.045454545454545456, 'swedish pop': 0.045454545454545456}
# TOKEN STILL VALID, AGE: 3.9017343600591023 MINUTES
# Mae-Neo-psychedelic | neo-psychedelic | {'neo-psychedelic': 0.25, 'new americana': 0.25, 'southern americana': 0.25, 'nyc pop': 0.25}
#
# ########## Genre extraction COMPLETE! ##########
#
# TOKEN STILL VALID, AGE: 3.907159694035848 MINUTES
#
# ## Chunk[ 3800:4000 ] ##
#
#
# ########## Extract genre info from 200 tracks! ##########
#
# Identified 4 genres in this collection of 200 tracks!
# TOKEN STILL VALID, AGE: 5.292915177345276 MINUTES
# TOKEN STILL VALID, AGE: 5.2993794798851015 MINUTES
# King-Urban Contemporary | southern soul | {'trap queen': 0.00975609756097561, 'bboy': 0.00975609756097561, 'nu jazz': 0.004878048780487805, 'alternative r&b': 0.014634146341463415, 'indie soul': 0.014634146341463415, 'nyc pop': 0.004878048780487805, 'southern soul': 0.03414634146341464, 'classic soul': 0.01951219512195122, 'disco': 0.004878048780487805, 'funk': 0.014634146341463415, 'jazz funk': 0.00975609756097561, 'p funk': 0.004878048780487805, 'post-disco': 0.00975609756097561, 'quiet storm': 0.00975609756097561, 'soul': 0.024390243902439025, 'funk rock': 0.004878048780487805, 'minneapolis sound': 0.004878048780487805, 'rock': 0.00975609756097561, 'synth funk': 0.004878048780487805, 'pop edm': 0.004878048780487805, 'motown': 0.004878048780487805, 'neo soul': 0.004878048780487805, 'northern soul': 0.004878048780487805, 'vocal jazz': 0.00975609756097561, 'atl hip hop': 0.00975609756097561, 'hip hop': 0.01951219512195122, 'rap': 0.014634146341463415, 'new jersey underground rap': 0.004878048780487805, 'new mexico music': 0.004878048780487805, 'modern blues': 0.01951219512195122, 'modern blues rock': 0.004878048780487805, 'alternative dance': 0.004878048780487805, 'electropop': 0.004878048780487805, 'indietronica': 0.004878048780487805, 'neo-synthpop': 0.004878048780487805, 'traditional soul': 0.004878048780487805, 'indie pop': 0.004878048780487805, 'modern alternative pop': 0.004878048780487805, 'dance pop': 0.014634146341463415, 'dance rock': 0.004878048780487805, 'permanent wave': 0.004878048780487805, 'pop rock': 0.004878048780487805, 'alternative country': 0.004878048780487805, 'indie folk': 0.00975609756097561, 'modern folk rock': 0.004878048780487805, 'new americana': 0.00975609756097561, 'north carolina indie': 0.004878048780487805, 'north carolina roots': 0.004878048780487805, 'stomp and holler': 0.004878048780487805, 'uk contemporary r&b': 0.004878048780487805, 'uk pop': 0.004878048780487805, 'british soul': 0.004878048780487805, 'east coast hip hop': 0.014634146341463415, 'golden age hip hop': 0.00975609756097561, 'jazz rap': 0.00975609756097561, 'contemporary r&b': 0.01951219512195122, 'r&b': 0.024390243902439025, 'spirituals': 0.004878048780487805, 'vocal harmony group': 0.004878048780487805, 'vapor soul': 0.004878048780487805, 'kentucky roots': 0.004878048780487805, 'roots americana': 0.004878048780487805, 'western americana': 0.004878048780487805, 'memphis soul': 0.00975609756097561, 'new orleans soul': 0.004878048780487805, 'crunk': 0.004878048780487805, 'dirty south rap': 0.00975609756097561, 'new orleans rap': 0.004878048780487805, 'latin afrobeat': 0.004878048780487805, 'conscious hip hop': 0.004878048780487805, 'queens hip hop': 0.004878048780487805, 'southern soul blues': 0.004878048780487805, 'girl group': 0.004878048780487805, 'album rock': 0.004878048780487805, 'blues rock': 0.00975609756097561, 'classic rock': 0.004878048780487805, 'country rock': 0.014634146341463415, 'folk rock': 0.004878048780487805, 'heartland rock': 0.004878048780487805, 'mellow gold': 0.004878048780487805, 'singer-songwriter': 0.004878048780487805, 'soft rock': 0.004878048780487805, 'southern rock': 0.014634146341463415, 'swamp rock': 0.004878048780487805, 'chicago rap': 0.004878048780487805, 'hip pop': 0.014634146341463415, 'new jack swing': 0.004878048780487805, 'urban contemporary': 0.014634146341463415, 'rhythm and blues': 0.004878048780487805, 'greek indie': 0.004878048780487805, 'popping': 0.004878048780487805, 'purple sound': 0.004878048780487805, 'gospel': 0.00975609756097561, 'gospel r&b': 0.004878048780487805, 'black americana': 0.004878048780487805, 'indie r&b': 0.00975609756097561, 'post-disco soul': 0.004878048780487805, 'nz folk': 0.004878048780487805, 'nz pop': 0.004878048780487805, 'nz singer-songwriter': 0.004878048780487805, 'retro soul': 0.004878048780487805, 'blues': 0.004878048780487805, 'electric blues': 0.00975609756097561, 'texas blues': 0.004878048780487805, 'british blues': 0.004878048780487805, 'german  ...
# TOKEN STILL VALID, AGE: 5.466090873877207 MINUTES
# 2003-Permanent Wave | alternative r&b | {'british soul': 0.016666666666666666, 'neo soul': 0.016666666666666666, 'modern blues': 0.016666666666666666, 'dance pop': 0.016666666666666666, 'dance rock': 0.016666666666666666, 'permanent wave': 0.016666666666666666, 'pop rock': 0.03333333333333333, 'rock': 0.016666666666666666, 'indie surf': 0.016666666666666666, 'neo-psychedelic': 0.016666666666666666, 'noise pop': 0.016666666666666666, 'classic soul': 0.03333333333333333, 'disco': 0.016666666666666666, 'funk': 0.016666666666666666, 'memphis soul': 0.016666666666666666, 'motown': 0.016666666666666666, 'p funk': 0.016666666666666666, 'post-disco': 0.016666666666666666, 'quiet storm': 0.016666666666666666, 'soul': 0.03333333333333333, 'southern soul': 0.016666666666666666, 'hip hop': 0.016666666666666666, 'rap': 0.016666666666666666, 'tennessee hip hop': 0.016666666666666666, 'underground hip hop': 0.016666666666666666, 'chicago soul': 0.016666666666666666, 'rock-and-roll': 0.016666666666666666, 'bedroom soul': 0.016666666666666666, 'new wave pop': 0.016666666666666666, 'edm': 0.016666666666666666, 'pop': 0.016666666666666666, 'pop dance': 0.016666666666666666, 'acoustic blues': 0.016666666666666666, 'gospel blues': 0.016666666666666666, 'traditional blues': 0.016666666666666666, 'contemporary vocal jazz': 0.016666666666666666, 'jazz pop': 0.016666666666666666, 'neo mellow': 0.016666666666666666, 'vocal jazz': 0.016666666666666666, 'alternative r&b': 0.05, 'la pop': 0.016666666666666666, 'scandinavian r&b': 0.016666666666666666, 'swedish soul': 0.016666666666666666, 'synth funk': 0.016666666666666666, 'alternative country': 0.016666666666666666, 'new americana': 0.016666666666666666, 'outlaw country': 0.016666666666666666, 'bubblegrunge': 0.016666666666666666, 'countrygaze': 0.016666666666666666, 'surf punk': 0.016666666666666666, 'dutch r&b': 0.016666666666666666, 'conscious hip hop': 0.016666666666666666, 'mississippi hip hop': 0.016666666666666666, 'southern hip hop': 0.016666666666666666, 'trap': 0.016666666666666666}
# TOKEN STILL VALID, AGE: 5.478058922290802 MINUTES
# Thu-Canadian Contemporary R&b T He | indie r&b | {'canadian contemporary r&b': 0.3333333333333333, 'indie r&b': 0.6666666666666666}
# TOKEN STILL VALID, AGE: 5.4962244908014934 MINUTES
# Fort-Merseybeat | post-disco | {'post-disco': 0.14285714285714285, 'southern soul': 0.14285714285714285, 'bubblegum pop': 0.14285714285714285, 'classic uk pop': 0.14285714285714285, 'merseybeat': 0.14285714285714285, 'rock-and-roll': 0.14285714285714285, 'swamp pop': 0.14285714285714285}
#
# ########## Genre extraction COMPLETE! ##########
#
# TOKEN STILL VALID, AGE: 5.501579717795054 MINUTES
#
# ## Chunk[ 4000:4112 ] ##
#
#
# ########## Extract genre info from 112 tracks! ##########
#
# Identified 3 genres in this collection of 112 tracks!
# TOKEN STILL VALID, AGE: 5.898268294334412 MINUTES
# Toto-Roots Reggae | r&b | {'canadian contemporary r&b': 0.009615384615384616, 'synth funk': 0.009615384615384616, 'southern soul blues': 0.019230769230769232, 'indie garage rock': 0.009615384615384616, 'portland indie': 0.009615384615384616, 'alternative r&b': 0.019230769230769232, 'r&b': 0.038461538461538464, 'quiet storm': 0.009615384615384616, 'soul': 0.009615384615384616, 'album rock': 0.009615384615384616, 'classic rock': 0.009615384615384616, 'hard rock': 0.009615384615384616, 'mellow gold': 0.009615384615384616, 'new romantic': 0.009615384615384616, 'new wave': 0.009615384615384616, 'new wave pop': 0.009615384615384616, 'permanent wave': 0.009615384615384616, 'power pop': 0.009615384615384616, 'rock': 0.009615384615384616, 'singer-songwriter': 0.009615384615384616, 'soft rock': 0.009615384615384616, 'synthpop': 0.009615384615384616, 'art pop': 0.009615384615384616, 'pop': 0.038461538461538464, 'big beat': 0.009615384615384616, 'electronica': 0.009615384615384616, 'crunk': 0.009615384615384616, 'dirty south rap': 0.009615384615384616, 'gangster rap': 0.009615384615384616, 'new orleans rap': 0.009615384615384616, 'classic soul': 0.009615384615384616, 'memphis soul': 0.009615384615384616, 'southern soul': 0.028846153846153848, 'contemporary r&b': 0.019230769230769232, 'neo soul': 0.009615384615384616, 'new jack swing': 0.009615384615384616, 'urban contemporary': 0.019230769230769232, 'kansas indie': 0.009615384615384616, 'classic oklahoma country': 0.009615384615384616, 'contemporary country': 0.009615384615384616, 'country': 0.009615384615384616, 'country road': 0.009615384615384616, 'indie r&b': 0.028846153846153848, 'rap': 0.028846153846153848, 'popping': 0.009615384615384616, 'atl hip hop': 0.009615384615384616, 'indie hip hop': 0.009615384615384616, 'psychedelic hip hop': 0.009615384615384616, 'underground hip hop': 0.009615384615384616, 'hip pop': 0.019230769230769232, 'brostep': 0.009615384615384616, 'edm': 0.009615384615384616, 'progressive electro house': 0.009615384615384616, 'canadian hip hop': 0.009615384615384616, 'dark trap': 0.009615384615384616, 'meme rap': 0.009615384615384616, 'girl group': 0.009615384615384616, 'deep underground hip hop': 0.009615384615384616, 'hip hop': 0.009615384615384616, 'kentucky hip hop': 0.009615384615384616, 'pop rap': 0.009615384615384616, 'folk-pop': 0.009615384615384616, 'chill abstract hip hop': 0.009615384615384616, 'dance pop': 0.009615384615384616, 'la pop': 0.009615384615384616, 'arab groove': 0.009615384615384616, 'lebanese indie': 0.009615384615384616, 'deep northern soul': 0.009615384615384616, 'motown': 0.009615384615384616, 'indie pop': 0.009615384615384616, 'indie poptimism': 0.009615384615384616, 'bubblegrunge': 0.009615384615384616, 'countrygaze': 0.009615384615384616, 'surf punk': 0.009615384615384616, 'conscious hip hop': 0.009615384615384616, 'bboy': 0.009615384615384616, 'brass band': 0.009615384615384616, 'british soul': 0.009615384615384616, 'nz pop': 0.009615384615384616, 'reggae': 0.019230769230769232, 'roots reggae': 0.009615384615384616, 'uk reggae': 0.009615384615384616, 'early reggae': 0.009615384615384616, 'rocksteady': 0.009615384615384616, 'ska': 0.009615384615384616, 'ska revival': 0.009615384615384616}
# TOKEN STILL VALID, AGE: 5.92019811073939 MINUTES
# Sops-Alternative R&b | r&b | {'atl hip hop': 0.058823529411764705, 'contemporary r&b': 0.058823529411764705, 'dance pop': 0.11764705882352941, 'pop': 0.11764705882352941, 'r&b': 0.17647058823529413, 'rap': 0.058823529411764705, 'south carolina hip hop': 0.058823529411764705, 'urban contemporary': 0.058823529411764705, 'alternative r&b': 0.11764705882352941, 'metropopolis': 0.058823529411764705, 'glam metal': 0.058823529411764705, 'hard rock': 0.058823529411764705}
# TOKEN STILL VALID, AGE: 5.954150076707204 MINUTES
# Mike-Modern Rock | australian indie rock | {'australian indie rock': 0.0625, 'funk': 0.0625, 'neo soul': 0.0625, 'soul': 0.0625, 'indie pop': 0.0625, 'indie poptimism': 0.0625, 'brooklyn drill': 0.0625, 'hip hop': 0.0625, 'rap': 0.0625, 'indie r&b': 0.0625, 'modern alternative rock': 0.0625, 'modern rock': 0.0625, 'pop': 0.0625, 'pov: indie': 0.0625, 'rock': 0.0625, 'indie jazz': 0.0625}
#
# ########## Genre extraction COMPLETE! ##########
#
# TOKEN STILL VALID, AGE: 5.959432717164358 MINUTES
#
# Genre generation from Faves took 2191.135905981064 seconds!

# %% [markdown]
# ## Merge Micro-Genres into Mini-Genres

# %%
def merge_micro_genres_in_db( db ):
    """ Attempt to merge similar genres in the `db` """

    print( f"########## Attempt to merge similar genres in the music database ##########" )
    
    ### Init ###
    Ngenres = len( db['genres'] )
    IDs     = list()
    trees   = list()
    pntLsts = list()
    
    # Gather track vectors
    for k, v in db['genres'].items():
        IDs.append( k )
        trees.append( v['kdTree'] )
        pntLsts.append( v['vectors'] )
    
    ### Search for merge candidates ###
    mergeLst = list()
    for i, gID_i in enumerate( IDs ):
        pts_i = pntLsts[i]
        if len( pts_i ) > 1:
            for j in range( i+1, Ngenres ):
                gID_j = IDs[j]
                kdt_j = trees[j]
                dif_j = list()
                for pnt_k in pts_i:
                    dif_j.append( kdt_j.query( pnt_k )[0] )
                if (np.mean( dif_j ) < (_DBS_EPSILON/_MRG_D_FACTOR)):
                    found = False
                    for mrgSet in mergeLst:
                        if ((gID_i in mrgSet) or (gID_j in mrgSet)):
                            mrgSet.add( gID_i )
                            mrgSet.add( gID_j )
                            found = True
                            break
                    if not found:
                        mergeLst.append( set([gID_i, gID_j,]) )

    print( f"There are {len(mergeLst)} merge jobs to perform!" )
    
    ### Perform all merge jobs ###
    for mrgJob in mergeLst:
        mDct = {
            'nameSpot' : None, # --- Most prominent Spotify genre across all artists
            'nameDist' : dict(), # --- Discrete distribution of Spotify genre across all artists
            'nameLocal': None, # --- Humorous (semi-)unique name given to micro-genre
            'tracks'   : list(), # Tracks that belong to this micro-genre
            'len'      : 0, # ------ Number of identified tracks in the micro-genre
            'vectors'  : None, # --- Vector representation of the tracks
            'kdTree'   : None, # --- Spatial tree for 'vectors'
            'origins'  : list(), # Playlist(s) that tracks come from
        }
        namSplt = list()
        keys_i = list( mrgJob )
        print( "\nMerge:" )
        for j, key_ij in enumerate( keys_i ):
            if key_ij in db['genres']:
                if j > 0:
                    print( "\t\t-and-" )
                print( f"\t{db['genres'][ key_ij ]['nameLocal']}" )
            
        for mID in mrgJob:
            if mID in db['genres']:
                # Local name components
                namSplt.append( [db['genres'][ mID ]['len'], db['genres'][ mID ]['nameLocal'].split(),] )
                # Tracks
                mDct['tracks'].extend( db['genres'][ mID ]['tracks'] )
                # Vectors
                if mDct['vectors'] is None:
                    mDct['vectors'] = db['genres'][ mID ]['vectors']
                else:
                    mDct['vectors'] = np.vstack( (mDct['vectors'], db['genres'][ mID ]['vectors'],) )
                # Len
                mDct['len'] += db['genres'][ mID ]['len']
                # Origins
                mDct['origins'].extend( db['genres'][ mID ]['origins'] )
                # Name Distribution
                for k, v in db['genres'][ mID ]['nameDist'].items():
                    if k in mDct['nameDist']:
                        mDct['nameDist'][k] += v * db['genres'][ mID ]['len']
                    else:
                        mDct['nameDist'][k]  = v * db['genres'][ mID ]['len']
                # Delete the merged genre
                del db['genres'][ mID ]
        if (mDct['vectors'] is not None) and (len( mDct['vectors'] ) > 1):
            # Recalc the spatial tree
            mDct['kdTree'] = cKDTree( mDct['vectors'], balanced_tree = False, compact_nodes = False )
        # Normalize Name Distribution
        mDct['nameDist'] = normalize_dist( mDct['nameDist'] )
        # Choose the top Spotify genre
        if len( mDct['nameDist'] ):
            topSpGenre = sort_keys_by_value( mDct['nameDist'], reverse = True )[0]
        else:
            topSpGenre = _NULL_GENRE
        mDct['nameSpot'] = topSpGenre
        
        # Construct a new local name
        lenLst = [len( item[1] ) for item in namSplt]
        if len( lenLst ) > 0:
            lenMax = max( lenLst )
            lclNam = ""
            for j in range( lenMax ):
                dice = dict()
                for k, (mag_k, lst_k) in enumerate( namSplt ):
                    print( f"Components: {k}, {mag_k}, {lst_k}" )
                    len_k = len( lst_k )
                    if j < len_k:
                        dice[ lst_k[j] ] = mag_k
                token = roll_outcome( dice )
                # print( namSplt )
                # print( lenLst )
                # pprint( dice )
                print( f"Token: {token}" )
                if j > 0:
                    lclNam += ' '
                lclNam += (token if (token is not None) else _NULL_GENRE)
            mDct['nameLocal'] = lclNam
        else:
            mDct['nameLocal'] = _NULL_GENRE

        # Store the merged mini-genre
        nuID = str( uuid4() )
        db['genres'][ nuID ] = mDct
        print( f"Merge Complete!: New Mini-Genre {mDct['nameLocal']} ({nuID}) created with {mDct['len']} tracks!" )


def move_mini_genre_outliers_to_better_homes( db ):
    """ Attempt to rehome outlier tracks that were collected during the micro-genre creation and merge """

    ### Search for split candidates ###
    Ngenres = len( db['genres'] )
    IDs     = list()
    trees   = list()
    pntLsts = list()
    dstLsts = list()

    # Gather track vectors
    for k, v in db['genres'].items():
        IDs.append( k )
        trees.append( v['kdTree'] )
        pntLsts.append( v['vectors'] )

    # Evaluate spread within each mini-genre
    for i, pts_i in enumerate( pntLsts ):
        avgDist = list()
        if pts_i is not None:
            for j, pnt_j in enumerate( pts_i ):
                dists = list()
                for k, pnt_k in enumerate( pts_i ):
                    dists.append( np.linalg.norm( np.subtract( pnt_j, pnt_k ) ) )
                avgDist.append( np.mean( dists ) )
            dstLsts.append( avgDist )
        else:
            dstLsts.append( _ONE_BILLION )

    ## Evaluate relative closeness of every point in a genre to every other genre ##
    # For every mini-genre, do
    for i, gID_i in enumerate( IDs ):
        if pntLsts[i] is None:
            continue
        pts_i = pntLsts[i][:].tolist()
        dst_i = dstLsts[i][:]
        # For every vector in the mini-genre, do
        j = 0 
        while (j < len( pts_i )):
            pnt_j = pts_i[j]
            dst_j = dst_i[j]
            dMn_j = 1e6
            gnr_j = None
            # For every other mini-genre, Search for the shortest dist
            for k, gID_k in enumerate( IDs ):
                if i != k:
                    tre_k  = db['genres'][ gID_k ]['kdTree']
                    if tre_k is not None:
                        dst_jk = tre_k.query( pnt_j )[0]
                        if ((dst_jk < dst_j) and (dst_jk < dMn_j)):
                            dMn_j = dst_jk
                            gnr_j = gID_k
            # If a new home was found, then move
            if gnr_j is not None:
                print( f"Moving track {j} of  {db['genres'][ gID_i ]['nameLocal']}  --to->  {db['genres'][ gnr_j ]['nameLocal']}" )
                trk_j = db['genres'][ gID_i ]['tracks'][j]
                db['genres'][ gID_i ]['tracks'].pop(j)
                pts_i.pop(j)
                dst_i.pop(j)
                db['genres'][ gnr_j ]['tracks'].append( trk_j )
                db['genres'][ gnr_j ]['changed'] = True
                db['genres'][ gID_i ]['changed'] = True
            else:
                j += 1
                
    # For every mini-genre, Recalc vectors if it has changed
    for i, gID_i in enumerate( IDs ):
        if (('changed' in db['genres'][ gID_i ]) and db['genres'][ gID_i ]['changed']):
            gnre = db['genres'][ gID_i ]
            genre_vector_ops( gnre )
            gnre['changed'] = False

    print( "\n########## Genre Report ##########\n" )
    print( f"Filter {len( db['genres'] )} to filter...\n" )
    lstDel = list()
    
    for gID, genre in db['genres'].items():
        if genre['len'] >= _MIN_GNR_MMBR:
            print( f"{genre['nameLocal']}, {genre['len']}" )
        else:
            lstDel.append( gID )

    print( "Deleting ...", end = " " )
    for gID in lstDel:
        print( gID, end = ", " )
        del db['genres'][ gID ]
        
    print( f"\nDeleted {len( lstDel )} mini-genres, {len( db['genres'] )} remain" )
    print( "\n########## Report Complete ##########\n" )

# %%
merge_micro_genres_in_db( data )
move_mini_genre_outliers_to_better_homes( data )
# Out:
# ########## Attempt to merge similar genres in the music database ##########
# There are 5 merge jobs to perform!
#
# Merge:
# 	Heartbreaker-Roots Rock
# 		-and-
# 	Tue-Queens Hip Hop
# Components: 0, 5, ['Heartbreaker-Roots', 'Rock']
# Components: 1, 104, ['Tue-Queens', 'Hip', 'Hop']
# Token: Heartbreaker-Roots
# Components: 0, 5, ['Heartbreaker-Roots', 'Rock']
# Components: 1, 104, ['Tue-Queens', 'Hip', 'Hop']
# Token: Hip
# Components: 0, 5, ['Heartbreaker-Roots', 'Rock']
# Components: 1, 104, ['Tue-Queens', 'Hip', 'Hop']
# Token: Hop
# Merge Complete!: New Mini-Genre Heartbreaker-Roots Hip Hop (74ab819d-b8a6-473e-aba6-c6e18a67386c) created with 109 tracks!
#
# Merge:
# 	Boyd-Alternative Country
# 		-and-
# 	Chromosome-Rock
# Components: 0, 148, ['Boyd-Alternative', 'Country']
# Components: 1, 131, ['Chromosome-Rock']
# Token: Chromosome-Rock
# Components: 0, 148, ['Boyd-Alternative', 'Country']
# Components: 1, 131, ['Chromosome-Rock']
# Token: Country
# Merge Complete!: New Mini-Genre Chromosome-Rock Country (d168ed02-4686-4778-8d0d-f30b73672996) created with 279 tracks!
#
# Merge:
# 	Floodlights-Indie Folk True
# 		-and-
# 	Dawn-Gauze Pop
# Components: 0, 5, ['Floodlights-Indie', 'Folk', 'True']
# Components: 1, 4, ['Dawn-Gauze', 'Pop']
# Token: Dawn-Gauze
# Components: 0, 5, ['Floodlights-Indie', 'Folk', 'True']
# Components: 1, 4, ['Dawn-Gauze', 'Pop']
# Token: Pop
# Components: 0, 5, ['Floodlights-Indie', 'Folk', 'True']
# Components: 1, 4, ['Dawn-Gauze', 'Pop']
# Token: True
# Merge Complete!: New Mini-Genre Dawn-Gauze Pop True (cb457684-fb27-4478-aec7-59295209e2c8) created with 9 tracks!
#
# Merge:
# 	Wan-Folk
# 		-and-
# 	Pay-Indie Soul
# Components: 0, 134, ['Wan-Folk']
# Components: 1, 3, ['Pay-Indie', 'Soul']
# Token: Wan-Folk
# Components: 0, 134, ['Wan-Folk']
# Components: 1, 3, ['Pay-Indie', 'Soul']
# Token: Soul
# Merge Complete!: New Mini-Genre Wan-Folk Soul (ed1b35c4-e60b-4a8d-9f5e-de7698fb4b8e) created with 137 tracks!
#
# Merge:
# 	Oder-Dance Pop
# 		-and-
# 	Breaky-Country Rock
# 		-and-
# 	Keen-Pop
# 		-and-
# 	King-Urban Contemporary
# 		-and-
# 	Ares-Lilith
# 		-and-
# 	Lire-Neo R&b
# Components: 0, 105, ['Oder-Dance', 'Pop']
# Components: 1, 97, ['Breaky-Country', 'Rock']
# Components: 2, 98, ['Keen-Pop']
# Components: 3, 96, ['King-Urban', 'Contemporary']
# Components: 4, 4, ['Ares-Lilith']
# Components: 5, 4, ['Lire-Neo', 'R&b']
# Token: Oder-Dance
# Components: 0, 105, ['Oder-Dance', 'Pop']
# Components: 1, 97, ['Breaky-Country', 'Rock']
# Components: 2, 98, ['Keen-Pop']
# Components: 3, 96, ['King-Urban', 'Contemporary']
# Components: 4, 4, ['Ares-Lilith']
# Components: 5, 4, ['Lire-Neo', 'R&b']
# Token: Contemporary
# Merge Complete!: New Mini-Genre Oder-Dance Contemporary (ddb69e1e-76b2-4780-abcf-660717d4d8ee) created with 404 tracks!
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wham-Classic Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wham-Classic Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lire-Trap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Fame-Southern Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wham-Classic Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Fame-Southern Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Snow-Philly Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lick-Traditional Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wham-Classic Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Borg-Queens Hip Hop  --to->  She-Indie Rock
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lick-Traditional Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lick-Traditional Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  2003-Permanent Wave
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lam-Black Americana
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lire-Trap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wham-Classic Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lam-Black Americana
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lam-Black Americana
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lam-Black Americana
# Moving track 0 of  Borg-Queens Hip Hop  --to->  She-Indie Rock
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Fame-Southern Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Snow-Philly Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lam-Black Americana
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lick-Traditional Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lam-Black Americana
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mai-Urban Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Fame-Southern Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lick-Traditional Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Snow-Philly Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Mack-Pop R&b
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Snow-Philly Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Borg-Queens Hip Hop  --to->  She-Indie Rock
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wan-Folk Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Wive-West Coast Rap
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  The-Arkansas Hip Hop
# Moving track 0 of  Borg-Queens Hip Hop  --to->  She-Indie Rock
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Lick-Traditional Soul
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Chromosome-Rock Country
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Oder-Dance Contemporary
# Moving track 0 of  Borg-Queens Hip Hop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Lobe-Stomp And Holler
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Dawn-Gauze Pop True
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Pews-Bebop
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Lobe-Stomp And Holler
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  T He-Neo Soul
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Freedom!-Metropopolis
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Freedom!-Metropopolis
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Freedom!-Metropopolis
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Dawn-Gauze Pop True
# Moving track 0 of  Tue-Indie Anthem-folk  --to->  Lobe-Stomp And Holler
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Wan-Folk Soul
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Lick-Traditional Soul
# Moving track 0 of  She-Indie Rock  --to->  Snow-Philly Rap
# Moving track 0 of  She-Indie Rock  --to->  2003-Permanent Wave
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Mack-Pop R&b
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Fame-Southern Soul
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Lire-Trap
# Moving track 0 of  She-Indie Rock  --to->  Wan-Folk Soul
# Moving track 0 of  She-Indie Rock  --to->  Toto-Roots Reggae
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Mack-Pop R&b
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Wan-Folk Soul
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Lire-Trap
# Moving track 0 of  She-Indie Rock  --to->  Fame-Southern Soul
# Moving track 0 of  She-Indie Rock  --to->  Try-Southern Soul Tee
# Moving track 0 of  She-Indie Rock  --to->  Mike-Modern Rock
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Snow-Philly Rap
# Moving track 0 of  She-Indie Rock  --to->  Lire-Trap
# Moving track 0 of  She-Indie Rock  --to->  Snow-Philly Rap
# Moving track 0 of  She-Indie Rock  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Fame-Southern Soul
# Moving track 0 of  She-Indie Rock  --to->  Fame-Southern Soul
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Lire-Trap
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Lick-Traditional Soul
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Toto-Roots Reggae
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Fame-Southern Soul
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Hash-Dream Pop Slip
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Lire-Trap
# Moving track 0 of  She-Indie Rock  --to->  Lick-Traditional Soul
# Moving track 0 of  She-Indie Rock  --to->  Mai-Urban Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Borg-Queens Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Borg-Queens Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Mack-Pop R&b
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Borg-Queens Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Snow-Philly Rap
# Moving track 0 of  She-Indie Rock  --to->  Lick-Traditional Soul
# Moving track 0 of  She-Indie Rock  --to->  Wham-Classic Soul
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Sops-Alternative R&b
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Thea-Jazz Blues
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Wan-Folk Soul
# Moving track 0 of  She-Indie Rock  --to->  Borg-Queens Hip Hop
# Moving track 0 of  She-Indie Rock  --to->  Lick-Traditional Soul
# Moving track 0 of  She-Indie Rock  --to->  Snow-Philly Rap
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  She-Indie Rock  --to->  Wham-Classic Soul
# Moving track 0 of  She-Indie Rock  --to->  Chromosome-Rock Country
# Moving track 0 of  She-Indie Rock  --to->  Lam-Black Americana
# Moving track 0 of  She-Indie Rock  --to->  Oder-Dance Contemporary
# Moving track 0 of  She-Indie Rock  --to->  Lire-Trap
# Moving track 0 of  She-Indie Rock  --to->  Wive-West Coast Rap
# Moving track 0 of  She-Indie Rock  --to->  Toto-Roots Reggae
# Moving track 0 of  She-Indie Rock  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Thea-Jazz Blues  --to->  Chromosome-Rock Country
# Moving track 0 of  Thea-Jazz Blues  --to->  Lire-Trap
# Moving track 0 of  Thea-Jazz Blues  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Wham-Classic Soul
# Moving track 0 of  Thea-Jazz Blues  --to->  Lick-Traditional Soul
# Moving track 0 of  Thea-Jazz Blues  --to->  Chromosome-Rock Country
# Moving track 0 of  Thea-Jazz Blues  --to->  Lire-Trap
# Moving track 0 of  Thea-Jazz Blues  --to->  Lick-Traditional Soul
# Moving track 0 of  Thea-Jazz Blues  --to->  Lick-Traditional Soul
# Moving track 0 of  Thea-Jazz Blues  --to->  She-Indie Rock
# Moving track 0 of  Thea-Jazz Blues  --to->  Chromosome-Rock Country
# Moving track 0 of  Thea-Jazz Blues  --to->  Oder-Dance Contemporary
# Moving track 0 of  Thea-Jazz Blues  --to->  Oder-Dance Contemporary
# Moving track 0 of  Thea-Jazz Blues  --to->  Mai-Urban Contemporary
# Moving track 0 of  Thea-Jazz Blues  --to->  Oder-Dance Contemporary
# Moving track 0 of  Thea-Jazz Blues  --to->  Wive-West Coast Rap
# Moving track 0 of  Thea-Jazz Blues  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Wive-West Coast Rap
# Moving track 0 of  Thea-Jazz Blues  --to->  Rate-Blues Rock
# Moving track 0 of  Thea-Jazz Blues  --to->  Rate-Blues Rock
# Moving track 0 of  Thea-Jazz Blues  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Might-Modern Rock
# Moving track 0 of  Lire-Trap  --to->  Mack-Pop R&b
# Moving track 0 of  Lire-Trap  --to->  Mae-Neo-psychedelic
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  She-Indie Rock
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Lick-Traditional Soul
# Moving track 0 of  Lire-Trap  --to->  Wham-Classic Soul
# Moving track 0 of  Lire-Trap  --to->  Snow-Philly Rap
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Mack-Pop R&b
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  2003-Permanent Wave
# Moving track 0 of  Lire-Trap  --to->  Thea-Jazz Blues
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Wan-Folk Soul
# Moving track 0 of  Lire-Trap  --to->  Fame-Southern Soul
# Moving track 0 of  Lire-Trap  --to->  Fame-Southern Soul
# Moving track 0 of  Lire-Trap  --to->  Toto-Roots Reggae
# Moving track 0 of  Lire-Trap  --to->  Mack-Pop R&b
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Toto-Roots Reggae
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Wham-Classic Soul
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Wan-Folk Soul
# Moving track 0 of  Lire-Trap  --to->  She-Indie Rock
# Moving track 0 of  Lire-Trap  --to->  Snow-Philly Rap
# Moving track 0 of  Lire-Trap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Snow-Philly Rap
# Moving track 0 of  Lire-Trap  --to->  Thea-Jazz Blues
# Moving track 0 of  Lire-Trap  --to->  Show-Indie Surf
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Pews-Bebop
# Moving track 0 of  Lire-Trap  --to->  Lick-Traditional Soul
# Moving track 0 of  Lire-Trap  --to->  Fame-Southern Soul
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Lick-Traditional Soul
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Hash-Dream Pop Slip
# Moving track 0 of  Lire-Trap  --to->  Wan-Folk Soul
# Moving track 0 of  Lire-Trap  --to->  She-Indie Rock
# Moving track 0 of  Lire-Trap  --to->  She-Indie Rock
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Mack-Pop R&b
# Moving track 0 of  Lire-Trap  --to->  Lick-Traditional Soul
# Moving track 0 of  Lire-Trap  --to->  Mike-Modern Rock
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Mack-Pop R&b
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Pews-Bebop
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Toto-Roots Reggae
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Pews-Bebop
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Mahogany-Yacht Rock
# Moving track 0 of  Lire-Trap  --to->  Lick-Traditional Soul
# Moving track 0 of  Lire-Trap  --to->  Fame-Southern Soul
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Revival-Modern Blues Rock
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Pews-Bebop
# Moving track 0 of  Lire-Trap  --to->  Wive-West Coast Rap
# Moving track 0 of  Lire-Trap  --to->  Wan-Folk Soul
# Moving track 0 of  Lire-Trap  --to->  Toto-Roots Reggae
# Moving track 0 of  Lire-Trap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 0 of  Lire-Trap  --to->  Toto-Roots Reggae
# Moving track 0 of  Lire-Trap  --to->  Wham-Classic Soul
# Moving track 0 of  Lire-Trap  --to->  Fame-Southern Soul
# Moving track 0 of  Lire-Trap  --to->  Lam-Black Americana
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lire-Trap  --to->  Fame-Southern Soul
# Moving track 0 of  Lire-Trap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lire-Trap  --to->  Chromosome-Rock Country
# Moving track 2 of  Ghost-Acoustic Pop  --to->  Tue-Indie Anthem-folk
# Moving track 2 of  Ghost-Acoustic Pop  --to->  Goo-Soul
# Moving track 0 of  Revival-Modern Blues Rock  --to->  Lick-Traditional Soul
# Moving track 0 of  Revival-Modern Blues Rock  --to->  Lire-Trap
# Moving track 0 of  Revival-Modern Blues Rock  --to->  Wain-Modern Blues Rock
# Moving track 0 of  Revival-Modern Blues Rock  --to->  Fame-Southern Soul
# Moving track 0 of  Goo-Soul  --to->  Pews-Bebop
# Moving track 0 of  Goo-Soul  --to->  Mahogany-Yacht Rock
# Moving track 0 of  Goo-Soul  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Goo-Soul  --to->  Hook-Singer-songwriter Pop
# Moving track 0 of  Goo-Soul  --to->  Mahogany-Yacht Rock
# Moving track 0 of  Goo-Soul  --to->  Mahogany-Yacht Rock
# Moving track 0 of  Goo-Soul  --to->  Dawn-Gauze Pop True
# Moving track 0 of  Goo-Soul  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Goo-Soul  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Goo-Soul  --to->  Mahogany-Yacht Rock
# Moving track 0 of  Goo-Soul  --to->  Lire-Trap
# Moving track 0 of  Goo-Soul  --to->  Chromosome-Rock Country
# Moving track 0 of  Goo-Soul  --to->  Lobe-Stomp And Holler
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lam-Black Americana
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lick-Traditional Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lam-Black Americana
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Hash-Dream Pop Slip
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Snow-Philly Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  She-Indie Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Pews-Bebop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lam-Black Americana
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lome-Brooklyn Indie
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lam-Black Americana
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Snow-Philly Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Snow-Philly Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mike-Modern Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  She-Indie Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lick-Traditional Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Hash-Dream Pop Slip
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  She-Indie Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Pews-Bebop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  She-Indie Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  She-Indie Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wain-Modern Blues Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lick-Traditional Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lick-Traditional Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Might-Modern Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Toto-Roots Reggae
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mike-Modern Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lam-Black Americana
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lire-Trap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  She-Indie Rock
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Fame-Southern Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mack-Pop R&b
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wive-West Coast Rap
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Chromosome-Rock Country
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Oder-Dance Contemporary
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wham-Classic Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Lick-Traditional Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Wham-Classic Soul
# Moving track 0 of  Pays-Contemporary Vocal Jazz  --to->  Mai-Urban Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  Snow-Philly Rap
# Moving track 0 of  Wive-West Coast Rap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  She-Indie Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  She-Indie Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Thea-Jazz Blues
# Moving track 0 of  Wive-West Coast Rap  --to->  Wan-Folk Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Mack-Pop R&b
# Moving track 0 of  Wive-West Coast Rap  --to->  Lick-Traditional Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Wive-West Coast Rap  --to->  Snow-Philly Rap
# Moving track 0 of  Wive-West Coast Rap  --to->  She-Indie Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Lick-Traditional Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Snow-Philly Rap
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Wan-Folk Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Lick-Traditional Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Toto-Roots Reggae
# Moving track 0 of  Wive-West Coast Rap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  She-Indie Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Mack-Pop R&b
# Moving track 0 of  Wive-West Coast Rap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  2003-Permanent Wave
# Moving track 0 of  Wive-West Coast Rap  --to->  Mack-Pop R&b
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Thea-Jazz Blues
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Wan-Folk Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Wham-Classic Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Wain-Modern Blues Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Mack-Pop R&b
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  She-Indie Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Fame-Southern Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Wain-Modern Blues Rock
# Moving track 0 of  Wive-West Coast Rap  --to->  Lick-Traditional Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Lick-Traditional Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Chromosome-Rock Country
# Moving track 0 of  Wive-West Coast Rap  --to->  Wham-Classic Soul
# Moving track 0 of  Wive-West Coast Rap  --to->  Oder-Dance Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Toto-Roots Reggae
# Moving track 0 of  Wive-West Coast Rap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  Lire-Trap
# Moving track 0 of  Wive-West Coast Rap  --to->  Mai-Urban Contemporary
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Wive-West Coast Rap  --to->  Lam-Black Americana
# Moving track 0 of  Wive-West Coast Rap  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Wive-West Coast Rap  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Show-Indie Surf  --to->  Wham-Classic Soul
# Moving track 0 of  Show-Indie Surf  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Show-Indie Surf  --to->  Lire-Trap
# Moving track 0 of  Show-Indie Surf  --to->  Lire-Trap
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop R&b
# Moving track 0 of  Pews-Bebop  --to->  Hash-Dream Pop Slip
# Moving track 0 of  Pews-Bebop  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Pews-Bebop  --to->  T He-Neo Soul
# Moving track 0 of  Pews-Bebop  --to->  Chromosome-Rock Country
# Moving track 0 of  Pews-Bebop  --to->  Chromosome-Rock Country
# Moving track 0 of  Pews-Bebop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Pews-Bebop  --to->  Lire-Trap
# Moving track 0 of  Pews-Bebop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Pews-Bebop  --to->  Lire-Trap
# Moving track 0 of  Pews-Bebop  --to->  Lire-Trap
# Moving track 0 of  Pews-Bebop  --to->  Chromosome-Rock Country
# Moving track 0 of  Pews-Bebop  --to->  Wham-Classic Soul
# Moving track 0 of  Pews-Bebop  --to->  Fame-Southern Soul
# Moving track 0 of  Pews-Bebop  --to->  Wan-Folk Soul
# Moving track 0 of  Pews-Bebop  --to->  Chromosome-Rock Country
# Moving track 0 of  Pews-Bebop  --to->  Chromosome-Rock Country
# Moving track 0 of  Pews-Bebop  --to->  Fame-Southern Soul
# Moving track 0 of  Pews-Bebop  --to->  Goo-Soul
# Moving track 0 of  Pews-Bebop  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Pews-Bebop  --to->  Wan-Folk Soul
# Moving track 0 of  Pews-Bebop  --to->  Wan-Folk Soul
# Moving track 0 of  Pews-Bebop  --to->  Lick-Traditional Soul
# Moving track 2 of  The-Norwegian Blues  --to->  Revival-Modern Blues Rock
# Moving track 2 of  The-Norwegian Blues  --to->  Lick-Traditional Soul
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lam-Black Americana  --to->  Revival-Modern Blues Rock
# Moving track 0 of  Lam-Black Americana  --to->  Lire-Trap
# Moving track 0 of  Lam-Black Americana  --to->  Wan-Folk Soul
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Lam-Black Americana  --to->  Snow-Philly Rap
# Moving track 0 of  Lam-Black Americana  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lam-Black Americana  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Lam-Black Americana  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Wan-Folk Soul
# Moving track 0 of  Lam-Black Americana  --to->  Lick-Traditional Soul
# Moving track 0 of  Lam-Black Americana  --to->  Wan-Folk Soul
# Moving track 0 of  Lam-Black Americana  --to->  Wive-West Coast Rap
# Moving track 0 of  Lam-Black Americana  --to->  2003-Permanent Wave
# Moving track 0 of  Lam-Black Americana  --to->  Wive-West Coast Rap
# Moving track 0 of  Lam-Black Americana  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lam-Black Americana  --to->  Lick-Traditional Soul
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lam-Black Americana  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lam-Black Americana  --to->  Fame-Southern Soul
# Moving track 0 of  Lam-Black Americana  --to->  Please-Country Rock
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# Moving track 0 of  Lam-Black Americana  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Lam-Black Americana  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lam-Black Americana  --to->  Oder-Dance Contemporary
# Moving track 0 of  Lam-Black Americana  --to->  Chromosome-Rock Country
# ...
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Thu-Canadian Contemporary R&b T He
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Snow-Philly Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Snow-Philly Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Thu-Canadian Contemporary R&b T He
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Please-Country Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Snow-Philly Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Thea-Jazz Blues
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Thea-Jazz Blues
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Snow-Philly Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lam-Black Americana
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Thea-Jazz Blues
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mack-Pop R&b
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Snow-Philly Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wive-West Coast Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wham-Classic Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Heartbreaker-Roots Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  Borg-Queens Hip Hop
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Snow-Philly Rap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Wan-Folk Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Toto-Roots Reggae
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Fame-Southern Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Mai-Urban Contemporary
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Pays-Contemporary Vocal Jazz
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lick-Traditional Soul
# Moving track 0 of  Oder-Dance Contemporary  --to->  She-Indie Rock
# Moving track 0 of  Oder-Dance Contemporary  --to->  Lire-Trap
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
# Moving track 0 of  Oder-Dance Contemporary  --to->  Chromosome-Rock Country
#
# ########## Genre Report ##########
#
# Filter 51 to filter...
#
# Borg-Queens Hip Hop, 128
# She-Indie Rock, 110
# Thea-Jazz Blues, 24
# Lire-Trap, 129
# Pays-Contemporary Vocal Jazz, 121
# Wive-West Coast Rap, 117
# Pews-Bebop, 27
# Lam-Black Americana, 112
# Lick-Traditional Soul, 115
# Wham-Classic Soul, 115
# Snow-Philly Rap, 72
# Fame-Southern Soul, 121
# Mack-Pop R&b, 135
# Mai-Urban Contemporary, 132
# 2003-Permanent Wave, 23
# Toto-Roots Reggae, 65
# Heartbreaker-Roots Hip Hop, 114
# Chromosome-Rock Country, 284
# Wan-Folk Soul, 129
# Oder-Dance Contemporary, 307
# Deleting ... a339ae9e-d5fd-444d-bbe6-0e986ee90c93, 5447222a-420e-4e8d-87eb-dc30edb0788e, fc561799-554a-4682-a4c5-fc6b14dcd03d, a2a25ecb-78c0-471d-a339-401770f3e8dd, ea419acc-aa74-40b9-8d0e-a4303db06d72, 8f9956a1-6d04-4069-afa4-a1bd782fa2c1, 49c347a8-c582-43fd-8286-5a7f4af49209, 066e4c9c-ef27-4334-bd84-16d1d5088f98, d428e242-a710-46fb-aa52-ff1f5a404bc3, c3b651da-7ddc-439e-a0ff-d18ca9e31613, 31ff6e91-ca00-4d9b-a8e2-3cf9af798493, e1065eb0-8134-43b5-b350-f43034c2a973, 036fc1b5-01b7-402a-9f78-ed762ee74b00, 2d0dab03-38f0-4e00-9083-22d2d02e8eac, e2ace289-875b-4268-9ce7-6ff12205f11e, 900e9cb3-967d-48d9-a51d-db8f6af1cc89, 7214c56b-cb62-4d5d-953a-ec66ad7d0cc8, 8721ca92-191e-4c2f-a7da-9d2a89a016c8, 702082ca-ccad-4f41-8e07-147cd9f6ff17, f14ef8bf-64e0-4671-b3a7-787ac8c6aab8, f8ae6422-702b-4e09-b96d-2542be0c471c, ddc78175-4879-4d97-a23d-156329f66204, d749e11c-a515-4fc8-b4c9-05d288626a32, 0bf64ccd-f381-4ffe-a4eb-7d2771dc3ffd, 1483db04-7ced-4a3c-a7bb-300f2ec6350d, 87787dd8-f02b-42e7-a496-be0157c64ff9, 9b3b75c7-a521-457c-9116-177419629c4a, fba0581c-8d17-404f-af0c-e802426a8988, ffbdfb8c-2504-4768-8a42-7a8939274aca, adb6db2e-703f-4c71-b30d-a112bc4356ed, cb457684-fb27-4478-aec7-59295209e2c8,
# Deleted 31 mini-genres, 20 remain
#
# ########## Report Complete ##########

# %%
save_music_database( data )
# Out:
# About to write data/Teo-Music-Data_2024-09-04T15:37:44.pkl ...
# COMPLETE!

# %% [markdown]
# # Search Version 02, Graded by Mini-Genre Proximity

# %% [markdown]
# ## Sub-Searches

# %%
def get_tracks_from_new_releases( N, div = 12, db = None, pause_s = 0.25 ):
    """ Get `N` tracks from newly-released albums """
    totTrks = list()
    Nalbums = int( ceil( N / div ) )
    albOfst =  0
    count   =  0
    Niter   =  0
    itrLim  = 20

    while count < N: 

        Niter += 1

        if Niter > itrLim:
            break
        
        if db is not None:
            if _NU_REL_Q_KEY in db['queries']:
                albOfst = db['queries'][ _NU_REL_Q_KEY ]
                db['queries'][ _NU_REL_Q_KEY ] += Nalbums
            else:
                db['queries'][ _NU_REL_Q_KEY ] = Nalbums
        
        response = spot.new_releases( limit = Nalbums, offset = albOfst )
        nuAlbums = [item['id'] for item in response['albums']['items']]
        sleep( pause_s )
        
        for albumID in nuAlbums:
            res    = spot.album_tracks( albumID, limit = 50, offset = 0 )
            tracks = res['items']
            totTrks.extend( tracks )
            count += len( tracks )
            sleep( pause_s )

    return totTrks


def get_recommended_tracks_from_db( db, N_tracks, pause_s = 0.25 ):
    """ Recommended tracks by both artists and genres """
    count  = 0
    gIDs   = list( db['genres'].keys() )
    rtnLst = list()
    while count < N_tracks:
        recArt = list()
        recTrk = list()
        recGnr = list()
        gID    = choice( gIDs )
        gnre   = db['genres'][ gID ]
        for i in range( 5 ):
            trk_i = choice( gnre['tracks'] )
            art_i = choice( trk_i['track']['album']['artists'] )
            if i % 3 == 0:
                recArt.append( art_i['id'] )
            elif i % 2 == 0:    
                recTrk.append( trk_i['track']['id'] )
            else:
                recGnr.append( roll_outcome( gnre['nameDist'] ) )
                
        nFetch = min( _RESPONSE_LIMIT, max( N_tracks-count, 0 ) )
        if nFetch > 0:
            response = spot.recommendations(
                seed_artists = recArt, 
                seed_genres  = recGnr, 
                seed_tracks  = recTrk, 
                limit        = nFetch
            )
            sleep( pause_s )
            # pprint( response )
            tracks = response['tracks']
            count += len( tracks )
            rtnLst.extend( tracks )
        else:
            break
    return rtnLst
        

def get_tracks_from_related_artists( db, N_tracks, pause_s = 0.25 ):
    """ Attempt to get fresh tracks from Spotify given artists currently in the collection """
    skipN  = 5
    count  = 0
    plNam  = list( db['playlists'].keys() )
    rtnLst = list()

    while count < N_tracks:
        tracks = db['playlists'][ choice( plNam ) ]['tracks']
        artist = choice( choice( tracks )['track']['album']['artists'] )['id']
        res    = spot.artist_related_artists( artist )
        artLst = [item['id'] for item in res['artists']]
        Nart   = len( artLst )
        sleep( pause_s )

        # For each artist, Get top tracks
        for art_i in artLst:
            qArtist = _ART_Q_PREFIX + str( art_i )
            if qArtist not in db['queries']:
                res = spot.artist_top_tracks( art_i )
                sleep( pause_s )
                count += len( res['tracks'] )
                rtnLst.extend( res['tracks'] )
                db['queries'][ qArtist ] = 1

        # For each group of artists, Get recommendations
        bgn  = 0
        end  = 0
        grps = list()
        while end < Nart:
            bgn = end
            end = min( end+skipN, Nart )
            grps.append( artLst[ bgn:end ] )
        for artGrp in grps:
            nFetch = min( _RESPONSE_LIMIT, max( N_tracks-count, 0 ) )
            if nFetch > 0:
                response = spot.recommendations(
                    seed_artists = artGrp, 
                    limit        = nFetch
                )
                sleep( pause_s )
                # pprint( response )
                tracks = response['tracks']
                count += len( tracks )
                rtnLst.extend( tracks )
            else:
                break

    return rtnLst


def get_tracks_from_featured_playlists( db, N_tracks, pause_s = 0.25 ):
    """ Attempt to get fresh tracks from Spotify featured playlists, one at a time """
    step    = 1
    count   = 0
    totTrks = list()
    while count < N_tracks:
        ofst  = db['queries'][ _FEAT_PL_Q_KY ] if (_FEAT_PL_Q_KY in db['queries']) else 0
        db['queries'][ _FEAT_PL_Q_KY ] = db['queries'].get( _FEAT_PL_Q_KY, 0 ) + 1
        response = spot.featured_playlists( limit = step, offset = ofst )
        if len( response['playlists']['items'] ):
            plylstID = response['playlists']['items'][0]['id']
            tracks   =  fetch_entire_playlist_with_audio_features( plylstID )
            count   += len( tracks )
            totTrks.extend( tracks )
    return totTrks

# %% [markdown]
# ## Search and Filter

# %%
def add_audio_features_to_track_list( tracks, pause_s = 0.25 ):
    """ Add audio features and calc vector for all `tracks` """
    ## Init ##
    N_trks = len( tracks )
    featrs = None

    while featrs is None:
        bgn    = 0
        end    = 0
        featrs = list()
        ## Get Features ##
        while end < N_trks:
            bgn = end
            end = min( end+_RESPONSE_LIMIT, N_trks )
            # pprint( tracks[0] )
            lst = [item['id'] for item in tracks[ bgn:end ]]
            featrs.extend( spot.audio_features( lst ) )
            sleep( pause_s )

        if featrs is None:
            continue
        
        ## Add Features and Vectors ##
        for i, track_i in enumerate( tracks ):
            track_i.update( featrs[i] )
            track_i['vector'] = get_track_vector( track_i )


def filter_short_and_explicit_tracks( qTracks ):
    """ Remove short (<1:45) and explicit (guaranteed vocal) songs and Return filtered tracks """
    tracks = qTracks[:]
    # 3. For every track j in playlist, do
    j = 0
    while j < len( tracks ):
        track_j   = tracks[j]
        trackID_j = track_j['id']
        len_s_j   = track_j['duration_ms']/1000.0
        explc_j   = track_j.get( 'explicit', False )

        if ((len_s_j < _MIN_LEN_S) or explc_j):
            tracks.pop(j)
        else:
            j += 1
    return tracks


def filter_collected_and_reviewed_tracks( db, qTracks ):
    """ Remove songs that are either already in the collection or have been reviewed and Return filtered tracks """
    tracks = qTracks[:]
    trkSet = set([])
    # 3. For every track j in playlist, do
    j = 0
    while j < len( tracks ):
        track_j   = tracks[j]
        trackID_j = track_j['id']
        p_collect = (trackID_j in db['collectID'])
        p_reviewd = (trackID_j in db['reviewID' ])
        p_intake  = (trackID_j in trkSet)

        if (p_collect or p_reviewd or p_intake):
            tracks.pop(j)
        else:
            trkSet.add( trackID_j )
            j += 1
    return tracks


def guided_multi_search_version_02( db, N_tracks ):
    print( "\n########## Guided Multi-Search, Version_02 ##########\n" )
    
    ### Search && Gather ###
    print( f"Search for {N_tracks} new releases ..." )
    tracks = get_tracks_from_new_releases( N_tracks, div = 12, db = db, pause_s = 0.25 )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} recommendations ..." )
    tracks.extend( get_recommended_tracks_from_db( db, N_tracks, pause_s = 0.25 ) )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} tracks from artists similar to collection ..." )
    tracks.extend( get_tracks_from_related_artists( db, N_tracks, pause_s = 0.25 ) )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} tracks in Spotify featured playlists ..." )
    tracks.extend( get_tracks_from_featured_playlists( db, N_tracks, pause_s = 0.25 ) )
    # pprint( tracks[-1] )
    
    print( f"Search for {N_tracks} tracks using Version 01 ..." )
    tracks.extend( basic_new_music_search_01( db, N_tracks, Mper = 5, pause_s = 0.125 ) )
    # pprint( tracks[-1] )
    
    print( f"Multi-Search COMPLETE: Retreived {len(tracks)} tracks!\n" )

    ### Filter ###
    print( f"About to filter {len(tracks)} tracks ..." )
    
    # for i in range( 0, int(N_tracks/2), len(tracks) ):
    #     print( f"\n\n Track {i}:" )
    #     pprint( tracks[i] )
        
    add_audio_features_to_track_list( tracks, pause_s = 0.25 )
    
    # tracks = filter_short_and_explicit_tracks( tracks )
    tracks = filter_collected_and_reviewed_tracks( db, tracks )
    
    ### Rank by Ascending Distance to Nearest Mini-Genre ###
    print( f"About to rank {len(tracks)} tracks ..." )
    for trk_i in tracks:
        dMin_i = _ONE_BILLION
        gnre_i = _NULL_GENRE
        for gnID_j, mGenre_j in db['genres'].items():
            dist_j = mGenre_j['kdTree'].query( trk_i['vector'] )[0]
            if dist_j < dMin_i:
                dMin_i = dist_j
                gnre_i = gnID_j
        trk_i['minGenreDist' ] = dMin_i
        trk_i['mini-genre_ID'] = gnre_i
    tracks.sort( key = lambda item: item['minGenreDist'] )
    print( "\n########## Multi-Search 02: COMPLETE ##########\n" )

    ### Return Top Hits ###
    if len( tracks ) < N_tracks:
        return tracks
    else:
        return tracks[ :N_tracks ]


def refill_playlist_with_new_tracks_02( plID, db, Ntot = 400, pause_s = 0.50 ):
    """ Top off the playlist with new tracks """
    plLen = get_playlist_length( plID )
    if Ntot > plLen:
        nRem = Ntot - plLen
        print( f"About to add {nRem} tracks ..." )
        addTrks = guided_multi_search_version_02( db, nRem )
        addID   = [item['id'] for item in addTrks]
        Nadd    = len( addID )
        bgn     = 0
        end     = 0
        while end < Nadd:
            bgn    = end
            end    = min( end+_RESPONSE_LIMIT, Nadd )
            result = spot.user_playlist_add_tracks( CLIENT_ID, plID, addID[ bgn:end ] )
        save_music_database( db ) # Save queries we made
        print( "Playlist refill complete!" )
    else:
        print( "No room for new tracks!" )

# %%
# tracks = guided_multi_search_version_02( data, 50 )
# refill_playlist_with_new_tracks_02( review['zd_Over'], data, Ntot = 400 )

# %%
save_music_database( data )
# Out:
# About to write data/Teo-Music-Data_2024-09-04T15:37:44.pkl ...
# COMPLETE!

# %% [markdown]
# # Genre Cleanup

# %%
from random import shuffle


def set_genre_membership( db ):
    """ Make sure all genres have a membership ID hash """
    for gnreID_k, genre_k in db['genres'].items():
        if ('trackIDs' not in genre_k):
            genre_k['trackIDs'] = set([])
        for l, track_l in enumerate( genre_k['tracks'] ):
            genre_k['trackIDs'].add( track_l['id'] )
    

def get_homeless_tracks( db ):
    """ Return a list of tracks not assicated with a current mini-genre """
    set_genre_membership( db )
    rtnLst = list()
    for plName_i, playls_i in db['playlists'].items():
        for j, track_j in enumerate( playls_i['tracks'] ):
            found   = False
            trkID_j = track_j['id']
            for gnreID_k, genre_k in db['genres'].items():
                if trkID_j in genre_k['trackIDs']:
                    found = True
                    break
            if not found:
                rtnLst.append( track_j )
    shuffle( rtnLst )
    print( f"Found {len(rtnLst)} unaffiliated tracks!" )
    return rtnLst


def genretize_remainder( db, chunkSize = 500 ):
    """ Try to generate affliations for free tracks """
    freeTrks = get_homeless_tracks( db )
    NfreTrks = len( freeTrks )
    
    bgn      = 0
    end      = 0
    trkChnks = list()
    while end < NfreTrks:
        bgn = end
        end = min( end+chunkSize, NfreTrks )
        trkChnks.append( freeTrks[ bgn:end ] )

    for i, tracks_i in enumerate( trkChnks ):
        bgn_i    = now()
        gnres_i  = generate_genres_from_track_list( tracks_i, db )
        for gnre_j in gnres_i.values():
            gnre_j['origins'] = ['FreeTracks',]
        db['genres'].update( gnres_i )
        dur_i = now() - bgn_i
        print( f"\nGenre generation from {len(tracks_i)} tracks took {dur_i/60.0} minutes!\n" )
        check_API_token() # 2024-08-21: This process can take a while on my home machine


def recruit_remainder( db ):
    """ Attempt to move free tracks to already-generated mini-genres """
    freeTrks = get_homeless_tracks( db )
    NfreTrks = len( freeTrks )
    totCount = 0

    def membership_score( qPnt, kNNpts ):
        """ Return a score that expresses cluster membership, Higher is better, -1 means not a member """
        if (len(kNNpts) < _DBS_MIN_MMBR):
            return -1
        dists = sorted( [item[0] for item in kNNpts] )
        insid = 0
        score = 0
        for i, p_i in enumerate( kNNpts ):
            d_i    = np.linalg.norm( np.subtract( qPnt, p_i ) )
            score += np.exp( -d_i ) # The closer it is, the larger this number    
        return score

    for i, track_i in enumerate( freeTrks ):
        if (i%100==0):
            print( '.', end='', flush=1 )
        hiScore = -1
        hiGenre = None
        
        for gnreID_j, genre_j in db['genres'].items():
            nn_j = genre_j['kdTree'].query_ball_point( track_i['vector'], _DBS_EPSILON )
            nn_j = [genre_j['vectors'][ index ] for index in nn_j]
            sc_j = membership_score( track_i['vector'], nn_j )
            if sc_j > hiScore:
                hiScore = sc_j
                hiGenre = gnreID_j
                
        if (hiGenre is not None):
            db['genres'][ hiGenre ]['tracks' ].append( track_i )
            db['genres'][ hiGenre ]['changed'] = True
            totCount += 1
    print()

    for gnre in db['genres'].values():         
        if gnre.get( 'changed', False ):
            print( f"Recalculating  {gnre['nameLocal']}  ..." )
            genre_vector_ops( gnre )
            gnre['changed'] = False

    set_genre_membership( db )
    print( f"Found homes for {totCount} free tracks!" )
    get_homeless_tracks( db )


def populate_releases( db ):
    """ Make sure releases are populated """
    
    for plName_i, plyLst_i in db['playlists'].items():
        print( plName_i, '-', plyLst_i['ID'], '...' )
        tracks_i = plyLst_i['tracks']
        assign_vectors_to_tracks( tracks_i )

        # Catalog artists from collection tracks (Req'd for (Sub-)Search 01)
        for track_j in tracks_i:
            for artist_k in track_j['track']['artists']:
                artistID_j = artist_k['id']
                if artistID_j not in db['artists']:
                    db['artists'][ artistID_j ] = { 
                        'name'    : track_j['track']['artists'][0]['name'], 
                        'count'   : 1, 
                        'releases': [track_j['track']['album']['release_date'],], 
                    }
                else:
                    db['artists'][ artistID_j ]['count'   ] += 1
                    db['artists'][ artistID_j ]['releases'].append( track_j['track']['album']['release_date'] )

# %%
genretize_remainder( data, chunkSize = 500 )
# Out:
# TOKEN OBTAINED
# TOKEN STILL VALID, AGE: 0.04081089893976848 MINUTES
# TOKEN STILL VALID, AGE: 0.0469593087832133 MINUTES
# TOKEN STILL VALID, AGE: 0.05475239753723145 MINUTES
# They-New Jack Swing | soul | {'indie soul': 0.017475728155339806, 'jazz pop': 0.005825242718446602, 'alternative hip hop': 0.003883495145631068, 'hip hop': 0.013592233009708738, 'instrumental hip hop': 0.003883495145631068, 'north carolina hip hop': 0.003883495145631068, 'neo soul': 0.009708737864077669, 'soul': 0.02524271844660194, 'louisiana blues': 0.003883495145631068, 'motown': 0.009708737864077669, 'new orleans blues': 0.001941747572815534, 'piano blues': 0.001941747572815534, 'rock-and-roll': 0.001941747572815534, 'rockabilly': 0.001941747572815534, 'alternative r&b': 0.009708737864077669, 'atl hip hop': 0.003883495145631068, 'conscious hip hop': 0.009708737864077669, 'old school atlanta hip hop': 0.001941747572815534, 'acoustic pop': 0.005825242718446602, 'indie folk': 0.017475728155339806, 'neo mellow': 0.005825242718446602, 'new americana': 0.02524271844660194, 'stomp and holler': 0.015533980582524271, 'modern folk rock': 0.009708737864077669, 'instrumental soul': 0.001941747572815534, 'boston rock': 0.001941747572815534, 'deep new americana': 0.003883495145631068, 'nashville indie': 0.001941747572815534, 'r&b': 0.011650485436893204, 'rap': 0.013592233009708738, 'lafayette indie': 0.001941747572815534, 'boy band': 0.001941747572815534, 'contemporary r&b': 0.003883495145631068, 'new jack swing': 0.005825242718446602, 'urban contemporary': 0.003883495145631068, 'minneapolis indie': 0.001941747572815534, 'art pop': 0.009708737864077669, 'electro-pop francais': 0.001941747572815534, 'metropopolis': 0.003883495145631068, 'shimmer pop': 0.003883495145631068, 'chamber pop': 0.007766990291262136, 'funk rock': 0.003883495145631068, 'jam band': 0.005825242718446602, 'new orleans funk': 0.003883495145631068, 'folktronica': 0.001941747572815534, 'albany ny indie': 0.001941747572815534, 'brooklyn indie': 0.001941747572815534, 'countrygaze': 0.001941747572815534, 'indie pop': 0.003883495145631068, 'indie rock': 0.007766990291262136, 'small room': 0.001941747572815534, 'classic soul': 0.017475728155339806, 'northern soul': 0.001941747572815534, 'quiet storm': 0.005825242718446602, 'vocal jazz': 0.009708737864077669, 'blues': 0.009708737864077669, 'blues rock': 0.005825242718446602, 'classic rock': 0.007766990291262136, 'electric blues': 0.005825242718446602, 'jazz blues': 0.009708737864077669, 'soul blues': 0.005825242718446602, 'traditional blues': 0.011650485436893204, 'southern americana': 0.001941747572815534, 'modern blues': 0.013592233009708738, 'modern blues rock': 0.011650485436893204, 'stomp and whittle': 0.003883495145631068, 'escape room': 0.003883495145631068, 'trap queen': 0.001941747572815534, 'canadian contemporary r&b': 0.001941747572815534, 'canadian pop': 0.001941747572815534, 'pop': 0.007766990291262136, 'neo r&b': 0.005825242718446602, 'uk contemporary r&b': 0.003883495145631068, 'indie r&b': 0.001941747572815534, 'piano rock': 0.001941747572815534, 'pop rock': 0.003883495145631068, 'viral pop': 0.001941747572815534, 'brass band': 0.001941747572815534, 'new orleans jazz': 0.001941747572815534, 'second line': 0.001941747572815534, 'street band': 0.001941747572815534, 'alternative country': 0.009708737864077669, 'north carolina indie': 0.001941747572815534, 'north carolina roots': 0.001941747572815534, 'underground hip hop': 0.007766990291262136, 'dance pop': 0.003883495145631068, 'dance rock': 0.003883495145631068, 'permanent wave': 0.003883495145631068, 'rock': 0.011650485436893204, 'delta blues': 0.001941747572815534, 'memphis blues': 0.001941747572815534, 'alabama indie': 0.001941747572815534, 'pop rap': 0.007766990291262136, 'portland hip hop': 0.001941747572815534, 'retro soul': 0.003883495145631068, 'alternative rock': 0.003883495145631068, 'britpop': 0.001941747572815534, 'scottish indie': 0.001941747572815534, 'jazz cover': 0.001941747572815534, 'swing': 0.001941747572815534, 'canadian indie folk': 0.001941747572815534, 'quebec indie': 0.001941747572815534, 'american folk revival': 0.003883495145631068, ' ...
# TOKEN STILL VALID, AGE: 0.11699757178624472 MINUTES
# Moog-Indie Soul | soul | {'modern blues rock': 0.03225806451612903, 'funk': 0.03225806451612903, 'soul': 0.06451612903225806, 'dance-punk': 0.03225806451612903, 'garage rock': 0.03225806451612903, 'blues rock': 0.03225806451612903, 'country rock': 0.03225806451612903, 'electric blues': 0.03225806451612903, 'folk': 0.03225806451612903, 'folk rock': 0.03225806451612903, 'jam band': 0.03225806451612903, 'mellow gold': 0.03225806451612903, 'roots rock': 0.03225806451612903, 'southern rock': 0.03225806451612903, 'swamp rock': 0.03225806451612903, 'modern blues': 0.03225806451612903, 'dub': 0.03225806451612903, 'lovers rock': 0.03225806451612903, 'reggae': 0.03225806451612903, 'rocksteady': 0.03225806451612903, 'roots reggae': 0.03225806451612903, 'alternative r&b': 0.03225806451612903, 'british soul': 0.03225806451612903, 'indie soul': 0.03225806451612903, 'neo soul': 0.03225806451612903, 'pop soul': 0.03225806451612903, 'j-rock': 0.03225806451612903, 'japanese alternative pop': 0.03225806451612903, 'baroque pop': 0.03225806451612903, 'australian r&b': 0.03225806451612903}
# TOKEN STILL VALID, AGE: 0.19281280835469564 MINUTES
# Noe-Roots Rock | indie folk | {'indie folk': 0.05263157894736842, 'new americana': 0.05263157894736842, 'western americana': 0.02631578947368421, 'art pop': 0.02631578947368421, 'downtempo': 0.05263157894736842, 'electronica': 0.02631578947368421, 'indie soul': 0.05263157894736842, 'indietronica': 0.05263157894736842, 'shimmer pop': 0.02631578947368421, 'modern blues': 0.02631578947368421, 'neo soul': 0.05263157894736842, 'soul': 0.05263157894736842, 'indie pop': 0.05263157894736842, 'modern dream pop': 0.02631578947368421, 'pov: indie': 0.02631578947368421, 'vapor soul': 0.02631578947368421, 'jazztronica': 0.02631578947368421, 'trip hop': 0.02631578947368421, 'british soul': 0.02631578947368421, 'pop soul': 0.02631578947368421, 'nyc pop': 0.02631578947368421, 'rva indie': 0.02631578947368421, 'alternative country': 0.02631578947368421, 'folk': 0.02631578947368421, 'heartland rock': 0.02631578947368421, 'outlaw country': 0.02631578947368421, 'roots rock': 0.02631578947368421, 'singer-songwriter': 0.02631578947368421, 'boston rock': 0.02631578947368421, 'uk contemporary r&b': 0.02631578947368421}
# TOKEN STILL VALID, AGE: 0.21691813468933105 MINUTES
# George-Rock-and-roll | southern soul | {'indie folk': 0.1, 'modern folk rock': 0.1, 'new americana': 0.1, 'stomp and holler': 0.1, 'classic soul': 0.1, 'southern soul': 0.2, 'memphis soul': 0.1, 'rock-and-roll': 0.1, 'rockabilly': 0.1}
# TOKEN STILL VALID, AGE: 0.23392715454101562 MINUTES
# Lot-Latin Alternative | latin alternative | {'colombian hip hop': 0.0625, 'colombian pop': 0.0625, 'latin alternative': 0.125, 'reggaeton colombiano': 0.0625, 'salsa choke': 0.0625, 'classic soul': 0.0625, 'quiet storm': 0.0625, 'soul': 0.0625, 'southern soul': 0.0625, 'latin afrobeat': 0.0625, 'latin funk': 0.0625, 'latin rock': 0.0625, 'rock en espanol': 0.0625, 'venezuelan indie': 0.0625, 'venezuelan rock': 0.0625}
#
# ########## Genre extraction COMPLETE! ##########
#
#
# Genre generation from 500 tracks took 4.571086104710897 minutes!
#
# TOKEN STILL VALID, AGE: 0.24078936576843263 MINUTES
#
# ########## Extract genre info from 500 tracks! ##########
#
# Identified 7 genres in this collection of 500 tracks!
# TOKEN STILL VALID, AGE: 5.033664898077647 MINUTES
# TOKEN STILL VALID, AGE: 5.040015347798666 MINUTES
# TOKEN STILL VALID, AGE: 5.050975163777669 MINUTES
# TOKEN STILL VALID, AGE: 5.057263970375061 MINUTES
# TOKEN STILL VALID, AGE: 5.064090347290039 MINUTES
# Nat-Soft Rock | new americana | {'indie soul': 0.020257826887661142, 'neo soul': 0.01289134438305709, 'soul': 0.022099447513812154, 'glam rock': 0.001841620626151013, 'baroque pop': 0.003683241252302026, 'modern rock': 0.009208103130755065, 'neo mellow': 0.009208103130755065, 'uk alternative pop': 0.003683241252302026, 'boston rock': 0.001841620626151013, 'indie folk': 0.009208103130755065, 'new americana': 0.02578268876611418, 'europop': 0.001841620626151013, 'swedish pop': 0.001841620626151013, 'alternative country': 0.007366482504604052, 'modern folk rock': 0.0055248618784530384, 'rhode island indie': 0.001841620626151013, 'stomp and holler': 0.016574585635359115, 'funk': 0.009208103130755065, 'instrumental soul': 0.001841620626151013, 'jazz funk': 0.001841620626151013, 'new orleans funk': 0.001841620626151013, 'p funk': 0.0055248618784530384, 'anti-folk': 0.001841620626151013, 'alternative r&b': 0.014732965009208104, 'canadian contemporary r&b': 0.003683241252302026, 'funk rock': 0.001841620626151013, 'minneapolis sound': 0.001841620626151013, 'rock': 0.016574585635359115, 'synth funk': 0.003683241252302026, 'idol': 0.003683241252302026, 'adult standards': 0.003683241252302026, 'classic soul': 0.01289134438305709, 'jazz blues': 0.007366482504604052, 'piano blues': 0.003683241252302026, 'soul blues': 0.007366482504604052, 'vocal jazz': 0.0055248618784530384, 'g funk': 0.001841620626151013, 'oakland hip hop': 0.001841620626151013, 'west coast rap': 0.001841620626151013, 'disco': 0.007366482504604052, 'quiet storm': 0.0055248618784530384, 'southern soul': 0.014732965009208104, 'seattle indie': 0.003683241252302026, 'dance pop': 0.001841620626151013, 'edm': 0.001841620626151013, 'electro house': 0.001841620626151013, 'moombahton': 0.001841620626151013, 'pop': 0.009208103130755065, 'pop dance': 0.001841620626151013, 'british invasion': 0.003683241252302026, 'classic rock': 0.016574585635359115, 'merseybeat': 0.003683241252302026, 'psychedelic rock': 0.003683241252302026, 'deep new americana': 0.003683241252302026, 'east coast hip hop': 0.003683241252302026, 'gangster rap': 0.001841620626151013, 'hip hop': 0.007366482504604052, 'pop rap': 0.001841620626151013, 'queens hip hop': 0.003683241252302026, 'rap': 0.003683241252302026, 'folk rock': 0.007366482504604052, 'colombian pop': 0.001841620626151013, 'indietronica': 0.014732965009208104, 'metropopolis': 0.003683241252302026, 'albany ny indie': 0.001841620626151013, 'northern soul': 0.001841620626151013, 'country rock': 0.007366482504604052, 'southern rock': 0.0055248618784530384, 'swamp rock': 0.003683241252302026, 'art pop': 0.01289134438305709, 'brooklyn indie': 0.003683241252302026, 'chamber pop': 0.007366482504604052, 'countrygaze': 0.003683241252302026, 'indie pop': 0.007366482504604052, 'indie rock': 0.011049723756906077, 'small room': 0.001841620626151013, 'motown': 0.003683241252302026, 'post-disco': 0.003683241252302026, 'british soul': 0.007366482504604052, 'pop soul': 0.0055248618784530384, 'uk pop': 0.0055248618784530384, 'swamp pop': 0.0055248618784530384, 'reggae fusion': 0.001841620626151013, 'scandinavian r&b': 0.003683241252302026, 'swedish soul': 0.001841620626151013, 'denver indie': 0.001841620626151013, 'elephant 6': 0.001841620626151013, 'lo-fi': 0.001841620626151013, 'downtempo': 0.0055248618784530384, 'electronica': 0.003683241252302026, 'latin alternative': 0.001841620626151013, 'nu jazz': 0.003683241252302026, 'nu-cumbia': 0.001841620626151013, 'trip hop': 0.003683241252302026, 'atl hip hop': 0.001841620626151013, 'futuristic swag': 0.001841620626151013, 'uk contemporary r&b': 0.009208103130755065, 'folk': 0.020257826887661142, 'heartland rock': 0.001841620626151013, 'outlaw country': 0.0055248618784530384, 'roots rock': 0.0055248618784530384, 'singer-songwriter': 0.020257826887661142, 'neo r&b': 0.009208103130755065, 'acoustic pop': 0.003683241252302026, 'alternative roots rock': 0.001841620626151013, 'australian indigenous music': 0.001841620626151013, ...
# TOKEN STILL VALID, AGE: 5.093931710720062 MINUTES
# The-Acoustic Blues | acoustic blues | {'acoustic blues': 0.05263157894736842, 'gospel blues': 0.05263157894736842, 'traditional blues': 0.05263157894736842, 'afropop': 0.05263157894736842, 'south african jazz': 0.05263157894736842, 'xhosa': 0.05263157894736842, 'indie surf': 0.05263157894736842, 'neo-psychedelic': 0.05263157894736842, 'noise pop': 0.05263157894736842, 'rhythm and blues': 0.05263157894736842, 'southern soul': 0.05263157894736842, 'rock-and-roll': 0.05263157894736842, 'rockabilly': 0.05263157894736842, 'nashville sound': 0.05263157894736842, 'alternative r&b': 0.05263157894736842, 'australian hip hop': 0.05263157894736842, 'conscious hip hop': 0.05263157894736842, 'escape room': 0.05263157894736842, 'zambian hip hop': 0.05263157894736842}
# TOKEN STILL VALID, AGE: 5.114242740472158 MINUTES
# Nerve-Neo-psychedelic | cymraeg | {'cymraeg': 0.08333333333333333, 'indie soul': 0.08333333333333333, 'neo-psychedelic': 0.08333333333333333, 'world': 0.08333333333333333, 'blues': 0.08333333333333333, 'blues rock': 0.08333333333333333, 'country rock': 0.08333333333333333, 'electric blues': 0.08333333333333333, 'modern blues': 0.08333333333333333, 'southern rock': 0.08333333333333333, 'texas blues': 0.08333333333333333, 'charlotte nc indie': 0.08333333333333333}
# TOKEN STILL VALID, AGE: 5.136513928572337 MINUTES
# Fed-Trap Queen | indie soul | {'indie soul': 0.14285714285714285, 'jazz pop': 0.14285714285714285, 'electro swing': 0.14285714285714285, 'charlotte nc indie': 0.14285714285714285, 'new jersey underground rap': 0.14285714285714285, 'trap queen': 0.14285714285714285, 'la indie': 0.14285714285714285}
# TOKEN STILL VALID, AGE: 5.171411220232645 MINUTES
# Sac-Classic Rock | hip hop | {'bay area indie': 0.034482758620689655, 'blues rock': 0.034482758620689655, 'classic canadian rock': 0.034482758620689655, 'classic rock': 0.034482758620689655, 'cosmic american': 0.034482758620689655, 'country rock': 0.034482758620689655, 'folk': 0.034482758620689655, 'folk rock': 0.034482758620689655, 'heartland rock': 0.034482758620689655, 'jam band': 0.034482758620689655, 'mellow gold': 0.034482758620689655, 'rock': 0.034482758620689655, 'roots rock': 0.034482758620689655, 'southern rock': 0.034482758620689655, 'swamp rock': 0.034482758620689655, 'alternative country': 0.034482758620689655, 'classic texas country': 0.034482758620689655, 'hip hop': 0.06896551724137931, 'pop rap': 0.034482758620689655, 'r&b': 0.06896551724137931, 'southern hip hop': 0.034482758620689655, 'trap': 0.034482758620689655, 'trap soul': 0.034482758620689655, 'art pop': 0.034482758620689655, 'canadian contemporary r&b': 0.034482758620689655, 'pittsburgh rap': 0.034482758620689655, 'rap': 0.034482758620689655}
# TOKEN STILL VALID, AGE: 5.187085787455241 MINUTES
# Brakes-Surf Punk Nome | bubblegrunge | {'bubblegrunge': 0.1, 'countrygaze': 0.1, 'surf punk': 0.1, 'alternative hip hop': 0.1, 'conscious hip hop': 0.1, 'oakland hip hop': 0.1, 'political hip hop': 0.1, 'vapor pop': 0.1, 'new romantic': 0.1, 'synthpop': 0.1}
# TOKEN STILL VALID, AGE: 5.2109900633494055 MINUTES
# Dust-Lgbtq+ Hip Hop | alternative r&b | {'alternative r&b': 0.14285714285714285, 'escape room': 0.07142857142857142, 'indie soul': 0.14285714285714285, 'lgbtq+ hip hop': 0.07142857142857142, 'neo soul': 0.14285714285714285, 'soul': 0.07142857142857142, 'cali rap': 0.07142857142857142, 'oakland hip hop': 0.07142857142857142, 'gothic americana': 0.07142857142857142, 'r&b': 0.07142857142857142, 'urban contemporary': 0.07142857142857142}
#
# ########## Genre extraction COMPLETE! ##########
#
#
# Genre generation from 500 tracks took 4.975851865609487 minutes!
#
# TOKEN STILL VALID, AGE: 5.216641815503438 MINUTES
#
# ########## Extract genre info from 232 tracks! ##########
#
# Identified 5 genres in this collection of 232 tracks!
# TOKEN STILL VALID, AGE: 5.350179505348206 MINUTES
# Yob-R&b | alternative r&b | {'acoustic pop': 0.024390243902439025, 'indie folk': 0.024390243902439025, 'neo mellow': 0.024390243902439025, 'new americana': 0.024390243902439025, 'stomp and holler': 0.024390243902439025, 'alternative r&b': 0.04878048780487805, 'indie soul': 0.024390243902439025, 'nyc pop': 0.04878048780487805, 'pop soul': 0.024390243902439025, 'classic soul': 0.024390243902439025, 'jazz blues': 0.024390243902439025, 'memphis soul': 0.024390243902439025, 'soul': 0.024390243902439025, 'southern soul': 0.024390243902439025, 'vocal jazz': 0.024390243902439025, 'deep new americana': 0.024390243902439025, 'new england americana': 0.024390243902439025, 'one-person band': 0.024390243902439025, 'western mass indie': 0.024390243902439025, 'bay area indie': 0.024390243902439025, 'canadian pop': 0.024390243902439025, 'neo soul': 0.024390243902439025, 'r&b': 0.024390243902439025, 'urban contemporary': 0.024390243902439025, 'trova': 0.024390243902439025, 'brooklyn indie': 0.024390243902439025, 'pov: indie': 0.024390243902439025, 'scandinavian r&b': 0.024390243902439025, 'swedish soul': 0.024390243902439025, 'alternative country': 0.024390243902439025, 'american folk revival': 0.024390243902439025, 'cosmic american': 0.024390243902439025, 'folk': 0.024390243902439025, 'outlaw country': 0.024390243902439025, 'singer-songwriter': 0.024390243902439025, 'bubblegrunge': 0.024390243902439025, 'countrygaze': 0.024390243902439025, 'indie punk': 0.024390243902439025, 'riot grrrl': 0.024390243902439025}
# TOKEN STILL VALID, AGE: 5.36730569601059 MINUTES
# Romantic-Neo Soul | alternative r&b | {'neo r&b': 0.07692307692307693, 'neo soul': 0.07692307692307693, 'north carolina hip hop': 0.07692307692307693, 'alternative r&b': 0.3076923076923077, 'uk contemporary r&b': 0.15384615384615385, 'cali rap': 0.07692307692307693, 'oakland hip hop': 0.07692307692307693, 'vapor pop': 0.07692307692307693, 'indie r&b': 0.07692307692307693}
# TOKEN STILL VALID, AGE: 5.421965308984121 MINUTES
# Love-Atl Hip Hop | alternative r&b | {'alternative r&b': 0.047619047619047616, 'indie soul': 0.047619047619047616, 'neo r&b': 0.047619047619047616, 'australian americana': 0.047619047619047616, 'atl hip hop': 0.047619047619047616, 'dirty south rap': 0.047619047619047616, 'gangster rap': 0.047619047619047616, 'hip hop': 0.047619047619047616, 'pop rap': 0.047619047619047616, 'rap': 0.047619047619047616, 'southern hip hop': 0.047619047619047616, 'trap': 0.047619047619047616, 'dance pop': 0.047619047619047616, 'pop': 0.047619047619047616, 'r&b': 0.047619047619047616, 'urban contemporary': 0.047619047619047616, 'austindie': 0.047619047619047616, 'experimental hip hop': 0.047619047619047616, 'classic uk pop': 0.047619047619047616, 'shimmer pop': 0.047619047619047616, 'stomp and whittle': 0.047619047619047616}
# TOKEN STILL VALID, AGE: 5.439082272847494 MINUTES
# Time-Melancholia | art pop | {'art pop': 0.07692307692307693, 'chamber pop': 0.07692307692307693, 'indie rock': 0.07692307692307693, 'melancholia': 0.07692307692307693, 'new jersey indie': 0.07692307692307693, 'singer-songwriter': 0.07692307692307693, 'alternative r&b': 0.07692307692307693, 'canadian contemporary r&b': 0.07692307692307693, 'indie soul': 0.07692307692307693, 'modern alternative pop': 0.07692307692307693, 'uk pop': 0.07692307692307693, 'vapor pop': 0.07692307692307693, 'chill r&b': 0.07692307692307693}
# TOKEN STILL VALID, AGE: 5.45266539255778 MINUTES
# Ssh-Rap | r&b | {'r&b': 0.1, 'rap': 0.1, 'uk contemporary r&b': 0.1, 'urban contemporary': 0.1, 'brooklyn indie': 0.1, 'pov: indie': 0.1, 'album rock': 0.1, 'classic rock': 0.1, 'hard rock': 0.1, 'rock': 0.1}
#
# ########## Genre extraction COMPLETE! ##########
#
#
# Genre generation from 232 tracks took 0.24143428405125936 minutes!
#
# TOKEN STILL VALID, AGE: 5.458076512813568 MINUTES

# %%
merge_micro_genres_in_db( data )
# Out:
# ########## Attempt to merge similar genres in the music database ##########
# There are 4 merge jobs to perform!
#
# Merge:
# 	Lick-Traditional Soul
# 		-and-
# 	Wive-West Coast Rap
# 		-and-
# 	Lam-Black Americana
# 		-and-
# 	Pays-Contemporary Vocal Jazz
# 		-and-
# 	Heartbreaker-Roots Hip Hop
# 		-and-
# 	Borg-Queens Hip Hop
# 		-and-
# 	Lire-Trap
# 		-and-
# 	Mai-Urban Contemporary
# 		-and-
# 	Fame-Southern Soul
# 		-and-
# 	Snow-Philly Rap
# 		-and-
# 	Mack-Pop R&b
# 		-and-
# 	Toto-Roots Reggae
# 		-and-
# 	Chromosome-Rock Country
# 		-and-
# 	She-Indie Rock
# 		-and-
# 	Oder-Dance Contemporary
# 		-and-
# 	Wham-Classic Soul
# Components: 0, 115, ['Lick-Traditional', 'Soul']
# Components: 1, 117, ['Wive-West', 'Coast', 'Rap']
# Components: 2, 112, ['Lam-Black', 'Americana']
# Components: 3, 121, ['Pays-Contemporary', 'Vocal', 'Jazz']
# Components: 4, 114, ['Heartbreaker-Roots', 'Hip', 'Hop']
# Components: 5, 128, ['Borg-Queens', 'Hip', 'Hop']
# Components: 6, 129, ['Lire-Trap']
# Components: 7, 132, ['Mai-Urban', 'Contemporary']
# Components: 8, 121, ['Fame-Southern', 'Soul']
# Components: 9, 72, ['Snow-Philly', 'Rap']
# Components: 10, 135, ['Mack-Pop', 'R&b']
# Components: 11, 65, ['Toto-Roots', 'Reggae']
# Components: 12, 284, ['Chromosome-Rock', 'Country']
# Components: 13, 110, ['She-Indie', 'Rock']
# Components: 14, 307, ['Oder-Dance', 'Contemporary']
# Components: 15, 115, ['Wham-Classic', 'Soul']
# Token: Mack-Pop
# Components: 0, 115, ['Lick-Traditional', 'Soul']
# Components: 1, 117, ['Wive-West', 'Coast', 'Rap']
# Components: 2, 112, ['Lam-Black', 'Americana']
# Components: 3, 121, ['Pays-Contemporary', 'Vocal', 'Jazz']
# Components: 4, 114, ['Heartbreaker-Roots', 'Hip', 'Hop']
# Components: 5, 128, ['Borg-Queens', 'Hip', 'Hop']
# Components: 6, 129, ['Lire-Trap']
# Components: 7, 132, ['Mai-Urban', 'Contemporary']
# Components: 8, 121, ['Fame-Southern', 'Soul']
# Components: 9, 72, ['Snow-Philly', 'Rap']
# Components: 10, 135, ['Mack-Pop', 'R&b']
# Components: 11, 65, ['Toto-Roots', 'Reggae']
# Components: 12, 284, ['Chromosome-Rock', 'Country']
# Components: 13, 110, ['She-Indie', 'Rock']
# Components: 14, 307, ['Oder-Dance', 'Contemporary']
# Components: 15, 115, ['Wham-Classic', 'Soul']
# Token: Contemporary
# Components: 0, 115, ['Lick-Traditional', 'Soul']
# Components: 1, 117, ['Wive-West', 'Coast', 'Rap']
# Components: 2, 112, ['Lam-Black', 'Americana']
# Components: 3, 121, ['Pays-Contemporary', 'Vocal', 'Jazz']
# Components: 4, 114, ['Heartbreaker-Roots', 'Hip', 'Hop']
# Components: 5, 128, ['Borg-Queens', 'Hip', 'Hop']
# Components: 6, 129, ['Lire-Trap']
# Components: 7, 132, ['Mai-Urban', 'Contemporary']
# Components: 8, 121, ['Fame-Southern', 'Soul']
# Components: 9, 72, ['Snow-Philly', 'Rap']
# Components: 10, 135, ['Mack-Pop', 'R&b']
# Components: 11, 65, ['Toto-Roots', 'Reggae']
# Components: 12, 284, ['Chromosome-Rock', 'Country']
# Components: 13, 110, ['She-Indie', 'Rock']
# Components: 14, 307, ['Oder-Dance', 'Contemporary']
# Components: 15, 115, ['Wham-Classic', 'Soul']
# Token: Jazz
# Merge Complete!: New Mini-Genre Mack-Pop Contemporary Jazz (04354c0d-2eab-41e9-8b10-14fa6b1605de) created with 2177 tracks!
#
# Merge:
# Merge Complete!: New Mini-Genre Music (27dc3341-58ef-4b78-9e11-cd9bc7c31e4b) created with 0 tracks!
#
# Merge:
# 	Pays-Indie Soul Katie
# 		-and-
# 	They-New Jack Swing
# Components: 0, 7, ['Pays-Indie', 'Soul', 'Katie']
# Components: 1, 193, ['They-New', 'Jack', 'Swing']
# Token: They-New
# Components: 0, 7, ['Pays-Indie', 'Soul', 'Katie']
# Components: 1, 193, ['They-New', 'Jack', 'Swing']
# Token: Jack
# Components: 0, 7, ['Pays-Indie', 'Soul', 'Katie']
# Components: 1, 193, ['They-New', 'Jack', 'Swing']
# Token: Swing
# Merge Complete!: New Mini-Genre They-New Jack Swing (df5deeea-a04b-44b2-bb5a-e9cc934de2c0) created with 200 tracks!
#
# Merge:
# 	Noe-Roots Rock
# 		-and-
# 	Nat-Soft Rock
# Components: 0, 12, ['Noe-Roots', 'Rock']
# Components: 1, 219, ['Nat-Soft', 'Rock']
# Token: Nat-Soft
# Components: 0, 12, ['Noe-Roots', 'Rock']
# Components: 1, 219, ['Nat-Soft', 'Rock']
# Token: Rock
# Merge Complete!: New Mini-Genre Nat-Soft Rock (427bd424-c7d1-447e-b690-42d125968cd7) created with 231 tracks!

# %%
move_mini_genre_outliers_to_better_homes( data )
# Out:
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  They-New Jack Swing
# Moving track 0 of  Thea-Jazz Blues  --to->  Nat-Soft Rock
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  They-New Jack Swing
# Moving track 0 of  Thea-Jazz Blues  --to->  Nat-Soft Rock
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mus-Pop Soul
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Soul-Quiet Storm
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Thea-Jazz Blues  --to->  Wan-Folk Soul
# Moving track 0 of  Pews-Bebop  --to->  Nat-Soft Rock
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Wan-Folk Soul
# Moving track 0 of  Pews-Bebop  --to->  They-New Jack Swing
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  They-New Jack Swing
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mus-Pop Soul
# Moving track 0 of  Pews-Bebop  --to->  Mus-Pop Soul
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  2003-Permanent Wave
# Moving track 0 of  Pews-Bebop  --to->  Mus-Pop Soul
# Moving track 0 of  Pews-Bebop  --to->  They-New Jack Swing
# Moving track 0 of  Pews-Bebop  --to->  They-New Jack Swing
# Moving track 0 of  Pews-Bebop  --to->  Nat-Soft Rock
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Nat-Soft Rock
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Pews-Bebop  --to->  Wan-Folk Soul
# Moving track 0 of  Pews-Bebop  --to->  Wan-Folk Soul
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  They-New Jack Swing
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Yob-R&b
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Wan-Folk Soul
# Moving track 0 of  2003-Permanent Wave  --to->  They-New Jack Swing
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  2003-Permanent Wave  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Pews-Bebop
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  They-New Jack Swing
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Pews-Bebop
# Moving track 0 of  Wan-Folk Soul  --to->  Pews-Bebop
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Wan-Folk Soul  --to->  They-New Jack Swing
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mus-Pop Soul
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  They-New Jack Swing
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Wan-Folk Soul  --to->  Romantic-Neo Soul
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Grandparent-Ann Arbor Indie
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Pews-Bebop
# Moving track 0 of  Wan-Folk Soul  --to->  Romantic-Neo Soul
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  They-New Jack Swing
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  They-New Jack Swing
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Romantic-Neo Soul
# Moving track 0 of  Wan-Folk Soul  --to->  They-New Jack Swing
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Wan-Folk Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Wan-Folk Soul
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Yob-R&b
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Yob-R&b
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  2003-Permanent Wave
# Moving track 0 of  Mus-Pop Soul  --to->  Thea-Jazz Blues
# Moving track 0 of  Mus-Pop Soul  --to->  Pews-Bebop
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Yob-R&b
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Ssh-Rap
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Yob-R&b
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Love-Atl Hip Hop
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Ssh-Rap
# Moving track 0 of  Mus-Pop Soul  --to->  George-Rock-and-roll
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Pews-Bebop
# Moving track 0 of  Mus-Pop Soul  --to->  Wan-Folk Soul
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Yob-R&b
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Wan-Folk Soul
# Moving track 0 of  Mus-Pop Soul  --to->  Yob-R&b
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Thea-Jazz Blues
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Pews-Bebop
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  Nat-Soft Rock
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Thea-Jazz Blues
# Moving track 0 of  Mus-Pop Soul  --to->  They-New Jack Swing
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Mus-Pop Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Wan-Folk Soul
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  They-New Jack Swing
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Wan-Folk Soul
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Sac-Classic Rock
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  They-New Jack Swing
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  They-New Jack Swing
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Danger-Uk Alternative Pop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Dix-Cowpunk  --to->  Nat-Soft Rock
# Moving track 0 of  Dix-Cowpunk  --to->  Nat-Soft Rock
# Moving track 0 of  Dix-Cowpunk  --to->  Nat-Soft Rock
# Moving track 0 of  Dix-Cowpunk  --to->  They-New Jack Swing
# Moving track 0 of  Dix-Cowpunk  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Dix-Cowpunk  --to->  They-New Jack Swing
# Moving track 0 of  Dix-Cowpunk  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Dix-Cowpunk  --to->  Wan-Folk Soul
# Moving track 0 of  Dix-Cowpunk  --to->  Nat-Soft Rock
# Moving track 0 of  Dix-Cowpunk  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Dix-Cowpunk  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Dix-Cowpunk  --to->  Mack-Pop Contemporary Jazz
# Moving track 1 of  Che-Neo-traditional Bluegrass  --to->  They-New Jack Swing
# Moving track 2 of  Che-Neo-traditional Bluegrass  --to->  They-New Jack Swing
# Moving track 0 of  Soul-Quiet Storm  --to->  Thea-Jazz Blues
# Moving track 0 of  Soul-Quiet Storm  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Soul-Quiet Storm  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Soul-Quiet Storm  --to->  They-New Jack Swing
# Moving track 0 of  Soul-Quiet Storm  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Grandparent-Ann Arbor Indie  --to->  Wan-Folk Soul
# Moving track 0 of  Grandparent-Ann Arbor Indie  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Grandparent-Ann Arbor Indie  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Grandparent-Ann Arbor Indie  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Grandparent-Ann Arbor Indie  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Hellbent-Art Pop Wove  --to->  Moog-Indie Soul
# Moving track 0 of  Hellbent-Art Pop Wove  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Hellbent-Art Pop Wove  --to->  Mack-Pop Contemporary Jazz
# Moving track 1 of  Hellbent-Art Pop Wove  --to->  Mack-Pop Contemporary Jazz
# Moving track 1 of  Hellbent-Art Pop Wove  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Cot-Reggae Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Cot-Reggae Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Cot-Reggae Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Cot-Reggae Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Cot-Reggae Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Cot-Reggae Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nantucket-Outlaw Country  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nantucket-Outlaw Country  --to->  Nat-Soft Rock
# Moving track 0 of  Nantucket-Outlaw Country  --to->  Mack-Pop Contemporary Jazz
# Moving track 1 of  Nantucket-Outlaw Country  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Moog-Indie Soul  --to->  Hellbent-Art Pop Wove
# Moving track 1 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 1 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 1 of  Moog-Indie Soul  --to->  Hellbent-Art Pop Wove
# Moving track 2 of  Moog-Indie Soul  --to->  The-Acoustic Blues
# Moving track 2 of  Moog-Indie Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  George-Rock-and-roll  --to->  Nat-Soft Rock
# Moving track 0 of  Lot-Latin Alternative  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Lot-Latin Alternative  --to->  Cot-Reggae Rock
# Moving track 0 of  Lot-Latin Alternative  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Lot-Latin Alternative  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Lot-Latin Alternative  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  The-Acoustic Blues  --to->  Moog-Indie Soul
# Moving track 0 of  The-Acoustic Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  The-Acoustic Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  The-Acoustic Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  The-Acoustic Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  The-Acoustic Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  The-Acoustic Blues  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nerve-Neo-psychedelic  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nerve-Neo-psychedelic  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Fed-Trap Queen  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Fed-Trap Queen  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Fed-Trap Queen  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Fed-Trap Queen  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Fed-Trap Queen  --to->  They-New Jack Swing
# Moving track 0 of  Fed-Trap Queen  --to->  Wan-Folk Soul
# Moving track 3 of  Sac-Classic Rock  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Brakes-Surf Punk Nome  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Brakes-Surf Punk Nome  --to->  They-New Jack Swing
# Moving track 0 of  Brakes-Surf Punk Nome  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Brakes-Surf Punk Nome  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Dust-Lgbtq+ Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Dust-Lgbtq+ Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Dust-Lgbtq+ Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Dust-Lgbtq+ Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Dust-Lgbtq+ Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Dust-Lgbtq+ Hip Hop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Yob-R&b  --to->  Mus-Pop Soul
# Moving track 0 of  Yob-R&b  --to->  Mus-Pop Soul
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  2003-Permanent Wave
# Moving track 0 of  Yob-R&b  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  They-New Jack Swing
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  They-New Jack Swing
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  Mus-Pop Soul
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  Pews-Bebop
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  Mus-Pop Soul
# Moving track 0 of  Yob-R&b  --to->  Nat-Soft Rock
# Moving track 0 of  Yob-R&b  --to->  They-New Jack Swing
# Moving track 0 of  Yob-R&b  --to->  They-New Jack Swing
# Moving track 0 of  Yob-R&b  --to->  Mus-Pop Soul
# Moving track 0 of  Yob-R&b  --to->  They-New Jack Swing
# Moving track 0 of  Yob-R&b  --to->  They-New Jack Swing
# Moving track 0 of  Romantic-Neo Soul  --to->  Wan-Folk Soul
# Moving track 0 of  Romantic-Neo Soul  --to->  Wan-Folk Soul
# Moving track 0 of  Romantic-Neo Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Romantic-Neo Soul  --to->  Wan-Folk Soul
# Moving track 0 of  Romantic-Neo Soul  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Romantic-Neo Soul  --to->  Dust-Lgbtq+ Hip Hop
# Moving track 0 of  Love-Atl Hip Hop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Love-Atl Hip Hop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Love-Atl Hip Hop  --to->  Nat-Soft Rock
# Moving track 0 of  Love-Atl Hip Hop  --to->  Nat-Soft Rock
# Moving track 0 of  Love-Atl Hip Hop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Love-Atl Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Love-Atl Hip Hop  --to->  Nat-Soft Rock
# Moving track 0 of  Love-Atl Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Love-Atl Hip Hop  --to->  Nat-Soft Rock
# Moving track 0 of  Love-Atl Hip Hop  --to->  They-New Jack Swing
# Moving track 0 of  Love-Atl Hip Hop  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Love-Atl Hip Hop  --to->  Nat-Soft Rock
# Moving track 0 of  Time-Melancholia  --to->  Nat-Soft Rock
# Moving track 0 of  Time-Melancholia  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Time-Melancholia  --to->  Nat-Soft Rock
# Moving track 0 of  Time-Melancholia  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Time-Melancholia  --to->  Nat-Soft Rock
# Moving track 0 of  Ssh-Rap  --to->  They-New Jack Swing
# Moving track 0 of  Ssh-Rap  --to->  Mus-Pop Soul
# Moving track 0 of  Ssh-Rap  --to->  Nat-Soft Rock
# Moving track 0 of  Ssh-Rap  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Grandparent-Ann Arbor Indie
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Love-Atl Hip Hop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Pews-Bebop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Pews-Bebop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nerve-Neo-psychedelic
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Hellbent-Art Pop Wove
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Soul-Quiet Storm
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Mus-Pop Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Grandparent-Ann Arbor Indie
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  The-Acoustic Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Soul-Quiet Storm
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Romantic-Neo Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Grandparent-Ann Arbor Indie
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Love-Atl Hip Hop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  2003-Permanent Wave
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Grandparent-Ann Arbor Indie
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Lot-Latin Alternative
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Thea-Jazz Blues
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Nat-Soft Rock
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  They-New Jack Swing
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Danger-Uk Alternative Pop
# Moving track 0 of  Mack-Pop Contemporary Jazz  --to->  Wan-Folk Soul
# ...
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  They-New Jack Swing  --to->  Nat-Soft Rock
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  They-New Jack Swing  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Dix-Cowpunk
# Moving track 0 of  Nat-Soft Rock  --to->  Time-Melancholia
# Moving track 0 of  Nat-Soft Rock  --to->  Dix-Cowpunk
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Dix-Cowpunk
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Love-Atl Hip Hop
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Dix-Cowpunk
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Thea-Jazz Blues
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Ssh-Rap
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Ssh-Rap
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Ssh-Rap
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Love-Atl Hip Hop
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Love-Atl Hip Hop
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  2003-Permanent Wave
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  2003-Permanent Wave
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Thea-Jazz Blues
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Thea-Jazz Blues
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Nantucket-Outlaw Country
# Moving track 0 of  Nat-Soft Rock  --to->  Love-Atl Hip Hop
# Moving track 0 of  Nat-Soft Rock  --to->  George-Rock-and-roll
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Thea-Jazz Blues
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Pews-Bebop
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Wan-Folk Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Yob-R&b
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  They-New Jack Swing
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mack-Pop Contemporary Jazz
# Moving track 0 of  Nat-Soft Rock  --to->  Mus-Pop Soul
#
# ########## Genre Report ##########
#
# Filter 31 to filter...
#
# Thea-Jazz Blues, 109
# Pews-Bebop, 52
# 2003-Permanent Wave, 97
# Wan-Folk Soul, 1107
# Mus-Pop Soul, 138
# Danger-Uk Alternative Pop, 83
# Soul-Quiet Storm, 47
# Grandparent-Ann Arbor Indie, 24
# Cot-Reggae Rock, 35
# Lot-Latin Alternative, 66
# The-Acoustic Blues, 30
# Yob-R&b, 27
# Romantic-Neo Soul, 28
# Mack-Pop Contemporary Jazz, 482
# They-New Jack Swing, 381
# Nat-Soft Rock, 293
# Deleting ... 7c39d34b-9cd3-4a07-a7f3-7df977e58c01, 99f6c726-e96c-4319-9126-6288ac10e736, 9aecd78b-71e6-486d-84fc-d9a401f4cb66, c2afa9fa-19be-4d17-af5f-ef3c17b91c3c, ccac9738-4e7f-4b17-b9ed-1c292904f43f, 79d05177-232d-4e01-908e-64e3119770f4, 961b9661-d404-4a04-af60-c5c9e7c2ac8e, 84d37295-bd67-44c4-ad3b-9b060592cb85, 3bdf26c2-b406-4979-97ed-ec354ae73fba, 62e3a914-424c-4374-8e15-a6c85239cf0d, f7ceb60b-6284-4170-8644-a9ab44a92c7e, 0c420723-8cc9-4dcf-9e8c-b7517b9a5e4a, 0186bdb2-6845-4ce2-a9fd-e765d18e283a, 5f527994-b022-4319-a534-5033ebfcc44e, 27dc3341-58ef-4b78-9e11-cd9bc7c31e4b,
# Deleted 15 mini-genres, 16 remain
#
# ########## Report Complete ##########

# %%
recruit_remainder( data )
# Out:
# Found 1113 unaffiliated tracks!
# ............
# Recalculating  Thea-Jazz Blues  ...
# Recalculating  2003-Permanent Wave  ...
# Recalculating  Wan-Folk Soul  ...
# Recalculating  Mus-Pop Soul  ...
# Recalculating  Danger-Uk Alternative Pop  ...
# Recalculating  Soul-Quiet Storm  ...
# Recalculating  Cot-Reggae Rock  ...
# Recalculating  Lot-Latin Alternative  ...
# Recalculating  The-Acoustic Blues  ...
# Recalculating  Mack-Pop Contemporary Jazz  ...
# Recalculating  They-New Jack Swing  ...
# Recalculating  Nat-Soft Rock  ...
# Found homes for 262 free tracks!
# Found 851 unaffiliated tracks!

# %%
save_music_database( data ) # Save queries we made
# Out:
# About to write data/Teo-Music-Data_2024-09-04T15:37:44.pkl ...
# COMPLETE!

# %%
check_API_token()
populate_releases( data )
refill_playlist_with_new_tracks_02( review['tryouts'], data, Ntot = 100 )
# Out:
# TOKEN STILL VALID, AGE: 5.75253453652064 MINUTES
# Faves - 1orrdNx6XLlaSQV7Cmr967 ...
# Stored vectors for 4112 tracks!
# About to add 100 tracks ...
#
# ########## Guided Multi-Search, Version_02 ##########
#
# Search for 100 new releases ...
# Search for 100 recommendations ...
# Search for 100 tracks from artists similar to collection ...
# Search for 100 tracks in Spotify featured playlists ...
# ...
# ...
# Search for 100 tracks using Version 01 ...
# How Many Artists?: 2727
# 	Search, Artist: Hey Rosetta!, Around Year: 2011
# Search: artist%3AHey%20Rosetta!%20year%3A2008
# Search: artist%3AHey%20Rosetta!%20year%3A2011
# Search: artist%3AHey%20Rosetta!%20year%3A2013
# Search: artist%3AHey%20Rosetta!%20year%3A2012
# Search: artist%3AHey%20Rosetta!%20year%3A2009
# Search: artist%3AHey%20Rosetta!%20year%3A2012
# TOKEN STILL VALID, AGE: 6.2243043899536135 MINUTES
# 	Search, Artist: The Donkeys, Around Year: 2014-06-03
# Search: artist%3AThe%20Donkeys%20year%3A2017
# Search: artist%3AThe%20Donkeys%20year%3A2014
# Search: artist%3AThe%20Donkeys%20year%3A2015
# Search: artist%3AThe%20Donkeys%20year%3A2011
# Search: artist%3AThe%20Donkeys%20year%3A2016
# Search: artist%3AThe%20Donkeys%20year%3A2013
# TOKEN STILL VALID, AGE: 6.303463089466095 MINUTES
# 	Search, Artist: Vanilla, Around Year: 2015-09-20
# Search: artist%3AVanilla%20year%3A2016
# Search: artist%3AVanilla%20year%3A2017
# Search: artist%3AVanilla%20year%3A2014
# Search: artist%3AVanilla%20year%3A2012
# Search: artist%3AVanilla%20year%3A2015
# Search: artist%3AVanilla%20year%3A2016
# TOKEN STILL VALID, AGE: 6.385513822237651 MINUTES
# 	Search, Artist: Mazzy Star, Around Year: 1996-10-29
# Search: artist%3AMazzy%20Star%20year%3A1996
# Search: artist%3AMazzy%20Star%20year%3A1998
# Search: artist%3AMazzy%20Star%20year%3A1998
# Search: artist%3AMazzy%20Star%20year%3A1996
# Search: artist%3AMazzy%20Star%20year%3A1996
# Search: artist%3AMazzy%20Star%20year%3A1998
# TOKEN STILL VALID, AGE: 6.464635133743286 MINUTES
# 	Search, Artist: Indigo De Souza, Around Year: 2021-08-27
# Search: artist%3AIndigo%20De%20Souza%20year%3A2018
# Search: artist%3AIndigo%20De%20Souza%20year%3A2023
# Search: artist%3AIndigo%20De%20Souza%20year%3A2023
# Search: artist%3AIndigo%20De%20Souza%20year%3A2022
# Search: artist%3AIndigo%20De%20Souza%20year%3A2018
# Search: artist%3AIndigo%20De%20Souza%20year%3A2019
# TOKEN STILL VALID, AGE: 6.552217880884807 MINUTES
# 	Search, Artist: The Preatures, Around Year: 2014-01-01
# Search: artist%3AThe%20Preatures%20year%3A2011
# Search: artist%3AThe%20Preatures%20year%3A2016
# Search: artist%3AThe%20Preatures%20year%3A2011
# Search: artist%3AThe%20Preatures%20year%3A2017
# Search: artist%3AThe%20Preatures%20year%3A2017
# Search: artist%3AThe%20Preatures%20year%3A2012
# TOKEN STILL VALID, AGE: 6.6315953731536865 MINUTES
# 	Search, Artist: Mt. Joy, Around Year: 2022-06-03
# Search: artist%3AMt.%20Joy%20year%3A2022
# Search: artist%3AMt.%20Joy%20year%3A2019
# Search: artist%3AMt.%20Joy%20year%3A2021
# Search: artist%3AMt.%20Joy%20year%3A2023
# Search: artist%3AMt.%20Joy%20year%3A2021
# Search: artist%3AMt.%20Joy%20year%3A2021
# TOKEN STILL VALID, AGE: 6.706579240163167 MINUTES
# 	Search, Artist: Tyga, Around Year: 2022-02-25
# Search: artist%3ATyga%20year%3A2023
# Search: artist%3ATyga%20year%3A2025
# Search: artist%3ATyga%20year%3A2024
# Search: artist%3ATyga%20year%3A2021
# Search: artist%3ATyga%20year%3A2024
# Search: artist%3ATyga%20year%3A2021
# TOKEN STILL VALID, AGE: 6.787804647286733 MINUTES
# 	Search, Artist: Ghostland Observatory, Around Year: 2006
# Search: artist%3AGhostland%20Observatory%20year%3A2009
# Search: artist%3AGhostland%20Observatory%20year%3A2005
# Search: artist%3AGhostland%20Observatory%20year%3A2006
# Search: artist%3AGhostland%20Observatory%20year%3A2009
# Search: artist%3AGhostland%20Observatory%20year%3A2008
# Search: artist%3AGhostland%20Observatory%20year%3A2009
# TOKEN STILL VALID, AGE: 6.868969309329986 MINUTES
# 	Search, Artist: Horace Trahan, Around Year: 2012-08-07
# Search: artist%3AHorace%20Trahan%20year%3A2014
# Search: artist%3AHorace%20Trahan%20year%3A2010
# Search: artist%3AHorace%20Trahan%20year%3A2011
# Search: artist%3AHorace%20Trahan%20year%3A2009
# Search: artist%3AHorace%20Trahan%20year%3A2012
# Search: artist%3AHorace%20Trahan%20year%3A2012
# TOKEN STILL VALID, AGE: 6.952859270572662 MINUTES
# 	Search, Artist: Anna Ash, Around Year: 2012-04-06
# Search: artist%3AAnna%20Ash%20year%3A2009
# Search: artist%3AAnna%20Ash%20year%3A2015
# Search: artist%3AAnna%20Ash%20year%3A2009
# Search: artist%3AAnna%20Ash%20year%3A2012
# Search: artist%3AAnna%20Ash%20year%3A2013
# Search: artist%3AAnna%20Ash%20year%3A2011
# Search: artist%3AAnna%20Ash%20year%3A2010
# Search: artist%3AAnna%20Ash%20year%3A2010
# Search: artist%3AAnna%20Ash%20year%3A2011
# Search: artist%3AAnna%20Ash%20year%3A2015
# TOKEN STILL VALID, AGE: 7.083457899093628 MINUTES
# 	Search, Artist: RJD2, Around Year: 2015-05-05
# Search: artist%3ARJD2%20year%3A2015
# Search: artist%3ARJD2%20year%3A2016
# Search: artist%3ARJD2%20year%3A2015
# Search: artist%3ARJD2%20year%3A2015
# Search: artist%3ARJD2%20year%3A2016
# Search: artist%3ARJD2%20year%3A2017
# TOKEN STILL VALID, AGE: 7.164807172616323 MINUTES
# 	Search, Artist: J.J. Cale, Around Year: 1972
# Search: artist%3AJ.J.%20Cale%20year%3A1971
# Search: artist%3AJ.J.%20Cale%20year%3A1971
# Search: artist%3AJ.J.%20Cale%20year%3A1970
# Search: artist%3AJ.J.%20Cale%20year%3A1974
# Search: artist%3AJ.J.%20Cale%20year%3A1971
# Search: artist%3AJ.J.%20Cale%20year%3A1969
# TOKEN STILL VALID, AGE: 7.244871389865875 MINUTES
# 	Search, Artist: RC & The Gritz, Around Year: 2019-03-08
# Search: artist%3ARC%20&%20The%20Gritz%20year%3A2018
# Search: artist%3ARC%20&%20The%20Gritz%20year%3A2021
# Search: artist%3ARC%20&%20The%20Gritz%20year%3A2016
# Search: artist%3ARC%20&%20The%20Gritz%20year%3A2016
# Search: artist%3ARC%20&%20The%20Gritz%20year%3A2019
# Search: artist%3ARC%20&%20The%20Gritz%20year%3A2017
# TOKEN STILL VALID, AGE: 7.328253026803335 MINUTES
# 	Search, Artist: Harari, Around Year: 2015-03-09
# Search: artist%3AHarari%20year%3A2015
# Search: artist%3AHarari%20year%3A2017
# Search: artist%3AHarari%20year%3A2014
# Search: artist%3AHarari%20year%3A2014
# Search: artist%3AHarari%20year%3A2018
# Search: artist%3AHarari%20year%3A2012
# TOKEN STILL VALID, AGE: 7.410276556015015 MINUTES
# 	Search, Artist: Scott Matthews, Around Year: 2006
# Search: artist%3AScott%20Matthews%20year%3A2004
# Search: artist%3AScott%20Matthews%20year%3A2003
# Search: artist%3AScott%20Matthews%20year%3A2005
# Search: artist%3AScott%20Matthews%20year%3A2006
# Search: artist%3AScott%20Matthews%20year%3A2003
# Search: artist%3AScott%20Matthews%20year%3A2009
# TOKEN STILL VALID, AGE: 7.493418737252553 MINUTES
# 	Search, Artist: Thelma Houston, Around Year: 1991-01-01
# Search: artist%3AThelma%20Houston%20year%3A1993
# Search: artist%3AThelma%20Houston%20year%3A1989
# Search: artist%3AThelma%20Houston%20year%3A1988
# Search: artist%3AThelma%20Houston%20year%3A1990
# Search: artist%3AThelma%20Houston%20year%3A1993
# Search: artist%3AThelma%20Houston%20year%3A1994
# Search: artist%3AThelma%20Houston%20year%3A1989
# Search: artist%3AThelma%20Houston%20year%3A1988
# Search: artist%3AThelma%20Houston%20year%3A1994
# Search: artist%3AThelma%20Houston%20year%3A1990
# TOKEN STILL VALID, AGE: 7.619891186555226 MINUTES
# 	Search, Artist: Passion Pit, Around Year: 2012-07-23
# Search: artist%3APassion%20Pit%20year%3A2014
# Search: artist%3APassion%20Pit%20year%3A2014
# Search: artist%3APassion%20Pit%20year%3A2011
# Search: artist%3APassion%20Pit%20year%3A2010
# Search: artist%3APassion%20Pit%20year%3A2013
# Search: artist%3APassion%20Pit%20year%3A2015
# TOKEN STILL VALID, AGE: 7.70033282438914 MINUTES
# 	Search, Artist: Sam & Dave, Around Year: 1968
# Search: artist%3ASam%20&%20Dave%20year%3A1970
# Search: artist%3ASam%20&%20Dave%20year%3A1968
# Search: artist%3ASam%20&%20Dave%20year%3A1965
# Search: artist%3ASam%20&%20Dave%20year%3A1970
# Search: artist%3ASam%20&%20Dave%20year%3A1970
# Search: artist%3ASam%20&%20Dave%20year%3A1970
# Search: artist%3ASam%20&%20Dave%20year%3A1966
# Search: artist%3ASam%20&%20Dave%20year%3A1971
# TOKEN STILL VALID, AGE: 7.8006306171417235 MINUTES
# 	Search, Artist: Eli "Paperboy" Reed & The True Loves, Around Year: 2008-01-01
# Search: artist%3AEli%20"Paperboy"%20Reed%20&%20The%20True%20Loves%20year%3A2005
# Search: artist%3AEli%20"Paperboy"%20Reed%20&%20The%20True%20Loves%20year%3A2011
# Search: artist%3AEli%20"Paperboy"%20Reed%20&%20The%20True%20Loves%20year%3A2011
# Search: artist%3AEli%20"Paperboy"%20Reed%20&%20The%20True%20Loves%20year%3A2005
# Search: artist%3AEli%20"Paperboy"%20Reed%20&%20The%20True%20Loves%20year%3A2006
# Search: artist%3AEli%20"Paperboy"%20Reed%20&%20The%20True%20Loves%20year%3A2010
# TOKEN STILL VALID, AGE: 7.877484905719757 MINUTES
# 	Search, Artist: Samuel L Cool J, Around Year: 2014-04-29
# Search: artist%3ASamuel%20L%20Cool%20J%20year%3A2012
# Search: artist%3ASamuel%20L%20Cool%20J%20year%3A2011
# Search: artist%3ASamuel%20L%20Cool%20J%20year%3A2016
# Search: artist%3ASamuel%20L%20Cool%20J%20year%3A2017
# Search: artist%3ASamuel%20L%20Cool%20J%20year%3A2012
# Search: artist%3ASamuel%20L%20Cool%20J%20year%3A2013
# TOKEN STILL VALID, AGE: 7.965210219224294 MINUTES
# 	Search, Artist: Gritz, Around Year: 2013-08-27
# Search: artist%3AGritz%20year%3A2016
# Search: artist%3AGritz%20year%3A2013
# Search: artist%3AGritz%20year%3A2011
# Search: artist%3AGritz%20year%3A2010
# Search: artist%3AGritz%20year%3A2012
# Search: artist%3AGritz%20year%3A2011
# TOKEN STILL VALID, AGE: 8.04811935822169 MINUTES
# 	Search, Artist: Daniel Norgren, Around Year: 2019-04-19
# Search: artist%3ADaniel%20Norgren%20year%3A2017
# Search: artist%3ADaniel%20Norgren%20year%3A2018
# Search: artist%3ADaniel%20Norgren%20year%3A2021
# Search: artist%3ADaniel%20Norgren%20year%3A2021
# Search: artist%3ADaniel%20Norgren%20year%3A2021
# Search: artist%3ADaniel%20Norgren%20year%3A2022
# TOKEN STILL VALID, AGE: 8.128575615088145 MINUTES
# 	Search, Artist: The The, Around Year: 1983-03-13
# Search: artist%3AThe%20The%20year%3A1982
# Search: artist%3AThe%20The%20year%3A1984
# Search: artist%3AThe%20The%20year%3A1982
# Search: artist%3AThe%20The%20year%3A1985
# Search: artist%3AThe%20The%20year%3A1982
# Search: artist%3AThe%20The%20year%3A1981
# TOKEN STILL VALID, AGE: 8.205326251188914 MINUTES
# 	Search, Artist: The West Coast Pop Art Experimental Band, Around Year: 1967
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1969
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1966
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1966
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1969
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1966
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1970
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1969
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1970
# Search: artist%3AThe%20West%20Coast%20Pop%20Art%20Experimental%20Band%20year%3A1968
# TOKEN STILL VALID, AGE: 8.335981587568918 MINUTES
# 	Search, Artist: KAMAUU, Around Year: 2016-07-01
# Search: artist%3AKAMAUU%20year%3A2013
# Search: artist%3AKAMAUU%20year%3A2015
# Search: artist%3AKAMAUU%20year%3A2016
# Search: artist%3AKAMAUU%20year%3A2019
# Search: artist%3AKAMAUU%20year%3A2016
# Search: artist%3AKAMAUU%20year%3A2019
# TOKEN STILL VALID, AGE: 8.417126401265461 MINUTES
# 	Search, Artist: Haruomi Hosono, Around Year: 1978
# Search: artist%3AHaruomi%20Hosono%20year%3A1978
# Search: artist%3AHaruomi%20Hosono%20year%3A1978
# Search: artist%3AHaruomi%20Hosono%20year%3A1977
# Search: artist%3AHaruomi%20Hosono%20year%3A1979
# Search: artist%3AHaruomi%20Hosono%20year%3A1981
# Search: artist%3AHaruomi%20Hosono%20year%3A1978
# TOKEN STILL VALID, AGE: 8.50116229057312 MINUTES
# 	Search, Artist: Johann Sebastian Bach, Around Year: 1988-11-14
# Search: artist%3AJohann%20Sebastian%20Bach%20year%3A1987
# Search: artist%3AJohann%20Sebastian%20Bach%20year%3A1985
# Search: artist%3AJohann%20Sebastian%20Bach%20year%3A1990
# Search: artist%3AJohann%20Sebastian%20Bach%20year%3A1986
# Search: artist%3AJohann%20Sebastian%20Bach%20year%3A1989
# Search: artist%3AJohann%20Sebastian%20Bach%20year%3A1989
# TOKEN STILL VALID, AGE: 8.582883775234222 MINUTES
# 	Search, Artist: Reigning Sound, Around Year: 2015-12-09
# Search: artist%3AReigning%20Sound%20year%3A2015
# Search: artist%3AReigning%20Sound%20year%3A2015
# Search: artist%3AReigning%20Sound%20year%3A2016
# Search: artist%3AReigning%20Sound%20year%3A2017
# Search: artist%3AReigning%20Sound%20year%3A2018
# Search: artist%3AReigning%20Sound%20year%3A2013
# TOKEN STILL VALID, AGE: 8.66765388250351 MINUTES
# 	Search, Artist: Jessi Colter, Around Year: 1970-07-15
# Search: artist%3AJessi%20Colter%20year%3A1969
# Search: artist%3AJessi%20Colter%20year%3A1969
# Search: artist%3AJessi%20Colter%20year%3A1973
# Search: artist%3AJessi%20Colter%20year%3A1969
# Search: artist%3AJessi%20Colter%20year%3A1973
# Search: artist%3AJessi%20Colter%20year%3A1969
# TOKEN STILL VALID, AGE: 8.752327871322631 MINUTES
# 	Search, Artist: Pharoahe Monch, Around Year: 2007-01-01
# Search: artist%3APharoahe%20Monch%20year%3A2005
# Search: artist%3APharoahe%20Monch%20year%3A2009
# Search: artist%3APharoahe%20Monch%20year%3A2005
# Search: artist%3APharoahe%20Monch%20year%3A2006
# Search: artist%3APharoahe%20Monch%20year%3A2010
# Search: artist%3APharoahe%20Monch%20year%3A2004
# TOKEN STILL VALID, AGE: 8.836779709657034 MINUTES
# 	Search, Artist: J.E. Sunde, Around Year: 2020-11-20
# Search: artist%3AJ.E.%20Sunde%20year%3A2022
# Search: artist%3AJ.E.%20Sunde%20year%3A2022
# Search: artist%3AJ.E.%20Sunde%20year%3A2021
# Search: artist%3AJ.E.%20Sunde%20year%3A2023
# Search: artist%3AJ.E.%20Sunde%20year%3A2023
# Search: artist%3AJ.E.%20Sunde%20year%3A2020
# TOKEN STILL VALID, AGE: 8.915848219394684 MINUTES
# 	Search, Artist: Jagged Edge, Around Year: 2007-01-01
# Search: artist%3AJagged%20Edge%20year%3A2010
# Search: artist%3AJagged%20Edge%20year%3A2005
# Search: artist%3AJagged%20Edge%20year%3A2007
# Search: artist%3AJagged%20Edge%20year%3A2006
# Search: artist%3AJagged%20Edge%20year%3A2009
# Search: artist%3AJagged%20Edge%20year%3A2008
# TOKEN STILL VALID, AGE: 8.999401938915252 MINUTES
# 	Search, Artist: Neal Francis, Around Year: 2022-11-18
# Search: artist%3ANeal%20Francis%20year%3A2021
# Search: artist%3ANeal%20Francis%20year%3A2024
# Search: artist%3ANeal%20Francis%20year%3A2019
# Search: artist%3ANeal%20Francis%20year%3A2025
# Search: artist%3ANeal%20Francis%20year%3A2021
# TOKEN STILL VALID, AGE: 9.067394574483236 MINUTES
# 	Search, Artist: Pras, Around Year: 2009-12-07
# Search: artist%3APras%20year%3A2006
# Search: artist%3APras%20year%3A2011
# Search: artist%3APras%20year%3A2009
# TOKEN STILL VALID, AGE: 9.10855297644933 MINUTES
# 	Search, Artist: Eric Lindell and Co., Around Year: 2014-04-25
# Search: artist%3AEric%20Lindell%20and%20Co.%20year%3A2017
# Search: artist%3AEric%20Lindell%20and%20Co.%20year%3A2016
# Multi-Search COMPLETE: Retreived 637 tracks!
#
# About to filter 637 tracks ...
# About to rank 620 tracks ...
#
# ########## Multi-Search 02: COMPLETE ##########
#
# About to write data/Teo-Music-Data_2024-09-04T15:37:44.pkl ...
# COMPLETE!
# Playlist refill complete!
